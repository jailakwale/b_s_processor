# %% [markdown]
# # Preliminary test on a Single Bank

# %%
import os
import pdftables_api
import glob2
import tabula
import pandas as pd
import numpy as np
from tqdm import tqdm
import time
import cv2
import matplotlib.pyplot as plt
import re
import logging

# %%
pd.set_option("max_colwidth", 3000)
pd.set_option("max_rows", 2000)
pd.set_option("max_columns", 2000)

# %% [markdown]
# # 1. Statement extraction

# %%
DATA_FOLDER = './statements/'
MY_API_KEY = ''

# %%
glob2.glob(os.path.join(DATA_FOLDER, "*"))
# Out:
# ['./statements/224912180637606770417463100932.pdf',
#  './statements/Account Statement (1).pdf',
#  './statements/420 STATEMENT.pdf',
#  './statements/CUSTOMER_STATEMENT_OF_ACCT_ONLINE_F12[NWOLU].pdf',
#  './statements/0163041071-(205154861110).pdf',
#  './statements/account_stmt_24Apr2021_24Jun2021.pdf',
#  './statements/68197656963758929248882067034.pdf',
#  './statements/OFFER LETTER MR FITZGERALD Signed 01072021.pdf',
#  './statements/output.csv',
#  './statements/420 PROPERTIES LIMITED.pdf',
#  './statements/fav Ajo.pdf',
#  './statements/statement_adeshina iliasu.pdf',
#  './statements/224912180637606770417463100932output.csv',
#  './statements/68197656963758929248882067034output.csv']

# %%
def process_bank_statements(b_statements_gt_bank, out_format ='csv'):
    '''
    Method to transform to csv a list of Bank statements paths
    '''
    
    n_statements = len(b_statements_gt_bank)
    for bk_st in tqdm(b_statements_gt_bank):
        inp = bk_st
        out = bk_st.replace(".pdf","output.csv")
        tabula.convert_into(inp, out, output_format=out_format)
        
    print( f"{n_statements} bank_statements processed!")

# %%
bank_statements_gt_bank = ["./statements/224912180637606770417463100932.pdf",
                          "./statements/68197656963758929248882067034.pdf"]

# %%
process_bank_statements(bank_statements_gt_bank, out_format ='csv')
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]'pages' argument isn't specified.Will extract only from page 1 by default.
#  50%|█████     | 1/2 [00:02<00:02,  2.26s/it]'pages' argument isn't specified.Will extract only from page 1 by default.
# 100%|██████████| 2/2 [00:03<00:00,  1.91s/it]
# 2 bank_statements processed!

# %%
def bank_statement_to_dataframe(b_statement_gt_bank, mult=True, pages_all='all'):
    '''
    Function to transform to dataframe a Bank statement pdf
    
    b_statement_gt_bank: a statement path of a Bank statement pdf
    mult: consider various tables in the document
    pages_all: keep all pages if 'all'
    '''
    df = tabula.read_pdf(b_statement_gt_bank,
                         multiple_tables=mult,
                         pages=pages_all)
    return df

# %%
def bank_statement_to_dataframe_plus(b_statement_gt_bank, mult=True, pages_all='all'):
    '''
    Function to transform to dataframe a Bank statement pdf
    
    b_statement_gt_bank: a statement path of a Bank statement pdf
    mult: consider various tables in the document
    pages_all: keep all pages if 'all'
    '''
    df = tabula.read_pdf(b_statement_gt_bank,
                         multiple_tables=mult,
                         lattice= True,
                         pages=pages_all)
    return df

# %% [markdown]
# for the other type:
# read as normal to extract the 2 info tables
# and then read as lattice to extract the remaining info

# %%
df = tabula.read_pdf("./GT_BANK/orange_header/Abiodun_lanre_gtb_statement.pdf",
                     multiple_tables=True,
                     lattice = True,
                     pages='all')

# %%
df[50]

# %%
df = tabula.read_pdf("./statements/224912180637606770417463100932.pdf", 
                     multiple_tables=True,
                    pages='all')

# %%
b_statement = bank_statements_gt_bank[1]
customer = bank_statement_to_dataframe(b_statement, mult=True, pages_all='all')

# %%
type_account = type_account.T.reset_index().T.reset_index(drop=True)
type_account.columns = ["PI", "Detail"]

# %%
account_customer_description = type_account[type_account["PI"]== "Account Type"]["Detail"].values[0]

# %% [markdown]
# ### Refactor idea:
# - use abstract classes
# - use decorators

# %% [markdown]
# ### Abstract classes:

# %%
# On this example, we define a class Bank_statement
# this class is an abstract class. That is, it describes
# the list of methods / functions that the class implements

# %%
from abc import ABC, abstractmethod
 
class Bank_statement(ABC):
 
    def __init__(self, b_statement_bank, bank_id):
        self.b_statement_bank = b_statement_bank
        self.bank_id = bank_id
        super().__init__()
    
    @abstractmethod
    def return_bank(self):
        pass
    
    @abstractmethod
    # when you write an abstract class you are not
    # forced to declare the arguments in the abstract function
    def process_bank(self):
        pass

# %%
class _GT_BankStatement(Bank_statement):
    def __init__(self, b_gt_statement_bank, bank_id):
        self.b_statement_bank = b_gt_statement_bank
        self.bank_id = bank_id
        #super().__init__()
    
    def return_bank(self):
        return self.bank_id
    
    def process_bank(self, bk_statement):
        return "b_gt_bank"

# %%
# The class can be instantiated
# The class's methods can also be called

# %%
gt = _GT_BankStatement("my_file.csv", 15)

# %%
gt.process_bank(2)
# Out:
# 'b_gt_bank'

# %% [markdown]
# ### Decorators

# %%
def time_decorator(decorated_func):
    # the exterior  part returns the interior part
    # the interior part  runs the function we want to decorate
    # plus its decorations
    
    def timely_decorate_me():
        
        # this decoration happens here
        # the logic is to enclose the code with 2 timer ticks
        # start tick
        start_timer = time.time()
        
        # you need to evaluate the function
        interm = decorated_func()
        
        # end tick
        end_timer = time.time()
        
        # the goal is to display how long the function took
        print(end_timer-start_timer)
        
        return interm
    
    return timely_decorate_me

# %%
@time_decorator
def my_function():
    '''
    simple function which stores in a list
    1000 times the same piece of text
    '''
    l = []
    for i in range(1000):
        l.append("this is crazy")
    return "done"

# %%
my_function()
# Out:
# 8.296966552734375e-05
# 'done'

# %%
os.getcwd()
# Out:
# '/Users/assansanogo/Downloads'

# %%
import pdf2image
def safe_convert(filename, out, folder):
    assert os.path.exists(filename)
    my_im = pdf2image.convert_from_path(filename,output_folder = folder, last_page= 1, output_file= out, paths_only= True, fmt='jpg')
    return my_im

# %%
# step 0:
# conversion to images

# %%
def convert_pdf_2_im(folder,filename):
    full_filename = os.path.join(folder,filename)
    print(full_filename)
    out = full_filename.split(".pdf")[0].split("/")[-1]
    safe_convert(full_filename, out, folder)

# %%
folder = "./GT_BANK/no_header"
filenames = [os.path.basename(el) for el in glob2.glob(os.path.join(folder,"*.pdf"))]

# %%
filenames
# Out:
# []

# %%
for f in filenames:
    convert_pdf_2_im(folder,f)

# %%
def read_image_crop(folder, image_path, crop=250):
    '''
    the function crops the right upper corner
    '''
    my_im = cv2.imread(os.path.join(folder, image_path))
    my_im_RGB = cv2.cvtColor(my_im, cv2.COLOR_BGR2RGB)
    return my_im_RGB[:250,-250:]

# %%
my_folder = "./GT_BANK/no_header"
my_image_path =  [os.path.basename(el) for el in glob2.glob(os.path.join(folder,"*.jpg"))]

# %%
for im in my_image_path:
    plt.imshow(read_image_crop(my_folder, im))
    plt.show()

# %% [markdown]
# ## Second type of gt bank document

# %%
class GT_BankStatement_header():

    def __init__(self, b_statement_gt_bank, bank_id='GT_Bank', template_version=1):
        '''
        initializes the Gt_bank statement class
        '''
        # a bankstatement has 2 input attributes (for now)
        # bank_id & statement pdf path
        
        self.bank_id = bank_id
        self.customer_bank_statement_formatted = bank_statement_to_dataframe_plus(b_statement_gt_bank, mult=True, pages_all='all')
        self.customer_bank_statement_formatted_statement = [ df for df in self.customer_bank_statement_formatted if len(df.columns)>2 ]
        #self.customer_bank_statement_raw = bank_statement_to_dataframe(b_statement_gt_bank, mult=True, pages_all='all')
      
        self.df = self.customer_bank_statement_formatted.copy()
        #self.raw_df = self.customer_bank_statement_raw.copy()

    def describe_accounts_types_header(self):
        '''
        returns the account type (savings or current)
        '''
        
        info_idxs = []
        for i in range(len(self.df)):
            if len(self.df[i].columns) <=2:
                 info_idxs.append(i)
        self.accounts = []
        print(info_idxs)
        
        for idx,val in enumerate(info_idxs):

            df = self.df[idx].transpose().reset_index()
            try:
                df.columns = [0,1,2]
                arr_df =[]
                for i in range(3):
                    arr_df.append(df[i])
                for df_str in arr_df:
                    #print(df_str.values[0])
                    
                    if "\rAccount" in df_str.values[0]:
                        self.accounts.append(df_str.values[0])      
                        
            except Exception as e:
                pass
                #print(e)
                #print(self.df[idx])
        
        self.types_account = set((['current' for el in customer2.accounts if 'CURRENT' in el ])+(['savings' for el in customer2.accounts if 'SAVINGS' in el ]))
  
    def combine_df(self):
        
        all_statements = []
        for statement in self.customer_bank_statement_formatted_statement:
            all_statements.append(pd.DataFrame(statement).T.reset_index().T.replace(regex={r'Unnamed:':''}))
        self.combined = pd.concat(all_statements).reset_index(drop=True)
        sef.combined.columns = ['Trans. Date','Reference','Value. Date','Debits','Credits','Balance','Remarks_processed']

# %%
customer2 =  GT_BankStatement_header("./GT_BANK/orange_header/0163041071-(205154861110).pdf")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-ca61808ba384> in <module>
# ----> 1 customer2 =  GT_BankStatement_header("./GT_BANK/orange_header/0163041071-(205154861110).pdf")
#
# <ipython-input-28-1b8b3576ce8b> in __init__(self, b_statement_gt_bank, bank_id, template_version)
#       9
#      10         self.bank_id = bank_id
# ---> 11         self.customer_bank_statement_formatted = bank_statement_to_dataframe_plus(b_statement_gt_bank, mult=True, pages_all='all')
#      12         self.customer_bank_statement_formatted_statement = [ df for df in self.customer_bank_statement_formatted if len(df.columns)>2 ]
#      13         #self.customer_bank_statement_raw = bank_statement_to_dataframe(b_statement_gt_bank, mult=True, pages_all='all')
#
# <ipython-input-9-57e2430e6b1f> in bank_statement_to_dataframe_plus(b_statement_gt_bank, mult, pages_all)
#       7     pages_all: keep all pages if 'all'
#       8     '''
# ----> 9     df = tabula.read_pdf(b_statement_gt_bank,
#      10                          multiple_tables=mult,
#      11                          lattice= True,
#
# /opt/anaconda3/lib/python3.8/site-packages/tabula/io.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     312
#     313     if not os.path.exists(path):
# --> 314         raise FileNotFoundError(errno.ENOENT, os.strerror(errno.ENOENT), path)
#     315
#     316     if os.path.getsize(path) == 0:
#
# FileNotFoundError: [Errno 2] No such file or directory: './GT_BANK/orange_header/0163041071-(205154861110).pdf'

# %%
customer2.describe_accounts_types_header()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-a1ef466a26f5> in <module>
# ----> 1 customer2.describe_accounts_types_header()
#
# NameError: name 'customer2' is not defined

# %%
customer2.types_account
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1fd116f58717> in <module>
# ----> 1 customer2.types_account
#
# NameError: name 'customer2' is not defined

# %%
customer2.combine_df()

# %%
customer2.combined
# Out:
#                0          1              2           3           4  \
# 0    01­Dec­2020          0  01­Dec­2020.1   20,000.00           0
# 1    01­Dec­2020          0    01­Dec­2020    2,000.00         NaN
# 2    01­Dec­2020          0    01­Dec­2020         NaN   58,546.49
# 3    01­Dec­2020          0    01­Dec­2020   41,000.00         NaN
# 4    01­Dec­2020          0    01­Dec­2020    4,000.00         NaN
# 5    01­Dec­2020          0    01­Dec­2020      200.00         NaN
# 6    01­Dec­2020          0    01­Dec­2020    1,000.00         NaN
# 7    01­Dec­2020          0    01­Dec­2020    1,000.00         NaN
# 8    01­Dec­2020          0    01­Dec­2020         NaN    3,000.00
# 9    01­Dec­2020          4    01­Dec­2020   10,000.00         NaN
# 10   01­Dec­2020          5    01­Dec­2020    5,000.00         NaN
# 11   02­Dec­2020          0    02­Dec­2020      200.00         NaN
# 12   02­Dec­2020          0    02­Dec­2020      100.00         NaN
# 13   04­Dec­2020          0  04­Dec­2020.1      200.00           0
# 14   05­Dec­2020          0    05­Dec­2020      200.00         NaN
# 15   06­Dec­2020          0    06­Dec­2020      200.00         NaN
# 16   12­Dec­2020          0    12­Dec­2020      200.00         NaN
# 17   13­Dec­2020          0    12­Dec­2020         NaN    2,000.00
# 18   17­Dec­2020          0    17­Dec­2020         NaN    4,000.00
# 19   17­Dec­2020          0    17­Dec­2020    5,000.00         NaN
# 20   17­Dec­2020          0    17­Dec­2020    1,000.00         NaN
# 21   30­Dec­2020          0    31­Dec­2020         NaN   72,457.10
# 22   30­Dec­2020          0    31­Dec­2020         NaN  113,932.66
# 23   30­Dec­2020          0    31­Dec­2020         NaN   40,066.78
# 24   30­Dec­2020          0    30­Dec­2020         NaN    3,000.00
# 25   31­Dec­2020          0    30­Dec­2020  225,000.00         NaN
# 26   31­Dec­2020          0    31­Dec­2020         NaN  483,000.00
# 27   31­Dec­2020          0    31­Dec­2020         NaN    5,000.00
# 28   31­Dec­2020  412000...    31­Dec­2020  490,042.24         NaN
# 29   31­Dec­2020  412001...    31­Dec­2020         NaN  802,574.00
# 30   31­Dec­2020          0    31­Dec­2020  800,000.00         NaN
# 31   31­Dec­2020          0    31­Dec­2020      500.00         NaN
# 32   31­Dec­2020          0    31­Dec­2020    2,000.00         NaN
# 33   31­Dec­2020          0    31­Dec­2020         NaN   80,000.00
# 34   31­Dec­2020  412000...  31­Dec­2020.1    5,042.08           0
# 35   31­Dec­2020          0    31­Dec­2020      169.81         NaN
# 36   01­Jan­2021          0    31­Dec­2020   43,370.58         NaN
# 37   01­Jan­2021          0    01­Jan­2021         NaN   25,000.00
# 38   01­Jan­2021          0    01­Jan­2021      400.00         NaN
# 39   01­Jan­2021          0    01­Jan­2021    1,500.00         NaN
# 40   01­Jan­2021          0    01­Jan­2021      500.00         NaN
# 41   05­Jan­2021          0    05­Jan­2021         NaN  156,000.00
# 42   05­Jan­2021          0    05­Jan­2021   25,027.40         NaN
# 43   05­Jan­2021          0    05­Jan­2021   75,000.00         NaN
# 44   05­Jan­2021          0    05­Jan­2021    1,000.00         NaN
# 45   06­Jan­2021          0    06­Jan­2021      200.00         NaN
# 46   06­Jan­2021          0    06­Jan­2021      500.00         NaN
# 47   06­Jan­2021          0    06­Jan­2021    8,000.00         NaN
# 48   06­Jan­2021          0    06­Jan­2021   30,000.00         NaN
# 49   07­Jan­2021          0    07­Jan­2021    1,500.00         NaN
# 50   07­Jan­2021          0    07­Jan­2021      200.00         NaN
# 51   08­Jan­2021          0    08­Jan­2021      200.00         NaN
# 52   08­Jan­2021          0  08­Jan­2021.1    3,000.00           0
# 53   08­Jan­2021          0    08­Jan­2021    3,000.00         NaN
# 54   09­Jan­2021          0    09­Jan­2021    3,400.00         NaN
# 55   10­Jan­2021          0    10­Jan­2021         NaN   20,000.00
# 56   10­Jan­2021          0    10­Jan­2021   20,000.00         NaN
# 57   13­Jan­2021          0    13­Jan­2021      100.00         NaN
# 58   14­Jan­2021          0    14­Jan­2021         NaN    2,000.00
# 59   14­Jan­2021          0    14­Jan­2021      140.00         NaN
# 60   14­Jan­2021          0    14­Jan­2021       10.50         NaN
# 61   14­Jan­2021          0    14­Jan­2021      500.00         NaN
# 62   14­Jan­2021          0    14­Jan­2021    1,000.00         NaN
# 63   14­Jan­2021          0    14­Jan­2021      200.00         NaN
# 64   14­Jan­2021          0    14­Jan­2021      200.00         NaN
# 65   19­Jan­2021          0    19­Jan­2021         NaN    5,000.00
# 66   20­Jan­2021          0    20­Jan­2021    1,000.00         NaN
# 67   20­Jan­2021          0    20­Jan­2021         NaN  395,000.00
# 68   20­Jan­2021          0  20­Jan­2021.1           0  100,000.00
# 69   20­Jan­2021          0    20­Jan­2021   20,000.00         NaN
# 70   20­Jan­2021          0    20­Jan­2021    4,500.00         NaN
# 71   20­Jan­2021          0    20­Jan­2021    3,800.00         NaN
# 72   20­Jan­2021          0    20­Jan­2021         NaN    7,000.00
# 73   20­Jan­2021          0    20­Jan­2021   30,000.00         NaN
# 74   21­Jan­2021          0    21­Jan­2021   10,000.00         NaN
# 75   21­Jan­2021          0    21­Jan­2021    1,000.00         NaN
# 76   21­Jan­2021          0    21­Jan­2021    1,000.00         NaN
# 77   21­Jan­2021          0    21­Jan­2021    1,000.00         NaN
# 78   21­Jan­2021          0    21­Jan­2021      500.00         NaN
# 79   21­Jan­2021          0    21­Jan­2021      200.00         NaN
# 80   22­Jan­2021  491600...    22­Jan­2021    1,000.00         NaN
# 81   22­Jan­2021          0    22­Jan­2021      200.00         NaN
# 82   22­Jan­2021          0    22­Jan­2021    8,000.00         NaN
# 83   22­Jan­2021          0    22­Jan­2021   22,000.00         NaN
# 84   23­Jan­2021          0  23­Jan­2021.1   10,000.00           0
# 85   23­Jan­2021          0    23­Jan­2021      500.00         NaN
# 86   24­Jan­2021          0    24­Jan­2021    1,500.00         NaN
# 87   24­Jan­2021          0    24­Jan­2021    3,000.00         NaN
# 88   24­Jan­2021          0    24­Jan­2021    5,000.00         NaN
# 89   25­Jan­2021          0    25­Jan­2021      200.00         NaN
# 90   25­Jan­2021          0    25­Jan­2021    3,000.00         NaN
# 91   25­Jan­2021  491200...    25­Jan­2021    1,000.00         NaN
# 92   25­Jan­2021          0    25­Jan­2021   15,000.00         NaN
# 93   26­Jan­2021          0    26­Jan­2021   10,000.00         NaN
# 94   26­Jan­2021          0    26­Jan­2021      200.00         NaN
# 95   27­Jan­2021          0    27­Jan­2021    5,000.00         NaN
# 96   27­Jan­2021          0    27­Jan­2021         NaN    5,000.00
# 97   27­Jan­2021          0    27­Jan­2021    7,000.00         NaN
# 98   28­Jan­2021          0    28­Jan­2021    1,000.00         NaN
# 99   28­Jan­2021          0  28­Jan­2021.1      200.00           0
# 100  28­Jan­2021          0    28­Jan­2021    2,000.00         NaN
# 101  28­Jan­2021          0    28­Jan­2021      200.00         NaN
# 102  28­Jan­2021          0    28­Jan­2021      100.00         NaN
# 103  28­Jan­2021          0    28­Jan­2021   73,000.00         NaN
# 104  28­Jan­2021          0    29­Jan­2021         NaN   71,353.48
# 105  28­Jan­2021          0    29­Jan­2021         NaN  113,932.66
# 106  28­Jan­2021          0    29­Jan­2021         NaN   40,066.78
# 107  28­Jan­2021          0    28­Jan­2021         NaN  140,906.24
# 108  29­Jan­2021          0    29­Jan­2021      200.00         NaN
# 109  29­Jan­2021          0    29­Jan­2021   86,000.00         NaN
# 110  29­Jan­2021          0    29­Jan­2021  500,000.00         NaN
# 111  29­Jan­2021          0    29­Jan­2021         NaN  200,000.00
# 112  29­Jan­2021          0    29­Jan­2021   43,370.58         NaN
# 113  29­Jan­2021          0    29­Jan­2021    1,100.00         NaN
# 114  29­Jan­2021          0    29­Jan­2021    1,100.00         NaN
# 115  29­Jan­2021          0    29­Jan­2021   62,000.00         NaN
# 116  29­Jan­2021  411900...    29­Jan­2021   55,558.36         NaN
# 117  29­Jan­2021  412000...    29­Jan­2021    4,999.59         NaN
# 118  30­Jan­2021          0  30­Jan­2021.1    1,000.00           0
# 119  31­Jan­2021          0    31­Jan­2021   40,000.00         NaN
# 120  31­Jan­2021          0    31­Jan­2021    1,000.00         NaN
# 121  31­Jan­2021          0    31­Jan­2021    2,100.00         NaN
# 122  31­Jan­2021          0    31­Jan­2021      200.00         NaN
# 123  31­Jan­2021  412001...    31­Jan­2021   72,993.65         NaN
# 124  31­Jan­2021          0    31­Jan­2021       59.69         NaN
# 125  01­Feb­2021          0    01­Feb­2021         NaN   57,000.00
# 126  01­Feb­2021  491600...    01­Feb­2021    4,000.00         NaN
# 127  01­Feb­2021          0    31­Jan­2021         NaN   56,000.00
# 128  02­Feb­2021          0    02­Feb­2021   15,000.00         NaN
# 129  02­Feb­2021          0    02­Feb­2021    5,000.00         NaN
# 130  02­Feb­2021          0    02­Feb­2021    3,000.00         NaN
# 131  02­Feb­2021          0    02­Feb­2021    2,000.00         NaN
# 132  02­Feb­2021  491600...    02­Feb­2021    8,000.00         NaN
# 133  02­Feb­2021          0    02­Feb­2021         NaN   20,000.00
# 134  02­Feb­2021          0    02­Feb­2021   20,000.00         NaN
# 135  03­Feb­2021          0  03­Feb­2021.1    5,000.00           0
# 136  03­Feb­2021          0    03­Feb­2021    5,000.00         NaN
# 137  03­Feb­2021          0    03­Feb­2021   10,000.00         NaN
# 138  05­Feb­2021          0    05­Feb­2021      200.00         NaN
# 139  09­Feb­2021          0    09­Feb­2021         NaN    2,000.00
# 140  09­Feb­2021          0    09­Feb­2021      200.00         NaN
# 141  09­Feb­2021          0    09­Feb­2021    1,000.00         NaN
# 142  10­Feb­2021          0    10­Feb­2021      200.00         NaN
# 143  11­Feb­2021          0    11­Feb­2021      700.00         NaN
# 144  11­Feb­2021          0    11­Feb­2021       80.00         NaN
# 145  16­Feb­2021          0    16­Feb­2021         NaN   25,000.00
# 146  16­Feb­2021          0    16­Feb­2021      200.00         NaN
# 147  16­Feb­2021          0    16­Feb­2021      200.00         NaN
# 148  16­Feb­2021          0    16­Feb­2021    5,000.00         NaN
# 149  17­Feb­2021          0    17­Feb­2021   19,600.00         NaN
# 150  23­Feb­2021          0    23­Feb­2021         NaN  200,000.00
# 151  24­Feb­2021          0    24­Feb­2021      200.00         NaN
# 152  24­Feb­2021          0  24­Feb­2021.1  100,000.00           0
# 153  24­Feb­2021          0    24­Feb­2021   34,000.00         NaN
# 154  24­Feb­2021          0    24­Feb­2021   15,000.00         NaN
# 155  25­Feb­2021          0    25­Feb­2021         NaN    5,000.00
# 156  25­Feb­2021          0    25­Feb­2021         NaN    3,000.00
# 157  25­Feb­2021          0    25­Feb­2021   10,000.00         NaN
# 158  25­Feb­2021          0    25­Feb­2021      200.00         NaN
# 159  25­Feb­2021          0    26­Feb­2021         NaN   71,353.48
# 160  25­Feb­2021          0    26­Feb­2021         NaN  113,932.66
# 161  25­Feb­2021          0    26­Feb­2021         NaN   40,066.78
# 162  26­Feb­2021          0    26­Feb­2021      200.00         NaN
# 163  26­Feb­2021          0    26­Feb­2021   25,000.00         NaN
# 164  26­Feb­2021          0    26­Feb­2021      200.00         NaN
# 165  26­Feb­2021          0    26­Feb­2021    3,700.00         NaN
# 166  26­Feb­2021          0    26­Feb­2021  112,000.00         NaN
# 167  26­Feb­2021  411900...    26­Feb­2021   55,078.43         NaN
# 168            0          1              2           3           4
# 169  26­Feb­2021  412001...    26­Feb­2021   72,818.23         NaN
# 170  27­Feb­2021          0    27­Feb­2021         NaN   40,050.00
# 171  27­Feb­2021          0    27­Feb­2021      500.00         NaN
# 172  27­Feb­2021          0    27­Feb­2021         NaN   60,000.00
# 173  27­Feb­2021          0    27­Feb­2021   50,000.00         NaN
# 174  27­Feb­2021          0    27­Feb­2021   10,000.00         NaN
# 175  27­Feb­2021          0    27­Feb­2021         NaN   25,000.00
# 176  27­Feb­2021  491600...    27­Feb­2021    1,000.00         NaN
# 177  28­Feb­2021          0    28­Feb­2021      200.00         NaN
# 178  28­Feb­2021  491600...    28­Feb­2021   20,000.00         NaN
# 179  28­Feb­2021          0    28­Feb­2021    1,500.00         NaN
# 180  28­Feb­2021          0    28­Feb­2021   10,000.00         NaN
# 181  28­Feb­2021          0    28­Feb­2021         NaN   50,000.00
# 182  28­Feb­2021          0    28­Feb­2021         NaN       19.57
# 183  28­Feb­2021          0    28­Feb­2021        1.96         NaN
# 184  01­Mar­2021          0    01­Mar­2021      200.00         NaN
# 185  01­Mar­2021          0    01­Mar­2021    1,000.00         NaN
# 186  01­Mar­2021          0    01­Mar­2021    2,500.00         NaN
# 187  01­Mar­2021          0    01­Mar­2021    2,500.00         NaN
# 188  01­Mar­2021          0    01­Mar­2021    2,100.00         NaN
# 189  02­Mar­2021          0  02­Mar­2021.1    3,000.00           0
# 190  02­Mar­2021          0    02­Mar­2021   20,000.00         NaN
# 191  02­Mar­2021          0    02­Mar­2021         NaN   40,000.00
# 192  02­Mar­2021          0    02­Mar­2021   43,370.58         NaN
# 193  02­Mar­2021          0    02­Mar­2021      200.00         NaN
# 194  03­Mar­2021          0    03­Mar­2021    2,000.00         NaN
# 195  03­Mar­2021          0    03­Mar­2021    1,000.00         NaN
# 196  03­Mar­2021          0    03­Mar­2021      200.00         NaN
# 197  03­Mar­2021          0    03­Mar­2021      200.00         NaN
# 198  03­Mar­2021          0    03­Mar­2021    1,000.00         NaN
# 199  04­Mar­2021          0    04­Mar­2021    5,000.00         NaN
# 200  04­Mar­2021          0    04­Mar­2021         NaN   15,000.00
# 201  04­Mar­2021          0    04­Mar­2021   15,000.00         NaN
# 202  06­Mar­2021          0    06­Mar­2021      200.00         NaN
# 203  07­Mar­2021          0    07­Mar­2021      500.00         NaN
# 204  07­Mar­2021          0    07­Mar­2021      500.00         NaN
# 205  08­Mar­2021          0    08­Mar­2021         NaN   20,120.00
# 206  09­Mar­2021          0  09­Mar­2021.1    1,000.00           0
# 207  09­Mar­2021          0    09­Mar­2021      500.00         NaN
# 208  09­Mar­2021          0    09­Mar­2021    5,000.00         NaN
# 209  09­Mar­2021          0    09­Mar­2021      300.00         NaN
# 210  10­Mar­2021          0    10­Mar­2021    4,500.00         NaN
# 211  10­Mar­2021          0    10­Mar­2021         NaN   12,880.00
# 212  10­Mar­2021          0    10­Mar­2021         NaN   54,500.00
# 213  10­Mar­2021          0    10­Mar­2021   54,500.00         NaN
# 214  10­Mar­2021          0    10­Mar­2021    1,000.00         NaN
# 215  11­Mar­2021          0    11­Mar­2021    1,500.00         NaN
# 216  11­Mar­2021          0    11­Mar­2021         NaN   20,000.00
# 217  11­Mar­2021          0    11­Mar­2021      200.00         NaN
# 218  11­Mar­2021          0    11­Mar­2021    7,000.00         NaN
# 219  11­Mar­2021          0    11­Mar­2021    3,000.00         NaN
# 220  11­Mar­2021          0    11­Mar­2021    5,000.00         NaN
# 221  12­Mar­2021          0  12­Mar­2021.1           0    2,000.00
# 222  12­Mar­2021          0    12­Mar­2021    1,000.00         NaN
# 223  13­Mar­2021          0    13­Mar­2021   10,000.00         NaN
# 224  13­Mar­2021          0    13­Mar­2021    1,000.00         NaN
# 225  14­Mar­2021          0    14­Mar­2021      200.00         NaN
# 226  14­Mar­2021          0    14­Mar­2021         NaN    1,000.00
# 227  14­Mar­2021          0    14­Mar­2021    1,000.00         NaN
# 228  14­Mar­2021          0    14­Mar­2021    1,000.00         NaN
# 229  15­Mar­2021          0    15­Mar­2021      200.00         NaN
# 230  15­Mar­2021          0    15­Mar­2021         NaN   60,000.00
# 231  15­Mar­2021          0    15­Mar­2021   60,000.00         NaN
# 232  15­Mar­2021          0    15­Mar­2021      300.00         NaN
# 233  15­Mar­2021          0    15­Mar­2021      200.00         NaN
# 234  16­Mar­2021          0    16­Mar­2021      500.00         NaN
# 235  16­Mar­2021          0    16­Mar­2021    4,000.00         NaN
# 236  16­Mar­2021          0    16­Mar­2021      200.00         NaN
# 237  16­Mar­2021          0    16­Mar­2021         NaN   60,000.00
# 238  16­Mar­2021          0  16­Mar­2021.1           0    8,000.00
# 239  16­Mar­2021          0    16­Mar­2021   64,500.00         NaN
# 240  16­Mar­2021          0    16­Mar­2021      200.00         NaN
# 241  16­Mar­2021          0    16­Mar­2021      200.00         NaN
# 242  17­Mar­2021          0    17­Mar­2021    1,500.00         NaN
# 243  17­Mar­2021          0    17­Mar­2021         NaN   30,000.00
# 244  18­Mar­2021          0    18­Mar­2021      200.00         NaN
# 245  18­Mar­2021          0    18­Mar­2021   23,500.00         NaN
# 246  18­Mar­2021          0    18­Mar­2021    5,000.00         NaN
# 247  18­Mar­2021          0    18­Mar­2021         NaN   20,000.00
# 248  19­Mar­2021          0    19­Mar­2021         NaN   50,000.00
# 249  19­Mar­2021          0    19­Mar­2021      200.00         NaN
# 250  19­Mar­2021          0    19­Mar­2021   74,400.00         NaN
# 251  22­Mar­2021          0    22­Mar­2021         NaN   50,000.00
# 252  22­Mar­2021          0    22­Mar­2021   50,000.00         NaN
# 253  30­Mar­2021          0    31­Mar­2021         NaN   40,066.78
# 254  30­Mar­2021          0    31­Mar­2021         NaN  113,932.66
# 255  30­Mar­2021          0    31­Mar­2021         NaN   71,353.48
# 256  31­Mar­2021          0    31­Mar­2021    2,000.00         NaN
# 257  31­Mar­2021          0  31­Mar­2021.1    1,500.00           0
# 258  31­Mar­2021          0    31­Mar­2021   50,000.00         NaN
# 259  31­Mar­2021          0    31­Mar­2021  150,000.00         NaN
# 260  31­Mar­2021          0    31­Mar­2021         NaN  150,000.00
# 261  31­Mar­2021          0    31­Mar­2021  195,000.00         NaN
# 262  31­Mar­2021          0    31­Mar­2021      200.00         NaN
# 263  31­Mar­2021          0    31­Mar­2021         NaN   10,000.00
# 264  31­Mar­2021  411900...    31­Mar­2021   56,338.88         NaN
# 265  31­Mar­2021  412000...    31­Mar­2021    5,003.27         NaN
# 266  31­Mar­2021  412001...    31­Mar­2021   72,818.23         NaN
# 267  31­Mar­2021          0    31­Mar­2021       69.36         NaN
# 268  01­Apr­2021          0    01­Apr­2021         NaN   79,000.00
# 269  01­Apr­2021          0    01­Apr­2021         NaN   15,000.00
# 270  01­Apr­2021          0    01­Apr­2021         NaN  156,000.00
# 271  01­Apr­2021          0    01­Apr­2021   25,305.48         NaN
# 272  01­Apr­2021          0    01­Apr­2021   50,000.00         NaN
# 273  01­Apr­2021          0    01­Apr­2021   43,370.58         NaN
# 274  01­Apr­2021          0    01­Apr­2021    5,000.00         NaN
# 275  01­Apr­2021      13622  01­Apr­2021.1    7,500.00           0
# 276  01­Apr­2021          1    01­Apr­2021    5,000.00         NaN
# 277  02­Apr­2021          0    02­Apr­2021         NaN   36,000.00
# 278  02­Apr­2021          0    02­Apr­2021         NaN   19,000.00
# 279  02­Apr­2021  491500...    02­Apr­2021   30,000.00         NaN
# 280  02­Apr­2021  491500...    02­Apr­2021   22,000.00         NaN
# 281  02­Apr­2021          0    02­Apr­2021   10,000.00         NaN
# 282  02­Apr­2021          0    02­Apr­2021         NaN   54,000.00
# 283  02­Apr­2021  491600...    02­Apr­2021   40,000.00         NaN
# 284  02­Apr­2021          0    02­Apr­2021   15,000.00         NaN
# 285  04­Apr­2021          0    04­Apr­2021         NaN   33,000.00
# 286  04­Apr­2021  491600...    04­Apr­2021   40,000.00         NaN
# 287  04­Apr­2021  491600...    04­Apr­2021    3,000.00         NaN
# 288  06­Apr­2021          0    06­Apr­2021         NaN   35,200.00
# 289  06­Apr­2021          0    06­Apr­2021    6,257.50         NaN
# 290  06­Apr­2021          0  06­Apr­2021.1   28,661.25           0
# 291  06­Apr­2021          0    06­Apr­2021      100.00         NaN
# 292  07­Apr­2021          0    07­Apr­2021      200.00         NaN
# 293  08­Apr­2021          0    08­Apr­2021         NaN   20,000.00
# 294  09­Apr­2021          0    09­Apr­2021         NaN   13,000.00
# 295  09­Apr­2021          0    09­Apr­2021   10,000.00         NaN
# 296  09­Apr­2021          0    09­Apr­2021         NaN   41,500.00
# 297  09­Apr­2021          0    09­Apr­2021      200.00         NaN
# 298  09­Apr­2021          0    09­Apr­2021         NaN   30,000.00
# 299  09­Apr­2021          0    09­Apr­2021   33,000.00         NaN
# 300  09­Apr­2021          0    09­Apr­2021   10,000.00         NaN
# 301  09­Apr­2021          0    09­Apr­2021      200.00         NaN
# 302  10­Apr­2021          0    10­Apr­2021    5,000.00         NaN
# 303  12­Apr­2021          0  12­Apr­2021.1           0   30,000.00
# 304  12­Apr­2021          0    12­Apr­2021   30,000.00         NaN
# 305  13­Apr­2021          0    13­Apr­2021   10,000.00         NaN
# 306  13­Apr­2021          0    13­Apr­2021    5,000.00         NaN
# 307  13­Apr­2021          0    13­Apr­2021   10,000.00         NaN
# 308  14­Apr­2021          0    14­Apr­2021    1,500.00         NaN
# 309  14­Apr­2021          0    14­Apr­2021      200.00         NaN
# 310  14­Apr­2021          0    14­Apr­2021   10,000.00         NaN
# 311  15­Apr­2021          0    15­Apr­2021    1,000.00         NaN
# 312  17­Apr­2021          0    17­Apr­2021      200.00         NaN
# 313  17­Apr­2021          0    17­Apr­2021    1,000.00         NaN
# 314  17­Apr­2021          0    17­Apr­2021    1,000.00         NaN
# 315  17­Apr­2021          0    17­Apr­2021         NaN    5,000.00
# 316  17­Apr­2021          0    17­Apr­2021    3,000.00         NaN
# 317  17­Apr­2021          0    17­Apr­2021         NaN   25,000.00
# 318  17­Apr­2021          0  17­Apr­2021.1   10,000.00           0
# 319  17­Apr­2021          0    17­Apr­2021         NaN      400.00
# 320  17­Apr­2021          0    17­Apr­2021    2,460.00         NaN
# 321  17­Apr­2021          0    17­Apr­2021       50.00         NaN
# 322  18­Apr­2021          0    18­Apr­2021         NaN    5,000.00
# 323  18­Apr­2021          0    18­Apr­2021    5,000.00         NaN
# 324  18­Apr­2021          0    18­Apr­2021      200.00         NaN
# 325  19­Apr­2021          0    19­Apr­2021         NaN   75,000.00
# 326  19­Apr­2021          0    19­Apr­2021   75,000.00         NaN
# 327  24­Apr­2021          0    24­Apr­2021         NaN    3,000.00
# 328  24­Apr­2021          0    24­Apr­2021      200.00         NaN
# 329  25­Apr­2021  491300...    25­Apr­2021    1,000.00         NaN
# 330  25­Apr­2021          0    25­Apr­2021    1,000.00         NaN
# 331  25­Apr­2021          0    25­Apr­2021         NaN      200.00
# 332  25­Apr­2021          0    25­Apr­2021    1,000.00         NaN
# 333  27­Apr­2021          0    27­Apr­2021         NaN    1,500.00
# 334  27­Apr­2021          0    27­Apr­2021         NaN      400.00
# 335  27­Apr­2021          0    27­Apr­2021      200.00         NaN
# 336  28­Apr­2021          0  28­Apr­2021.1      200.00           0
# 337  28­Apr­2021          0    28­Apr­2021         NaN   20,000.00
# 338  29­Apr­2021          0    30­Apr­2021         NaN   71,353.48
# 339  29­Apr­2021          0    29­Apr­2021      200.00         NaN
# 340  29­Apr­2021          0    30­Apr­2021         NaN  113,932.66
# 341  29­Apr­2021          0    30­Apr­2021         NaN   40,066.78
# 342  30­Apr­2021          0    30­Apr­2021   43,370.58         NaN
# 343  30­Apr­2021          0    30­Apr­2021    5,000.00         NaN
# 344  30­Apr­2021          0    30­Apr­2021      200.00         NaN
# 345  30­Apr­2021          0    30­Apr­2021    2,000.00         NaN
# 346  30­Apr­2021          0    30­Apr­2021    5,000.00         NaN
# 347  30­Apr­2021  411900...    30­Apr­2021   55,283.39         NaN
# 348  30­Apr­2021  412000...    30­Apr­2021    4,953.47         NaN
# 349  30­Apr­2021  412001...    30­Apr­2021   72,818.23         NaN
# 350  01­May­2021          0    01­May­2021   30,000.00         NaN
# 351  01­May­2021          0    01­May­2021      200.00         NaN
# 352  01­May­2021          0    01­May­2021   20,000.00         NaN
# 353  01­May­2021          1    01­May­2021    5,000.00         NaN
# 354  02­May­2021          0    02­May­2021      200.00         NaN
# 355  03­May­2021          0  03­May­2021.1      200.00           0
# 356  03­May­2021          0    03­May­2021         NaN   21,000.00
# 357  03­May­2021          0    03­May­2021   15,000.00         NaN
# 358  03­May­2021          0    03­May­2021    6,000.00         NaN
# 359  04­May­2021          0    04­May­2021         NaN   25,000.00
# 360  04­May­2021          0    04­May­2021   20,000.00         NaN
# 361  04­May­2021          0    04­May­2021    1,000.00         NaN
# 362  05­May­2021          0    05­May­2021    1,500.00         NaN
# 363  06­May­2021          0    06­May­2021    3,000.00         NaN
# 364  06­May­2021          0    06­May­2021      200.00         NaN
# 365  06­May­2021          0    06­May­2021         NaN   45,000.00
# 366  06­May­2021          0    06­May­2021         NaN    5,000.00
# 367  06­May­2021          0    06­May­2021   50,000.00         NaN
# 368  06­May­2021          0    06­May­2021         NaN    2,000.00
# 369  06­May­2021          0    06­May­2021    2,000.00         NaN
# 370  10­May­2021          0    10­May­2021         NaN   15,500.00
# 371  10­May­2021          0  10­May­2021.1   15,000.00           0
# 372  10­May­2021          0    10­May­2021   25,000.00         NaN
# 373  11­May­2021          0    11­May­2021      200.00         NaN
# 374  11­May­2021          0    11­May­2021      200.00         NaN
# 375  11­May­2021          0    11­May­2021    1,000.00         NaN
# 376  12­May­2021          0    12­May­2021    1,500.00         NaN
# 377  12­May­2021          0    12­May­2021         NaN   10,000.00
# 378  12­May­2021          0    12­May­2021    2,650.00         NaN
# 379  12­May­2021          0    12­May­2021      200.00         NaN
# 380  13­May­2021          0    13­May­2021      200.00         NaN
# 381  13­May­2021          0    13­May­2021    6,000.00         NaN
# 382  13­May­2021          0    13­May­2021      200.00         NaN
# 383  14­May­2021          0    14­May­2021    1,000.00         NaN
# 384  15­May­2021          0    15­May­2021      200.00         NaN
# 385  16­May­2021          0    16­May­2021      200.00         NaN
# 386  17­May­2021          0    17­May­2021      200.00         NaN
# 387  18­May­2021          0    18­May­2021         NaN   30,000.00
# 388  18­May­2021          0    18­May­2021   30,000.00         NaN
# 389  18­May­2021          0  18­May­2021.1           0   47,000.00
# 390  18­May­2021          0    18­May­2021   10,000.00         NaN
# 391  19­May­2021          0    19­May­2021    1,500.00         NaN
# 392  19­May­2021          0    19­May­2021         NaN   15,000.00
# 393  19­May­2021          0    19­May­2021    5,000.00         NaN
# 394  19­May­2021          0    19­May­2021   46,000.00         NaN
# 395  19­May­2021          0    19­May­2021         NaN   30,000.00
# 396  19­May­2021          0    19­May­2021   30,000.00         NaN
# 397  20­May­2021          0    20­May­2021      100.00         NaN
# 398  26­May­2021          0    26­May­2021         NaN   50,000.00
# 399          NaN        NaN            NaN         NaN         NaN
# 400  26­May­2021          0    26­May­2021   50,000.00         NaN
# 401  28­May­2021          0    31­May­2021         NaN   40,066.78
# 402  28­May­2021          0    31­May­2021         NaN  113,932.66
# 403  28­May­2021          0    31­May­2021         NaN   71,353.48
# 404  29­May­2021          0    29­May­2021         NaN   27,000.00
# 405  29­May­2021  491600...    29­May­2021   27,000.00         NaN
# 406  31­May­2021          0    31­May­2021   10,000.00         NaN
# 407  31­May­2021          0  31­May­2021.1      200.00           0
# 408  31­May­2021          0    31­May­2021   99,000.00         NaN
# 409  31­May­2021          0    31­May­2021   50,000.00         NaN
# 410  31­May­2021          0    31­May­2021      200.00         NaN
# 411  31­May­2021          0    31­May­2021    2,000.00         NaN
# 412  31­May­2021  411900...    31­May­2021   55,366.53         NaN
# 413  31­May­2021  412000...    31­May­2021    4,943.50         NaN
# 414  31­May­2021  412001...    31­May­2021   72,818.23         NaN
# 415  01­Jun­2021          0    01­Jun­2021      200.00         NaN
# 416  01­Jun­2021          0    01­Jun­2021      200.00         NaN
# 417  01­Jun­2021          1    01­Jun­2021    5,000.00         NaN
# 418  02­Jun­2021          0    02­Jun­2021    1,500.00         NaN
# 419  02­Jun­2021          0    02­Jun­2021    1,025.00         NaN
# 420  02­Jun­2021          0    02­Jun­2021      200.00         NaN
# 421  03­Jun­2021          0    03­Jun­2021    2,000.00         NaN
# 422  03­Jun­2021          0    03­Jun­2021         NaN   43,000.00
# 423  03­Jun­2021          0    03­Jun­2021   43,000.00         NaN
# 424  03­Jun­2021          0    03­Jun­2021      200.00         NaN
# 425  04­Jun­2021          0    04­Jun­2021      200.00         NaN
# 426  05­Jun­2021          0  05­Jun­2021.1    1,000.00           0
# 427  07­Jun­2021          0    07­Jun­2021         100         NaN
#
#               5  \
# 0      3,993.22
# 1      1,993.22
# 2     60,539.71
# 3     19,539.71
# 4     15,539.71
# 5     15,339.71
# 6     14,339.71
# 7     13,339.71
# 8     16,339.71
# 9      6,339.71
# 10     1,339.71
# 11     1,139.71
# 12     1,039.71
# 13       639.71
# 14       439.71
# 15       239.71
# 16        39.71
# 17     2,039.71
# 18     6,039.71
# 19     1,039.71
# 20        39.71
# 21    72,496.81
# 22   186,429.47
# 23   226,496.25
# 24   229,496.25
# 25     4,496.25
# 26   487,496.25
# 27   492,496.25
# 28     2,454.01
# 29   805,028.01
# 30     5,028.01
# 31     4,528.01
# 32     2,528.01
# 33    82,528.01
# 34    21,127.71
# 35    20,957.90
# 36   ­22,412.68
# 37     2,587.32
# 38     2,187.32
# 39       687.32
# 40       187.32
# 41   156,187.32
# 42   131,159.92
# 43    56,159.92
# 44    55,159.92
# 45    54,959.92
# 46    54,459.92
# 47    46,459.92
# 48    16,459.92
# 49    14,959.92
# 50    14,759.92
# 51    14,559.92
# 52     6,559.92
# 53     3,559.92
# 54       159.92
# 55    20,159.92
# 56       159.92
# 57        59.92
# 58     2,059.92
# 59     1,919.92
# 60     1,909.42
# 61     1,409.42
# 62       409.42
# 63       209.42
# 64         9.42
# 65     5,009.42
# 66     4,009.42
# 67   399,009.42
# 68   494,009.42
# 69   474,009.42
# 70   469,509.42
# 71   465,709.42
# 72   472,709.42
# 73   442,709.42
# 74   432,709.42
# 75   431,709.42
# 76   430,709.42
# 77   429,709.42
# 78   429,209.42
# 79   429,009.42
# 80   428,009.42
# 81   427,809.42
# 82   419,809.42
# 83   397,809.42
# 84   382,809.42
# 85   382,309.42
# 86   380,809.42
# 87   377,809.42
# 88   372,809.42
# 89   372,609.42
# 90   369,609.42
# 91   368,609.42
# 92   353,609.42
# 93   343,609.42
# 94   343,409.42
# 95   338,409.42
# 96   343,409.42
# 97   336,409.42
# 98   335,409.42
# 99   330,209.42
# 100  328,209.42
# 101  328,009.42
# 102  327,909.42
# 103  254,909.42
# 104  326,262.90
# 105  440,195.56
# 106  480,262.34
# 107  621,168.58
# 108  620,968.58
# 109  534,968.58
# 110   34,968.58
# 111  234,968.58
# 112  191,598.00
# 113  190,498.00
# 114  189,398.00
# 115  127,398.00
# 116   71,839.64
# 117   66,840.05
# 118   60,840.05
# 119   20,840.05
# 120   19,840.05
# 121   17,740.05
# 122   17,540.05
# 123  ­55,453.60
# 124  ­55,513.29
# 125    1,486.71
# 126   ­2,513.29
# 127   53,486.71
# 128   38,486.71
# 129   33,486.71
# 130   30,486.71
# 131   28,486.71
# 132   20,486.71
# 133   40,486.71
# 134   20,486.71
# 135   15,386.71
# 136   10,386.71
# 137      386.71
# 138      186.71
# 139    2,186.71
# 140    1,986.71
# 141      986.71
# 142      786.71
# 143       86.71
# 144        6.71
# 145   25,006.71
# 146   24,806.71
# 147   24,606.71
# 148   19,606.71
# 149        6.71
# 150  200,006.71
# 151  199,806.71
# 152   69,806.71
# 153   35,806.71
# 154   20,806.71
# 155   25,806.71
# 156   28,806.71
# 157   18,806.71
# 158   18,606.71
# 159   89,960.19
# 160  203,892.85
# 161  243,959.63
# 162  243,759.63
# 163  218,759.63
# 164  218,559.63
# 165  214,859.63
# 166  102,859.63
# 167   47,781.20
# 168           5
# 169  ­30,007.22
# 170   10,042.78
# 171    9,542.78
# 172   69,542.78
# 173   19,542.78
# 174    9,542.78
# 175   34,542.78
# 176   33,542.78
# 177   33,342.78
# 178   13,342.78
# 179   11,842.78
# 180    1,842.78
# 181   51,842.78
# 182   51,862.35
# 183   51,860.39
# 184   51,660.39
# 185   50,660.39
# 186   48,160.39
# 187   45,660.39
# 188   43,560.39
# 189   35,560.39
# 190   15,560.39
# 191   55,560.39
# 192   12,189.81
# 193   11,989.81
# 194    9,989.81
# 195    8,989.81
# 196    8,789.81
# 197    8,589.81
# 198    7,589.81
# 199    2,589.81
# 200   17,589.81
# 201    2,589.81
# 202    2,389.81
# 203    1,889.81
# 204    1,389.81
# 205   21,509.81
# 206   17,509.81
# 207   17,009.81
# 208   12,009.81
# 209   11,709.81
# 210    7,209.81
# 211   20,089.81
# 212   74,589.81
# 213   20,089.81
# 214   19,089.81
# 215   17,589.81
# 216   37,589.81
# 217   37,389.81
# 218   30,389.81
# 219   27,389.81
# 220   22,389.81
# 221   22,389.81
# 222   21,389.81
# 223   11,389.81
# 224   10,389.81
# 225   10,189.81
# 226   11,189.81
# 227   10,189.81
# 228    9,189.81
# 229    8,989.81
# 230   68,989.81
# 231    8,989.81
# 232    8,689.81
# 233    8,489.81
# 234    7,989.81
# 235    3,989.81
# 236    3,789.81
# 237   63,789.81
# 238   69,789.81
# 239    5,289.81
# 240    5,089.81
# 241    4,889.81
# 242    3,389.81
# 243   33,389.81
# 244   33,189.81
# 245    9,689.81
# 246    4,689.81
# 247   24,689.81
# 248   74,689.81
# 249   74,489.81
# 250       89.81
# 251   50,089.81
# 252       89.81
# 253   40,156.59
# 254  154,089.25
# 255  225,442.73
# 256  223,442.73
# 257  278,942.73
# 258  228,942.73
# 259   78,942.73
# 260  228,942.73
# 261   33,942.73
# 262   33,742.73
# 263   43,742.73
# 264  ­12,596.15
# 265  ­17,599.42
# 266  ­90,417.65
# 267  ­90,487.01
# 268  ­11,487.01
# 269    3,512.99
# 270  159,512.99
# 271  134,207.51
# 272   84,207.51
# 273   40,836.93
# 274   35,836.93
# 275   23,336.93
# 276   18,336.93
# 277   54,336.93
# 278   73,336.93
# 279   43,336.93
# 280   21,336.93
# 281   11,336.93
# 282   65,336.93
# 283   25,336.93
# 284   10,336.93
# 285   43,336.93
# 286    3,336.93
# 287      336.93
# 288   35,536.93
# 289   29,279.43
# 290      518.18
# 291      418.18
# 292      218.18
# 293   20,218.18
# 294   33,218.18
# 295   23,218.18
# 296   64,718.18
# 297   64,518.18
# 298   94,518.18
# 299   61,518.18
# 300   51,518.18
# 301   51,318.18
# 302   46,318.18
# 303   70,318.18
# 304   40,318.18
# 305   30,318.18
# 306   25,318.18
# 307   15,318.18
# 308   13,818.18
# 309   13,618.18
# 310    3,618.18
# 311    2,618.18
# 312    2,418.18
# 313    1,418.18
# 314      418.18
# 315    5,418.18
# 316    2,418.18
# 317   27,418.18
# 318    2,418.18
# 319    2,818.18
# 320      358.18
# 321      308.18
# 322    5,308.18
# 323      308.18
# 324      108.18
# 325   75,108.18
# 326      108.18
# 327    3,108.18
# 328    2,908.18
# 329    1,908.18
# 330      908.18
# 331    1,108.18
# 332      108.18
# 333    1,608.18
# 334    2,008.18
# 335    1,808.18
# 336      108.18
# 337   20,108.18
# 338   91,461.66
# 339   91,261.66
# 340  205,194.32
# 341  245,261.10
# 342  201,890.52
# 343  196,890.52
# 344  196,690.52
# 345  194,690.52
# 346  189,690.52
# 347  134,407.13
# 348  129,453.66
# 349   56,635.43
# 350   26,635.43
# 351   26,435.43
# 352    6,435.43
# 353    1,435.43
# 354    1,235.43
# 355      835.43
# 356   21,835.43
# 357    6,835.43
# 358      835.43
# 359   25,835.43
# 360    5,835.43
# 361    4,835.43
# 362    3,335.43
# 363      335.43
# 364      135.43
# 365   45,135.43
# 366   50,135.43
# 367      135.43
# 368    2,135.43
# 369      135.43
# 370   15,635.43
# 371   29,635.43
# 372    4,635.43
# 373    4,435.43
# 374    4,235.43
# 375    3,235.43
# 376    1,735.43
# 377   11,735.43
# 378    9,085.43
# 379    8,885.43
# 380    8,685.43
# 381    2,685.43
# 382    2,485.43
# 383    1,485.43
# 384    1,285.43
# 385    1,085.43
# 386      885.43
# 387   30,885.43
# 388      885.43
# 389   47,685.43
# 390   37,685.43
# 391   36,185.43
# 392   51,185.43
# 393   46,185.43
# 394      185.43
# 395   30,185.43
# 396      185.43
# 397       85.43
# 398   50,085.43
# 399         NaN
# 400       85.43
# 401   40,152.21
# 402  154,084.87
# 403  225,438.35
# 404  252,438.35
# 405  225,438.35
# 406  215,438.35
# 407  296,238.35
# 408  197,238.35
# 409  147,238.35
# 410  147,038.35
# 411  145,038.35
# 412   89,671.82
# 413   84,728.32
# 414   11,910.09
# 415   11,710.09
# 416   11,510.09
# 417    6,510.09
# 418    5,010.09
# 419    3,985.09
# 420    3,785.09
# 421    1,785.09
# 422   44,785.09
# 423    1,785.09
# 424    1,585.09
# 425    1,385.09
# 426      185.09
# 427       85.09
#
#                                                                                                                                                                                                                    6
# 0                                                                                                                                                                 OWN ACCOUNT TRANSFER\rREF:205154861000000200002...
# 1                                                                          TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612320696...\rfrom ADEOSUN KEHINDE WAKIL\rto ODELE,ABIODUN RAYMOND
# 2                                                                                                                                                                                       MTHLY SALARY 13th Month 2020
# 3                                                                         TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548613710356...\rfrom ADEOSUN KEHINDE WAKIL\rto ADEOSUN, ABDULSEMIU G.
# 4                                                        NIBSS Instant Payment Outward\r0000132012011932440002717...\rUSSD NIP Transfer from\r08033725563 TO\rZBN/TEMITAYO ALIU AIBINU\rREF:000013201201193244000...
# 5                                                                                                                                                   Airtime Purchase USSD­\r101CT0000000002185428097­\r2348033725563
# 6                                                                                                                                                   Airtime Purchase USSD­\r101CT0000000002185430572­\r2348031164646
# 7                                                                                                                                                   Airtime Purchase USSD­\r101CT0000000002185792084­\r2348180043134
# 8                                                                                                                                                                 OWN ACCOUNT TRANSFER\rREF:205154861000000030002...
# 9                                                                                                                                                    STANDING ORDER Standing\rOrder via Internet Banking food\rstuff
# 10                                                                                                                                             STANDING ORDER Standing\rOrder via Internet Banking For\rMy Sweet Mum
# 11                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002188404710­\r2348034395533
# 12                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002188409588­\r2348127107811
# 13                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002192004930­\r2348033725563
# 14                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002196087600­\r2348033725563
# 15                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002198016341­\r2348033725563
# 16                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002212734957­\r2348033725563
# 17                                             TRANSFER BETWEEN\rCUSTOMERS\r0000142012122359312285307...\rADEOSUN MONSURAT\rOLARANTI TO\rADEOSUN|VNM812041183150...\rMONSURAT OLARANTI\rREF:000014201212235931228...
# 18                                                                                                                                                                    OWN ACCOUNT TRANSFER trf\rvia Internet Banking
# 19                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548613710356...\rfrom ADEOSUN KEHINDE WAKIL\rto ADEOSUN, ABDULSEMIU G.
# 20                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002224342762­\r2349090373699
# 21                                                                                                                                                                                   MTHLY SALARY December 2020\rSal
# 22                                                                                                                                                                                         MISC. December 2020 Allow
# 23                                                                                                                                                                      MEDICAL BILL/REFUND\rMedrefund December 2020
# 24                                                                      TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000023404955322050154...\rfrom AGBOOLA, ALIRAT\rOLAKEMI to ADEOSUN KEHINDE\rWAKIL
# 25                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000002250002...
# 26                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000004830002...
# 27                                                                              TRANSFER BETWEEN\rCUSTOMERS Via GTWorld Trfs\rREF:205153162000000050002...\rfrom OLADEJI, SAHEED\rADEKUNLE to ADEOSUN\rKEHINDE WAKIL
# 28                                                                                                                                                                                              PREMATURE SETTLEMENT
# 29                                                                                                                                                                                                 LOAN DISBURSEMENT
# 30                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000008000002...
# 31                                                                      TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612050153...\rfrom ADEOSUN KEHINDE WAKIL\rto OLADEJI, SAHEED ADEKUNLE
# 32                                                                       TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614920470...\rfrom ADEOSUN KEHINDE WAKIL\rto YUSUF , NAFISAT OPEYEMI
# 33                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000000800002...
# 34                                                                                                                                                                                          MATURED LOAN INSTALLMENT
# 35                                                                                                                                                                                              INTEREST CAPITALISED
# 36                   REMITA PAYMENT R­\r444669036/LIBER:Loan\rrepayment Loan repayment\rDD:3304343 84446690366 from\rADEOSUN KEHINDE WAKIL To\rGENERAL REF:\r0000016304107184446690366\rREF:205015486100043370582...
# 37                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000000250002...
# 38                                                                                                                                               Airtime Purchase GTWORLD­\r101CT0000000002262779776­\r2349034765471
# 39                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002259503318­\r2349090373699
# 40                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002264277713­\r2348030460489
# 41                                                                                                                                                              OTHER TRANSACTION 2020\rQuarterly Deferred Incentive
# 42                                                                                                                                                    OTHER TRANSACTION GSAC\rPremium (Jan 5, 2021 ­ April 4,\r2021)
# 43                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614910462...\rfrom ADEOSUN KEHINDE WAKIL\rto ADEDEJI OMOTAYO GANIYU
# ...
# 354                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002559111735­\r2348033725563
# 355                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002561393688­\r2348033725563
# 356                                                                          TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rCollect it\rREF:481454704000000210002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 357                                                                                           Biometric ATM Withdrawal ATM\rFingerprint Cash for ADEOSUN\rKEHINDE WAKIL_\r8175_1948098\rREF:020515486100000150000...
# 358                                                                                           Biometric ATM Withdrawal ATM\rFingerprint Cash for ADEOSUN\rKEHINDE WAKIL_\r3043_1948142\rREF:020515486100000060000...
# 359                                                                              TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rThanks\rREF:481454704000000250002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 360                                                                                                                                                               OWN ACCOUNT TRANSFER\rREF:205154861000000200002...
# 361                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614810454...\rfrom ADEOSUN KEHINDE WAKIL\rto JIMOH, SHADE SHAKIRAT
# 362                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002566080309­\r2349090373699
# 363                                                                                                                                                               OWN ACCOUNT TRANSFER\rREF:205154861000000030002...
# 364                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002569273316­\r2348033725563
# 365                                                                              TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rThanks\rREF:481454704000000450002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 366                                                                                                                                                               OWN ACCOUNT TRANSFER\rREF:205154861000000050002...
# 367                                                                    TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612280679...\rfrom ADEOSUN KEHINDE WAKIL\rto OYEKUNLE KEHINDE\rADEJOKE
# 368                                                                                  TRANSFER BETWEEN\rCUSTOMERS Via GTWorld Add\rREF:481454704000000020002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 369                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614810454...\rfrom ADEOSUN KEHINDE WAKIL\rto JIMOH, SHADE SHAKIRAT
# 370                                     TRANSFER BETWEEN\rCUSTOMERS\r0000082105101639505907296...\rTo: ADEOSUN KEHINDE\rWAKIL:GTBank :\rD212667D924B435FA107412A...\rOLAJEMIYO ADEOSUN\rREF:000008210510163950590...
# 371                                                                                      GTRescue Cashout GTRescue\rcashout for 08033725563 from\rADEOSUN KEHINDE WAKIL_\r5644_2114371\rREF:020515486100000150000...
# 372                                                                                           Biometric ATM Withdrawal ATM\rFingerprint Cash for ADEOSUN\rKEHINDE WAKIL_\r8142_2114828\rREF:020515486100000250000...
# 373                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002581977897­\r2348033725563
# 374                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002581985870­\r2348033725563
# 375                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002582988307­\r2348187682149
# 376                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002583988630­\r2349090373699
# 377                                                                                      TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rREF:481454704000000100002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 378                                                                      TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614920441...\rfrom ADEOSUN KEHINDE WAKIL\rto OYEBODE OYEPEJU GANIYAT
# 379                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002586146283­\r2348033725563
# 380                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002587379676­\r2348033725563
# 381                                                            NIBSS Instant Payment Outward\r0000132105131449490001313...\rUSSD NIP Transfer from\r08033725563 TO ARIKE TAIBAT\rJIMOH\rREF:000013210513144949000...
# 382                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002588460673­\r2348033725563
# 383                                                                                           Biometric ATM Withdrawal ATM\rFingerprint Cash for ADEOSUN\rKEHINDE WAKIL_\r9048_2216845\rREF:020515486100000010000...
# 384                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002592570118­\r2348033725563
# 385                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002593930515­\r2348033725563
# 386                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002595600236­\r2348033725563
# 387                                                                   TRANSFER BETWEEN\rCUSTOMERS\r1100072105181415165554658...\rPOS\rAgent|DEP|2MPT1z7c|1394642...\rAgent AZ Ventures\rREF:110007210518141516555...
# 388                                            NIBSS Instant Payment Outward\r0000132105181440290001379...\rvia GTWORLD Adeosun Wasiu\rOlajemiyo TO LETSHEGO\rMICROFINANCE BANK LIMITED\rREF:GW205154861000000300...
# 389                                                                                   TRANSFER BETWEEN\rCUSTOMERS Via GTWorld Re\rREF:481454704000000470002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 390                                                                                   FASTTRACK CASH\rWITHDRAWAL PINPAD­\r80974523­491/1564 CASH\rWITHDRAWAL BY ADEOSUN\rKEHINDE WAKIL\r0006375695084901239313380...
# 391                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002600613300­\r2349090373699
# 392                                                                   TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000049105478352050154...\rfrom BULIAMINU, ABDULLAHI\rFEMI to ADEOSUN KEHINDE\rWAKIL
# 393                                                                         TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612480305...\rfrom ADEOSUN KEHINDE WAKIL\rto AINA, BABAJIDE DAVID
# 394                                                                                                                                                               OWN ACCOUNT TRANSFER\rREF:205154861000000460002...
# 395                                                                                   TRANSFER BETWEEN\rCUSTOMERS Via GTWorld Ok\rREF:481454704000000300002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 396                                                                                   FASTTRACK CASH\rWITHDRAWAL PINPAD­\r80991622­491/1564 CASH\rWITHDRAWAL BY ADEOSUN\rKEHINDE WAKIL\r0006375703345975884483380...
# 397                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002604135151­\r2348033725563
# 398                                                                              TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rThanks\rREF:481454704000000500002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 399                                                                                                                                                                                                   FASTTRACK CASH
# 400                                                                                                                       81094178­491/1564 CASH\rWITHDRAWAL BY ADEOSUN\rKEHINDE WAKIL\r0006375764115666410053380...
# 401                                                                                                                                                                          MEDICAL BILL/REFUND\rMedrefund May 2021
# 402                                                                                                                                                                                             MISC. May 2021 Allow
# 403                                                                                                                                                                                        MTHLY SALARY May 2021 Sal
# 404                                                                         TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000024302265352050154...\rfrom FALOLA ISAAC OLUFEMI to\rADEOSUN KEHINDE WAKIL
# 405                                                                                                                               CASH WITHDRAWAL FROM OUR\rATM ­008394­ ­360416­GTBank\r3, Lagere Road Ile­Ife OSNG
# 406                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614810454...\rfrom ADEOSUN KEHINDE WAKIL\rto JIMOH, SHADE SHAKIRAT
# 407                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002630330396­\r2348033725563
# 408                                                                                      TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rREF:205154861000000990002...\rfrom ADEOSUN KEHINDE WAKIL\rto ODELE,ABIODUN RAYMOND
# 409                                                                     TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612050153...\rfrom ADEOSUN KEHINDE WAKIL\rto OLADEJI, SAHEED ADEKUNLE
# 410                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002631673142­\r2348033725563
# 411                                                                     TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614910495...\rfrom ADEOSUN KEHINDE WAKIL\rto ABIYEYE, OLUWATOMISIN O.
# 412                                                                                                                                                                                         MATURED LOAN INSTALLMENT
# 413                                                                                                                                                                                         MATURED LOAN INSTALLMENT
# 414                                                                                                                                                                                         MATURED LOAN INSTALLMENT
# 415                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002633441152­\r2348113897792
# 416                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002635178608­\r2348033725563
# 417                                                                                                                                            STANDING ORDER Standing\rOrder via Internet Banking For\rmy sweet mum
# 418                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002635972771­\r2349090373699
# 419                                                                                   TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rREF:205154861000000010252...\rfrom ADEOSUN KEHINDE WAKIL\rto OLADEJI, SAHEED ADEKUNLE
# 420                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002637741277­\r2348033725563
# 421                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614910542...\rfrom ADEOSUN KEHINDE WAKIL\rto ADEOSUN, OMOBOLAJI O.
# 422                                                                                    TRANSFER BETWEEN\rCUSTOMERS Via GTWorld K\rREF:481454704000000430002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 423                                                                                   FASTTRACK CASH\rWITHDRAWAL PINPAD­\r81238406­491/1564 CASH\rWITHDRAWAL BY ADEOSUN\rKEHINDE WAKIL\r0006375833362441499213380...
# 424                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002640604089­\r2348033725563
# 425                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002641830288­\r2349034765471
# 426                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002645228359­\r2348187682149
# 427                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002650673299­\r2348033725563

# %%
customer2.combined
# Out:
#                0          1              2           3           4  \
# 0    01­Dec­2020          0  01­Dec­2020.1   20,000.00           0
# 1    01­Dec­2020          0    01­Dec­2020    2,000.00         NaN
# 2    01­Dec­2020          0    01­Dec­2020         NaN   58,546.49
# 3    01­Dec­2020          0    01­Dec­2020   41,000.00         NaN
# 4    01­Dec­2020          0    01­Dec­2020    4,000.00         NaN
# 5    01­Dec­2020          0    01­Dec­2020      200.00         NaN
# 6    01­Dec­2020          0    01­Dec­2020    1,000.00         NaN
# 7    01­Dec­2020          0    01­Dec­2020    1,000.00         NaN
# 8    01­Dec­2020          0    01­Dec­2020         NaN    3,000.00
# 9    01­Dec­2020          4    01­Dec­2020   10,000.00         NaN
# 10   01­Dec­2020          5    01­Dec­2020    5,000.00         NaN
# 11   02­Dec­2020          0    02­Dec­2020      200.00         NaN
# 12   02­Dec­2020          0    02­Dec­2020      100.00         NaN
# 13   04­Dec­2020          0  04­Dec­2020.1      200.00           0
# 14   05­Dec­2020          0    05­Dec­2020      200.00         NaN
# 15   06­Dec­2020          0    06­Dec­2020      200.00         NaN
# 16   12­Dec­2020          0    12­Dec­2020      200.00         NaN
# 17   13­Dec­2020          0    12­Dec­2020         NaN    2,000.00
# 18   17­Dec­2020          0    17­Dec­2020         NaN    4,000.00
# 19   17­Dec­2020          0    17­Dec­2020    5,000.00         NaN
# 20   17­Dec­2020          0    17­Dec­2020    1,000.00         NaN
# 21   30­Dec­2020          0    31­Dec­2020         NaN   72,457.10
# 22   30­Dec­2020          0    31­Dec­2020         NaN  113,932.66
# 23   30­Dec­2020          0    31­Dec­2020         NaN   40,066.78
# 24   30­Dec­2020          0    30­Dec­2020         NaN    3,000.00
# 25   31­Dec­2020          0    30­Dec­2020  225,000.00         NaN
# 26   31­Dec­2020          0    31­Dec­2020         NaN  483,000.00
# 27   31­Dec­2020          0    31­Dec­2020         NaN    5,000.00
# 28   31­Dec­2020  412000...    31­Dec­2020  490,042.24         NaN
# 29   31­Dec­2020  412001...    31­Dec­2020         NaN  802,574.00
# 30   31­Dec­2020          0    31­Dec­2020  800,000.00         NaN
# 31   31­Dec­2020          0    31­Dec­2020      500.00         NaN
# 32   31­Dec­2020          0    31­Dec­2020    2,000.00         NaN
# 33   31­Dec­2020          0    31­Dec­2020         NaN   80,000.00
# 34   31­Dec­2020  412000...  31­Dec­2020.1    5,042.08           0
# 35   31­Dec­2020          0    31­Dec­2020      169.81         NaN
# 36   01­Jan­2021          0    31­Dec­2020   43,370.58         NaN
# 37   01­Jan­2021          0    01­Jan­2021         NaN   25,000.00
# 38   01­Jan­2021          0    01­Jan­2021      400.00         NaN
# 39   01­Jan­2021          0    01­Jan­2021    1,500.00         NaN
# 40   01­Jan­2021          0    01­Jan­2021      500.00         NaN
# 41   05­Jan­2021          0    05­Jan­2021         NaN  156,000.00
# 42   05­Jan­2021          0    05­Jan­2021   25,027.40         NaN
# 43   05­Jan­2021          0    05­Jan­2021   75,000.00         NaN
# 44   05­Jan­2021          0    05­Jan­2021    1,000.00         NaN
# 45   06­Jan­2021          0    06­Jan­2021      200.00         NaN
# 46   06­Jan­2021          0    06­Jan­2021      500.00         NaN
# 47   06­Jan­2021          0    06­Jan­2021    8,000.00         NaN
# 48   06­Jan­2021          0    06­Jan­2021   30,000.00         NaN
# 49   07­Jan­2021          0    07­Jan­2021    1,500.00         NaN
# 50   07­Jan­2021          0    07­Jan­2021      200.00         NaN
# 51   08­Jan­2021          0    08­Jan­2021      200.00         NaN
# 52   08­Jan­2021          0  08­Jan­2021.1    3,000.00           0
# 53   08­Jan­2021          0    08­Jan­2021    3,000.00         NaN
# 54   09­Jan­2021          0    09­Jan­2021    3,400.00         NaN
# 55   10­Jan­2021          0    10­Jan­2021         NaN   20,000.00
# 56   10­Jan­2021          0    10­Jan­2021   20,000.00         NaN
# 57   13­Jan­2021          0    13­Jan­2021      100.00         NaN
# 58   14­Jan­2021          0    14­Jan­2021         NaN    2,000.00
# 59   14­Jan­2021          0    14­Jan­2021      140.00         NaN
# 60   14­Jan­2021          0    14­Jan­2021       10.50         NaN
# 61   14­Jan­2021          0    14­Jan­2021      500.00         NaN
# 62   14­Jan­2021          0    14­Jan­2021    1,000.00         NaN
# 63   14­Jan­2021          0    14­Jan­2021      200.00         NaN
# 64   14­Jan­2021          0    14­Jan­2021      200.00         NaN
# 65   19­Jan­2021          0    19­Jan­2021         NaN    5,000.00
# 66   20­Jan­2021          0    20­Jan­2021    1,000.00         NaN
# 67   20­Jan­2021          0    20­Jan­2021         NaN  395,000.00
# 68   20­Jan­2021          0  20­Jan­2021.1           0  100,000.00
# 69   20­Jan­2021          0    20­Jan­2021   20,000.00         NaN
# 70   20­Jan­2021          0    20­Jan­2021    4,500.00         NaN
# 71   20­Jan­2021          0    20­Jan­2021    3,800.00         NaN
# 72   20­Jan­2021          0    20­Jan­2021         NaN    7,000.00
# 73   20­Jan­2021          0    20­Jan­2021   30,000.00         NaN
# 74   21­Jan­2021          0    21­Jan­2021   10,000.00         NaN
# 75   21­Jan­2021          0    21­Jan­2021    1,000.00         NaN
# 76   21­Jan­2021          0    21­Jan­2021    1,000.00         NaN
# 77   21­Jan­2021          0    21­Jan­2021    1,000.00         NaN
# 78   21­Jan­2021          0    21­Jan­2021      500.00         NaN
# 79   21­Jan­2021          0    21­Jan­2021      200.00         NaN
# 80   22­Jan­2021  491600...    22­Jan­2021    1,000.00         NaN
# 81   22­Jan­2021          0    22­Jan­2021      200.00         NaN
# 82   22­Jan­2021          0    22­Jan­2021    8,000.00         NaN
# 83   22­Jan­2021          0    22­Jan­2021   22,000.00         NaN
# 84   23­Jan­2021          0  23­Jan­2021.1   10,000.00           0
# 85   23­Jan­2021          0    23­Jan­2021      500.00         NaN
# 86   24­Jan­2021          0    24­Jan­2021    1,500.00         NaN
# 87   24­Jan­2021          0    24­Jan­2021    3,000.00         NaN
# 88   24­Jan­2021          0    24­Jan­2021    5,000.00         NaN
# 89   25­Jan­2021          0    25­Jan­2021      200.00         NaN
# 90   25­Jan­2021          0    25­Jan­2021    3,000.00         NaN
# 91   25­Jan­2021  491200...    25­Jan­2021    1,000.00         NaN
# 92   25­Jan­2021          0    25­Jan­2021   15,000.00         NaN
# 93   26­Jan­2021          0    26­Jan­2021   10,000.00         NaN
# 94   26­Jan­2021          0    26­Jan­2021      200.00         NaN
# 95   27­Jan­2021          0    27­Jan­2021    5,000.00         NaN
# 96   27­Jan­2021          0    27­Jan­2021         NaN    5,000.00
# 97   27­Jan­2021          0    27­Jan­2021    7,000.00         NaN
# 98   28­Jan­2021          0    28­Jan­2021    1,000.00         NaN
# 99   28­Jan­2021          0  28­Jan­2021.1      200.00           0
# 100  28­Jan­2021          0    28­Jan­2021    2,000.00         NaN
# 101  28­Jan­2021          0    28­Jan­2021      200.00         NaN
# 102  28­Jan­2021          0    28­Jan­2021      100.00         NaN
# 103  28­Jan­2021          0    28­Jan­2021   73,000.00         NaN
# 104  28­Jan­2021          0    29­Jan­2021         NaN   71,353.48
# 105  28­Jan­2021          0    29­Jan­2021         NaN  113,932.66
# 106  28­Jan­2021          0    29­Jan­2021         NaN   40,066.78
# 107  28­Jan­2021          0    28­Jan­2021         NaN  140,906.24
# 108  29­Jan­2021          0    29­Jan­2021      200.00         NaN
# 109  29­Jan­2021          0    29­Jan­2021   86,000.00         NaN
# 110  29­Jan­2021          0    29­Jan­2021  500,000.00         NaN
# 111  29­Jan­2021          0    29­Jan­2021         NaN  200,000.00
# 112  29­Jan­2021          0    29­Jan­2021   43,370.58         NaN
# 113  29­Jan­2021          0    29­Jan­2021    1,100.00         NaN
# 114  29­Jan­2021          0    29­Jan­2021    1,100.00         NaN
# 115  29­Jan­2021          0    29­Jan­2021   62,000.00         NaN
# 116  29­Jan­2021  411900...    29­Jan­2021   55,558.36         NaN
# 117  29­Jan­2021  412000...    29­Jan­2021    4,999.59         NaN
# 118  30­Jan­2021          0  30­Jan­2021.1    1,000.00           0
# 119  31­Jan­2021          0    31­Jan­2021   40,000.00         NaN
# 120  31­Jan­2021          0    31­Jan­2021    1,000.00         NaN
# 121  31­Jan­2021          0    31­Jan­2021    2,100.00         NaN
# 122  31­Jan­2021          0    31­Jan­2021      200.00         NaN
# 123  31­Jan­2021  412001...    31­Jan­2021   72,993.65         NaN
# 124  31­Jan­2021          0    31­Jan­2021       59.69         NaN
# 125  01­Feb­2021          0    01­Feb­2021         NaN   57,000.00
# 126  01­Feb­2021  491600...    01­Feb­2021    4,000.00         NaN
# 127  01­Feb­2021          0    31­Jan­2021         NaN   56,000.00
# 128  02­Feb­2021          0    02­Feb­2021   15,000.00         NaN
# 129  02­Feb­2021          0    02­Feb­2021    5,000.00         NaN
# 130  02­Feb­2021          0    02­Feb­2021    3,000.00         NaN
# 131  02­Feb­2021          0    02­Feb­2021    2,000.00         NaN
# 132  02­Feb­2021  491600...    02­Feb­2021    8,000.00         NaN
# 133  02­Feb­2021          0    02­Feb­2021         NaN   20,000.00
# 134  02­Feb­2021          0    02­Feb­2021   20,000.00         NaN
# 135  03­Feb­2021          0  03­Feb­2021.1    5,000.00           0
# 136  03­Feb­2021          0    03­Feb­2021    5,000.00         NaN
# 137  03­Feb­2021          0    03­Feb­2021   10,000.00         NaN
# 138  05­Feb­2021          0    05­Feb­2021      200.00         NaN
# 139  09­Feb­2021          0    09­Feb­2021         NaN    2,000.00
# 140  09­Feb­2021          0    09­Feb­2021      200.00         NaN
# 141  09­Feb­2021          0    09­Feb­2021    1,000.00         NaN
# 142  10­Feb­2021          0    10­Feb­2021      200.00         NaN
# 143  11­Feb­2021          0    11­Feb­2021      700.00         NaN
# 144  11­Feb­2021          0    11­Feb­2021       80.00         NaN
# 145  16­Feb­2021          0    16­Feb­2021         NaN   25,000.00
# 146  16­Feb­2021          0    16­Feb­2021      200.00         NaN
# 147  16­Feb­2021          0    16­Feb­2021      200.00         NaN
# 148  16­Feb­2021          0    16­Feb­2021    5,000.00         NaN
# 149  17­Feb­2021          0    17­Feb­2021   19,600.00         NaN
# 150  23­Feb­2021          0    23­Feb­2021         NaN  200,000.00
# 151  24­Feb­2021          0    24­Feb­2021      200.00         NaN
# 152  24­Feb­2021          0  24­Feb­2021.1  100,000.00           0
# 153  24­Feb­2021          0    24­Feb­2021   34,000.00         NaN
# 154  24­Feb­2021          0    24­Feb­2021   15,000.00         NaN
# 155  25­Feb­2021          0    25­Feb­2021         NaN    5,000.00
# 156  25­Feb­2021          0    25­Feb­2021         NaN    3,000.00
# 157  25­Feb­2021          0    25­Feb­2021   10,000.00         NaN
# 158  25­Feb­2021          0    25­Feb­2021      200.00         NaN
# 159  25­Feb­2021          0    26­Feb­2021         NaN   71,353.48
# 160  25­Feb­2021          0    26­Feb­2021         NaN  113,932.66
# 161  25­Feb­2021          0    26­Feb­2021         NaN   40,066.78
# 162  26­Feb­2021          0    26­Feb­2021      200.00         NaN
# 163  26­Feb­2021          0    26­Feb­2021   25,000.00         NaN
# 164  26­Feb­2021          0    26­Feb­2021      200.00         NaN
# 165  26­Feb­2021          0    26­Feb­2021    3,700.00         NaN
# 166  26­Feb­2021          0    26­Feb­2021  112,000.00         NaN
# 167  26­Feb­2021  411900...    26­Feb­2021   55,078.43         NaN
# 168            0          1              2           3           4
# 169  26­Feb­2021  412001...    26­Feb­2021   72,818.23         NaN
# 170  27­Feb­2021          0    27­Feb­2021         NaN   40,050.00
# 171  27­Feb­2021          0    27­Feb­2021      500.00         NaN
# 172  27­Feb­2021          0    27­Feb­2021         NaN   60,000.00
# 173  27­Feb­2021          0    27­Feb­2021   50,000.00         NaN
# 174  27­Feb­2021          0    27­Feb­2021   10,000.00         NaN
# 175  27­Feb­2021          0    27­Feb­2021         NaN   25,000.00
# 176  27­Feb­2021  491600...    27­Feb­2021    1,000.00         NaN
# 177  28­Feb­2021          0    28­Feb­2021      200.00         NaN
# 178  28­Feb­2021  491600...    28­Feb­2021   20,000.00         NaN
# 179  28­Feb­2021          0    28­Feb­2021    1,500.00         NaN
# 180  28­Feb­2021          0    28­Feb­2021   10,000.00         NaN
# 181  28­Feb­2021          0    28­Feb­2021         NaN   50,000.00
# 182  28­Feb­2021          0    28­Feb­2021         NaN       19.57
# 183  28­Feb­2021          0    28­Feb­2021        1.96         NaN
# 184  01­Mar­2021          0    01­Mar­2021      200.00         NaN
# 185  01­Mar­2021          0    01­Mar­2021    1,000.00         NaN
# 186  01­Mar­2021          0    01­Mar­2021    2,500.00         NaN
# 187  01­Mar­2021          0    01­Mar­2021    2,500.00         NaN
# 188  01­Mar­2021          0    01­Mar­2021    2,100.00         NaN
# 189  02­Mar­2021          0  02­Mar­2021.1    3,000.00           0
# 190  02­Mar­2021          0    02­Mar­2021   20,000.00         NaN
# 191  02­Mar­2021          0    02­Mar­2021         NaN   40,000.00
# 192  02­Mar­2021          0    02­Mar­2021   43,370.58         NaN
# 193  02­Mar­2021          0    02­Mar­2021      200.00         NaN
# 194  03­Mar­2021          0    03­Mar­2021    2,000.00         NaN
# 195  03­Mar­2021          0    03­Mar­2021    1,000.00         NaN
# 196  03­Mar­2021          0    03­Mar­2021      200.00         NaN
# 197  03­Mar­2021          0    03­Mar­2021      200.00         NaN
# 198  03­Mar­2021          0    03­Mar­2021    1,000.00         NaN
# 199  04­Mar­2021          0    04­Mar­2021    5,000.00         NaN
# 200  04­Mar­2021          0    04­Mar­2021         NaN   15,000.00
# 201  04­Mar­2021          0    04­Mar­2021   15,000.00         NaN
# 202  06­Mar­2021          0    06­Mar­2021      200.00         NaN
# 203  07­Mar­2021          0    07­Mar­2021      500.00         NaN
# 204  07­Mar­2021          0    07­Mar­2021      500.00         NaN
# 205  08­Mar­2021          0    08­Mar­2021         NaN   20,120.00
# 206  09­Mar­2021          0  09­Mar­2021.1    1,000.00           0
# 207  09­Mar­2021          0    09­Mar­2021      500.00         NaN
# 208  09­Mar­2021          0    09­Mar­2021    5,000.00         NaN
# 209  09­Mar­2021          0    09­Mar­2021      300.00         NaN
# 210  10­Mar­2021          0    10­Mar­2021    4,500.00         NaN
# 211  10­Mar­2021          0    10­Mar­2021         NaN   12,880.00
# 212  10­Mar­2021          0    10­Mar­2021         NaN   54,500.00
# 213  10­Mar­2021          0    10­Mar­2021   54,500.00         NaN
# 214  10­Mar­2021          0    10­Mar­2021    1,000.00         NaN
# 215  11­Mar­2021          0    11­Mar­2021    1,500.00         NaN
# 216  11­Mar­2021          0    11­Mar­2021         NaN   20,000.00
# 217  11­Mar­2021          0    11­Mar­2021      200.00         NaN
# 218  11­Mar­2021          0    11­Mar­2021    7,000.00         NaN
# 219  11­Mar­2021          0    11­Mar­2021    3,000.00         NaN
# 220  11­Mar­2021          0    11­Mar­2021    5,000.00         NaN
# 221  12­Mar­2021          0  12­Mar­2021.1           0    2,000.00
# 222  12­Mar­2021          0    12­Mar­2021    1,000.00         NaN
# 223  13­Mar­2021          0    13­Mar­2021   10,000.00         NaN
# 224  13­Mar­2021          0    13­Mar­2021    1,000.00         NaN
# 225  14­Mar­2021          0    14­Mar­2021      200.00         NaN
# 226  14­Mar­2021          0    14­Mar­2021         NaN    1,000.00
# 227  14­Mar­2021          0    14­Mar­2021    1,000.00         NaN
# 228  14­Mar­2021          0    14­Mar­2021    1,000.00         NaN
# 229  15­Mar­2021          0    15­Mar­2021      200.00         NaN
# 230  15­Mar­2021          0    15­Mar­2021         NaN   60,000.00
# 231  15­Mar­2021          0    15­Mar­2021   60,000.00         NaN
# 232  15­Mar­2021          0    15­Mar­2021      300.00         NaN
# 233  15­Mar­2021          0    15­Mar­2021      200.00         NaN
# 234  16­Mar­2021          0    16­Mar­2021      500.00         NaN
# 235  16­Mar­2021          0    16­Mar­2021    4,000.00         NaN
# 236  16­Mar­2021          0    16­Mar­2021      200.00         NaN
# 237  16­Mar­2021          0    16­Mar­2021         NaN   60,000.00
# 238  16­Mar­2021          0  16­Mar­2021.1           0    8,000.00
# 239  16­Mar­2021          0    16­Mar­2021   64,500.00         NaN
# 240  16­Mar­2021          0    16­Mar­2021      200.00         NaN
# 241  16­Mar­2021          0    16­Mar­2021      200.00         NaN
# 242  17­Mar­2021          0    17­Mar­2021    1,500.00         NaN
# 243  17­Mar­2021          0    17­Mar­2021         NaN   30,000.00
# 244  18­Mar­2021          0    18­Mar­2021      200.00         NaN
# 245  18­Mar­2021          0    18­Mar­2021   23,500.00         NaN
# 246  18­Mar­2021          0    18­Mar­2021    5,000.00         NaN
# 247  18­Mar­2021          0    18­Mar­2021         NaN   20,000.00
# 248  19­Mar­2021          0    19­Mar­2021         NaN   50,000.00
# 249  19­Mar­2021          0    19­Mar­2021      200.00         NaN
# 250  19­Mar­2021          0    19­Mar­2021   74,400.00         NaN
# 251  22­Mar­2021          0    22­Mar­2021         NaN   50,000.00
# 252  22­Mar­2021          0    22­Mar­2021   50,000.00         NaN
# 253  30­Mar­2021          0    31­Mar­2021         NaN   40,066.78
# 254  30­Mar­2021          0    31­Mar­2021         NaN  113,932.66
# 255  30­Mar­2021          0    31­Mar­2021         NaN   71,353.48
# 256  31­Mar­2021          0    31­Mar­2021    2,000.00         NaN
# 257  31­Mar­2021          0  31­Mar­2021.1    1,500.00           0
# 258  31­Mar­2021          0    31­Mar­2021   50,000.00         NaN
# 259  31­Mar­2021          0    31­Mar­2021  150,000.00         NaN
# 260  31­Mar­2021          0    31­Mar­2021         NaN  150,000.00
# 261  31­Mar­2021          0    31­Mar­2021  195,000.00         NaN
# 262  31­Mar­2021          0    31­Mar­2021      200.00         NaN
# 263  31­Mar­2021          0    31­Mar­2021         NaN   10,000.00
# 264  31­Mar­2021  411900...    31­Mar­2021   56,338.88         NaN
# 265  31­Mar­2021  412000...    31­Mar­2021    5,003.27         NaN
# 266  31­Mar­2021  412001...    31­Mar­2021   72,818.23         NaN
# 267  31­Mar­2021          0    31­Mar­2021       69.36         NaN
# 268  01­Apr­2021          0    01­Apr­2021         NaN   79,000.00
# 269  01­Apr­2021          0    01­Apr­2021         NaN   15,000.00
# 270  01­Apr­2021          0    01­Apr­2021         NaN  156,000.00
# 271  01­Apr­2021          0    01­Apr­2021   25,305.48         NaN
# 272  01­Apr­2021          0    01­Apr­2021   50,000.00         NaN
# 273  01­Apr­2021          0    01­Apr­2021   43,370.58         NaN
# 274  01­Apr­2021          0    01­Apr­2021    5,000.00         NaN
# 275  01­Apr­2021      13622  01­Apr­2021.1    7,500.00           0
# 276  01­Apr­2021          1    01­Apr­2021    5,000.00         NaN
# 277  02­Apr­2021          0    02­Apr­2021         NaN   36,000.00
# 278  02­Apr­2021          0    02­Apr­2021         NaN   19,000.00
# 279  02­Apr­2021  491500...    02­Apr­2021   30,000.00         NaN
# 280  02­Apr­2021  491500...    02­Apr­2021   22,000.00         NaN
# 281  02­Apr­2021          0    02­Apr­2021   10,000.00         NaN
# 282  02­Apr­2021          0    02­Apr­2021         NaN   54,000.00
# 283  02­Apr­2021  491600...    02­Apr­2021   40,000.00         NaN
# 284  02­Apr­2021          0    02­Apr­2021   15,000.00         NaN
# 285  04­Apr­2021          0    04­Apr­2021         NaN   33,000.00
# 286  04­Apr­2021  491600...    04­Apr­2021   40,000.00         NaN
# 287  04­Apr­2021  491600...    04­Apr­2021    3,000.00         NaN
# 288  06­Apr­2021          0    06­Apr­2021         NaN   35,200.00
# 289  06­Apr­2021          0    06­Apr­2021    6,257.50         NaN
# 290  06­Apr­2021          0  06­Apr­2021.1   28,661.25           0
# 291  06­Apr­2021          0    06­Apr­2021      100.00         NaN
# 292  07­Apr­2021          0    07­Apr­2021      200.00         NaN
# 293  08­Apr­2021          0    08­Apr­2021         NaN   20,000.00
# 294  09­Apr­2021          0    09­Apr­2021         NaN   13,000.00
# 295  09­Apr­2021          0    09­Apr­2021   10,000.00         NaN
# 296  09­Apr­2021          0    09­Apr­2021         NaN   41,500.00
# 297  09­Apr­2021          0    09­Apr­2021      200.00         NaN
# 298  09­Apr­2021          0    09­Apr­2021         NaN   30,000.00
# 299  09­Apr­2021          0    09­Apr­2021   33,000.00         NaN
# 300  09­Apr­2021          0    09­Apr­2021   10,000.00         NaN
# 301  09­Apr­2021          0    09­Apr­2021      200.00         NaN
# 302  10­Apr­2021          0    10­Apr­2021    5,000.00         NaN
# 303  12­Apr­2021          0  12­Apr­2021.1           0   30,000.00
# 304  12­Apr­2021          0    12­Apr­2021   30,000.00         NaN
# 305  13­Apr­2021          0    13­Apr­2021   10,000.00         NaN
# 306  13­Apr­2021          0    13­Apr­2021    5,000.00         NaN
# 307  13­Apr­2021          0    13­Apr­2021   10,000.00         NaN
# 308  14­Apr­2021          0    14­Apr­2021    1,500.00         NaN
# 309  14­Apr­2021          0    14­Apr­2021      200.00         NaN
# 310  14­Apr­2021          0    14­Apr­2021   10,000.00         NaN
# 311  15­Apr­2021          0    15­Apr­2021    1,000.00         NaN
# 312  17­Apr­2021          0    17­Apr­2021      200.00         NaN
# 313  17­Apr­2021          0    17­Apr­2021    1,000.00         NaN
# 314  17­Apr­2021          0    17­Apr­2021    1,000.00         NaN
# 315  17­Apr­2021          0    17­Apr­2021         NaN    5,000.00
# 316  17­Apr­2021          0    17­Apr­2021    3,000.00         NaN
# 317  17­Apr­2021          0    17­Apr­2021         NaN   25,000.00
# 318  17­Apr­2021          0  17­Apr­2021.1   10,000.00           0
# 319  17­Apr­2021          0    17­Apr­2021         NaN      400.00
# 320  17­Apr­2021          0    17­Apr­2021    2,460.00         NaN
# 321  17­Apr­2021          0    17­Apr­2021       50.00         NaN
# 322  18­Apr­2021          0    18­Apr­2021         NaN    5,000.00
# 323  18­Apr­2021          0    18­Apr­2021    5,000.00         NaN
# 324  18­Apr­2021          0    18­Apr­2021      200.00         NaN
# 325  19­Apr­2021          0    19­Apr­2021         NaN   75,000.00
# 326  19­Apr­2021          0    19­Apr­2021   75,000.00         NaN
# 327  24­Apr­2021          0    24­Apr­2021         NaN    3,000.00
# 328  24­Apr­2021          0    24­Apr­2021      200.00         NaN
# 329  25­Apr­2021  491300...    25­Apr­2021    1,000.00         NaN
# 330  25­Apr­2021          0    25­Apr­2021    1,000.00         NaN
# 331  25­Apr­2021          0    25­Apr­2021         NaN      200.00
# 332  25­Apr­2021          0    25­Apr­2021    1,000.00         NaN
# 333  27­Apr­2021          0    27­Apr­2021         NaN    1,500.00
# 334  27­Apr­2021          0    27­Apr­2021         NaN      400.00
# 335  27­Apr­2021          0    27­Apr­2021      200.00         NaN
# 336  28­Apr­2021          0  28­Apr­2021.1      200.00           0
# 337  28­Apr­2021          0    28­Apr­2021         NaN   20,000.00
# 338  29­Apr­2021          0    30­Apr­2021         NaN   71,353.48
# 339  29­Apr­2021          0    29­Apr­2021      200.00         NaN
# 340  29­Apr­2021          0    30­Apr­2021         NaN  113,932.66
# 341  29­Apr­2021          0    30­Apr­2021         NaN   40,066.78
# 342  30­Apr­2021          0    30­Apr­2021   43,370.58         NaN
# 343  30­Apr­2021          0    30­Apr­2021    5,000.00         NaN
# 344  30­Apr­2021          0    30­Apr­2021      200.00         NaN
# 345  30­Apr­2021          0    30­Apr­2021    2,000.00         NaN
# 346  30­Apr­2021          0    30­Apr­2021    5,000.00         NaN
# 347  30­Apr­2021  411900...    30­Apr­2021   55,283.39         NaN
# 348  30­Apr­2021  412000...    30­Apr­2021    4,953.47         NaN
# 349  30­Apr­2021  412001...    30­Apr­2021   72,818.23         NaN
# 350  01­May­2021          0    01­May­2021   30,000.00         NaN
# 351  01­May­2021          0    01­May­2021      200.00         NaN
# 352  01­May­2021          0    01­May­2021   20,000.00         NaN
# 353  01­May­2021          1    01­May­2021    5,000.00         NaN
# 354  02­May­2021          0    02­May­2021      200.00         NaN
# 355  03­May­2021          0  03­May­2021.1      200.00           0
# 356  03­May­2021          0    03­May­2021         NaN   21,000.00
# 357  03­May­2021          0    03­May­2021   15,000.00         NaN
# 358  03­May­2021          0    03­May­2021    6,000.00         NaN
# 359  04­May­2021          0    04­May­2021         NaN   25,000.00
# 360  04­May­2021          0    04­May­2021   20,000.00         NaN
# 361  04­May­2021          0    04­May­2021    1,000.00         NaN
# 362  05­May­2021          0    05­May­2021    1,500.00         NaN
# 363  06­May­2021          0    06­May­2021    3,000.00         NaN
# 364  06­May­2021          0    06­May­2021      200.00         NaN
# 365  06­May­2021          0    06­May­2021         NaN   45,000.00
# 366  06­May­2021          0    06­May­2021         NaN    5,000.00
# 367  06­May­2021          0    06­May­2021   50,000.00         NaN
# 368  06­May­2021          0    06­May­2021         NaN    2,000.00
# 369  06­May­2021          0    06­May­2021    2,000.00         NaN
# 370  10­May­2021          0    10­May­2021         NaN   15,500.00
# 371  10­May­2021          0  10­May­2021.1   15,000.00           0
# 372  10­May­2021          0    10­May­2021   25,000.00         NaN
# 373  11­May­2021          0    11­May­2021      200.00         NaN
# 374  11­May­2021          0    11­May­2021      200.00         NaN
# 375  11­May­2021          0    11­May­2021    1,000.00         NaN
# 376  12­May­2021          0    12­May­2021    1,500.00         NaN
# 377  12­May­2021          0    12­May­2021         NaN   10,000.00
# 378  12­May­2021          0    12­May­2021    2,650.00         NaN
# 379  12­May­2021          0    12­May­2021      200.00         NaN
# 380  13­May­2021          0    13­May­2021      200.00         NaN
# 381  13­May­2021          0    13­May­2021    6,000.00         NaN
# 382  13­May­2021          0    13­May­2021      200.00         NaN
# 383  14­May­2021          0    14­May­2021    1,000.00         NaN
# 384  15­May­2021          0    15­May­2021      200.00         NaN
# 385  16­May­2021          0    16­May­2021      200.00         NaN
# 386  17­May­2021          0    17­May­2021      200.00         NaN
# 387  18­May­2021          0    18­May­2021         NaN   30,000.00
# 388  18­May­2021          0    18­May­2021   30,000.00         NaN
# 389  18­May­2021          0  18­May­2021.1           0   47,000.00
# 390  18­May­2021          0    18­May­2021   10,000.00         NaN
# 391  19­May­2021          0    19­May­2021    1,500.00         NaN
# 392  19­May­2021          0    19­May­2021         NaN   15,000.00
# 393  19­May­2021          0    19­May­2021    5,000.00         NaN
# 394  19­May­2021          0    19­May­2021   46,000.00         NaN
# 395  19­May­2021          0    19­May­2021         NaN   30,000.00
# 396  19­May­2021          0    19­May­2021   30,000.00         NaN
# 397  20­May­2021          0    20­May­2021      100.00         NaN
# 398  26­May­2021          0    26­May­2021         NaN   50,000.00
# 399          NaN        NaN            NaN         NaN         NaN
# 400  26­May­2021          0    26­May­2021   50,000.00         NaN
# 401  28­May­2021          0    31­May­2021         NaN   40,066.78
# 402  28­May­2021          0    31­May­2021         NaN  113,932.66
# 403  28­May­2021          0    31­May­2021         NaN   71,353.48
# 404  29­May­2021          0    29­May­2021         NaN   27,000.00
# 405  29­May­2021  491600...    29­May­2021   27,000.00         NaN
# 406  31­May­2021          0    31­May­2021   10,000.00         NaN
# 407  31­May­2021          0  31­May­2021.1      200.00           0
# 408  31­May­2021          0    31­May­2021   99,000.00         NaN
# 409  31­May­2021          0    31­May­2021   50,000.00         NaN
# 410  31­May­2021          0    31­May­2021      200.00         NaN
# 411  31­May­2021          0    31­May­2021    2,000.00         NaN
# 412  31­May­2021  411900...    31­May­2021   55,366.53         NaN
# 413  31­May­2021  412000...    31­May­2021    4,943.50         NaN
# 414  31­May­2021  412001...    31­May­2021   72,818.23         NaN
# 415  01­Jun­2021          0    01­Jun­2021      200.00         NaN
# 416  01­Jun­2021          0    01­Jun­2021      200.00         NaN
# 417  01­Jun­2021          1    01­Jun­2021    5,000.00         NaN
# 418  02­Jun­2021          0    02­Jun­2021    1,500.00         NaN
# 419  02­Jun­2021          0    02­Jun­2021    1,025.00         NaN
# 420  02­Jun­2021          0    02­Jun­2021      200.00         NaN
# 421  03­Jun­2021          0    03­Jun­2021    2,000.00         NaN
# 422  03­Jun­2021          0    03­Jun­2021         NaN   43,000.00
# 423  03­Jun­2021          0    03­Jun­2021   43,000.00         NaN
# 424  03­Jun­2021          0    03­Jun­2021      200.00         NaN
# 425  04­Jun­2021          0    04­Jun­2021      200.00         NaN
# 426  05­Jun­2021          0  05­Jun­2021.1    1,000.00           0
# 427  07­Jun­2021          0    07­Jun­2021         100         NaN
#
#               5  \
# 0      3,993.22
# 1      1,993.22
# 2     60,539.71
# 3     19,539.71
# 4     15,539.71
# 5     15,339.71
# 6     14,339.71
# 7     13,339.71
# 8     16,339.71
# 9      6,339.71
# 10     1,339.71
# 11     1,139.71
# 12     1,039.71
# 13       639.71
# 14       439.71
# 15       239.71
# 16        39.71
# 17     2,039.71
# 18     6,039.71
# 19     1,039.71
# 20        39.71
# 21    72,496.81
# 22   186,429.47
# 23   226,496.25
# 24   229,496.25
# 25     4,496.25
# 26   487,496.25
# 27   492,496.25
# 28     2,454.01
# 29   805,028.01
# 30     5,028.01
# 31     4,528.01
# 32     2,528.01
# 33    82,528.01
# 34    21,127.71
# 35    20,957.90
# 36   ­22,412.68
# 37     2,587.32
# 38     2,187.32
# 39       687.32
# 40       187.32
# 41   156,187.32
# 42   131,159.92
# 43    56,159.92
# 44    55,159.92
# 45    54,959.92
# 46    54,459.92
# 47    46,459.92
# 48    16,459.92
# 49    14,959.92
# 50    14,759.92
# 51    14,559.92
# 52     6,559.92
# 53     3,559.92
# 54       159.92
# 55    20,159.92
# 56       159.92
# 57        59.92
# 58     2,059.92
# 59     1,919.92
# 60     1,909.42
# 61     1,409.42
# 62       409.42
# 63       209.42
# 64         9.42
# 65     5,009.42
# 66     4,009.42
# 67   399,009.42
# 68   494,009.42
# 69   474,009.42
# 70   469,509.42
# 71   465,709.42
# 72   472,709.42
# 73   442,709.42
# 74   432,709.42
# 75   431,709.42
# 76   430,709.42
# 77   429,709.42
# 78   429,209.42
# 79   429,009.42
# 80   428,009.42
# 81   427,809.42
# 82   419,809.42
# 83   397,809.42
# 84   382,809.42
# 85   382,309.42
# 86   380,809.42
# 87   377,809.42
# 88   372,809.42
# 89   372,609.42
# 90   369,609.42
# 91   368,609.42
# 92   353,609.42
# 93   343,609.42
# 94   343,409.42
# 95   338,409.42
# 96   343,409.42
# 97   336,409.42
# 98   335,409.42
# 99   330,209.42
# 100  328,209.42
# 101  328,009.42
# 102  327,909.42
# 103  254,909.42
# 104  326,262.90
# 105  440,195.56
# 106  480,262.34
# 107  621,168.58
# 108  620,968.58
# 109  534,968.58
# 110   34,968.58
# 111  234,968.58
# 112  191,598.00
# 113  190,498.00
# 114  189,398.00
# 115  127,398.00
# 116   71,839.64
# 117   66,840.05
# 118   60,840.05
# 119   20,840.05
# 120   19,840.05
# 121   17,740.05
# 122   17,540.05
# 123  ­55,453.60
# 124  ­55,513.29
# 125    1,486.71
# 126   ­2,513.29
# 127   53,486.71
# 128   38,486.71
# 129   33,486.71
# 130   30,486.71
# 131   28,486.71
# 132   20,486.71
# 133   40,486.71
# 134   20,486.71
# 135   15,386.71
# 136   10,386.71
# 137      386.71
# 138      186.71
# 139    2,186.71
# 140    1,986.71
# 141      986.71
# 142      786.71
# 143       86.71
# 144        6.71
# 145   25,006.71
# 146   24,806.71
# 147   24,606.71
# 148   19,606.71
# 149        6.71
# 150  200,006.71
# 151  199,806.71
# 152   69,806.71
# 153   35,806.71
# 154   20,806.71
# 155   25,806.71
# 156   28,806.71
# 157   18,806.71
# 158   18,606.71
# 159   89,960.19
# 160  203,892.85
# 161  243,959.63
# 162  243,759.63
# 163  218,759.63
# 164  218,559.63
# 165  214,859.63
# 166  102,859.63
# 167   47,781.20
# 168           5
# 169  ­30,007.22
# 170   10,042.78
# 171    9,542.78
# 172   69,542.78
# 173   19,542.78
# 174    9,542.78
# 175   34,542.78
# 176   33,542.78
# 177   33,342.78
# 178   13,342.78
# 179   11,842.78
# 180    1,842.78
# 181   51,842.78
# 182   51,862.35
# 183   51,860.39
# 184   51,660.39
# 185   50,660.39
# 186   48,160.39
# 187   45,660.39
# 188   43,560.39
# 189   35,560.39
# 190   15,560.39
# 191   55,560.39
# 192   12,189.81
# 193   11,989.81
# 194    9,989.81
# 195    8,989.81
# 196    8,789.81
# 197    8,589.81
# 198    7,589.81
# 199    2,589.81
# 200   17,589.81
# 201    2,589.81
# 202    2,389.81
# 203    1,889.81
# 204    1,389.81
# 205   21,509.81
# 206   17,509.81
# 207   17,009.81
# 208   12,009.81
# 209   11,709.81
# 210    7,209.81
# 211   20,089.81
# 212   74,589.81
# 213   20,089.81
# 214   19,089.81
# 215   17,589.81
# 216   37,589.81
# 217   37,389.81
# 218   30,389.81
# 219   27,389.81
# 220   22,389.81
# 221   22,389.81
# 222   21,389.81
# 223   11,389.81
# 224   10,389.81
# 225   10,189.81
# 226   11,189.81
# 227   10,189.81
# 228    9,189.81
# 229    8,989.81
# 230   68,989.81
# 231    8,989.81
# 232    8,689.81
# 233    8,489.81
# 234    7,989.81
# 235    3,989.81
# 236    3,789.81
# 237   63,789.81
# 238   69,789.81
# 239    5,289.81
# 240    5,089.81
# 241    4,889.81
# 242    3,389.81
# 243   33,389.81
# 244   33,189.81
# 245    9,689.81
# 246    4,689.81
# 247   24,689.81
# 248   74,689.81
# 249   74,489.81
# 250       89.81
# 251   50,089.81
# 252       89.81
# 253   40,156.59
# 254  154,089.25
# 255  225,442.73
# 256  223,442.73
# 257  278,942.73
# 258  228,942.73
# 259   78,942.73
# 260  228,942.73
# 261   33,942.73
# 262   33,742.73
# 263   43,742.73
# 264  ­12,596.15
# 265  ­17,599.42
# 266  ­90,417.65
# 267  ­90,487.01
# 268  ­11,487.01
# 269    3,512.99
# 270  159,512.99
# 271  134,207.51
# 272   84,207.51
# 273   40,836.93
# 274   35,836.93
# 275   23,336.93
# 276   18,336.93
# 277   54,336.93
# 278   73,336.93
# 279   43,336.93
# 280   21,336.93
# 281   11,336.93
# 282   65,336.93
# 283   25,336.93
# 284   10,336.93
# 285   43,336.93
# 286    3,336.93
# 287      336.93
# 288   35,536.93
# 289   29,279.43
# 290      518.18
# 291      418.18
# 292      218.18
# 293   20,218.18
# 294   33,218.18
# 295   23,218.18
# 296   64,718.18
# 297   64,518.18
# 298   94,518.18
# 299   61,518.18
# 300   51,518.18
# 301   51,318.18
# 302   46,318.18
# 303   70,318.18
# 304   40,318.18
# 305   30,318.18
# 306   25,318.18
# 307   15,318.18
# 308   13,818.18
# 309   13,618.18
# 310    3,618.18
# 311    2,618.18
# 312    2,418.18
# 313    1,418.18
# 314      418.18
# 315    5,418.18
# 316    2,418.18
# 317   27,418.18
# 318    2,418.18
# 319    2,818.18
# 320      358.18
# 321      308.18
# 322    5,308.18
# 323      308.18
# 324      108.18
# 325   75,108.18
# 326      108.18
# 327    3,108.18
# 328    2,908.18
# 329    1,908.18
# 330      908.18
# 331    1,108.18
# 332      108.18
# 333    1,608.18
# 334    2,008.18
# 335    1,808.18
# 336      108.18
# 337   20,108.18
# 338   91,461.66
# 339   91,261.66
# 340  205,194.32
# 341  245,261.10
# 342  201,890.52
# 343  196,890.52
# 344  196,690.52
# 345  194,690.52
# 346  189,690.52
# 347  134,407.13
# 348  129,453.66
# 349   56,635.43
# 350   26,635.43
# 351   26,435.43
# 352    6,435.43
# 353    1,435.43
# 354    1,235.43
# 355      835.43
# 356   21,835.43
# 357    6,835.43
# 358      835.43
# 359   25,835.43
# 360    5,835.43
# 361    4,835.43
# 362    3,335.43
# 363      335.43
# 364      135.43
# 365   45,135.43
# 366   50,135.43
# 367      135.43
# 368    2,135.43
# 369      135.43
# 370   15,635.43
# 371   29,635.43
# 372    4,635.43
# 373    4,435.43
# 374    4,235.43
# 375    3,235.43
# 376    1,735.43
# 377   11,735.43
# 378    9,085.43
# 379    8,885.43
# 380    8,685.43
# 381    2,685.43
# 382    2,485.43
# 383    1,485.43
# 384    1,285.43
# 385    1,085.43
# 386      885.43
# 387   30,885.43
# 388      885.43
# 389   47,685.43
# 390   37,685.43
# 391   36,185.43
# 392   51,185.43
# 393   46,185.43
# 394      185.43
# 395   30,185.43
# 396      185.43
# 397       85.43
# 398   50,085.43
# 399         NaN
# 400       85.43
# 401   40,152.21
# 402  154,084.87
# 403  225,438.35
# 404  252,438.35
# 405  225,438.35
# 406  215,438.35
# 407  296,238.35
# 408  197,238.35
# 409  147,238.35
# 410  147,038.35
# 411  145,038.35
# 412   89,671.82
# 413   84,728.32
# 414   11,910.09
# 415   11,710.09
# 416   11,510.09
# 417    6,510.09
# 418    5,010.09
# 419    3,985.09
# 420    3,785.09
# 421    1,785.09
# 422   44,785.09
# 423    1,785.09
# 424    1,585.09
# 425    1,385.09
# 426      185.09
# 427       85.09
#
#                                                                                                                                                                                                                    6
# 0                                                                                                                                                                 OWN ACCOUNT TRANSFER\rREF:205154861000000200002...
# 1                                                                          TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612320696...\rfrom ADEOSUN KEHINDE WAKIL\rto ODELE,ABIODUN RAYMOND
# 2                                                                                                                                                                                       MTHLY SALARY 13th Month 2020
# 3                                                                         TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548613710356...\rfrom ADEOSUN KEHINDE WAKIL\rto ADEOSUN, ABDULSEMIU G.
# 4                                                        NIBSS Instant Payment Outward\r0000132012011932440002717...\rUSSD NIP Transfer from\r08033725563 TO\rZBN/TEMITAYO ALIU AIBINU\rREF:000013201201193244000...
# 5                                                                                                                                                   Airtime Purchase USSD­\r101CT0000000002185428097­\r2348033725563
# 6                                                                                                                                                   Airtime Purchase USSD­\r101CT0000000002185430572­\r2348031164646
# 7                                                                                                                                                   Airtime Purchase USSD­\r101CT0000000002185792084­\r2348180043134
# 8                                                                                                                                                                 OWN ACCOUNT TRANSFER\rREF:205154861000000030002...
# 9                                                                                                                                                    STANDING ORDER Standing\rOrder via Internet Banking food\rstuff
# 10                                                                                                                                             STANDING ORDER Standing\rOrder via Internet Banking For\rMy Sweet Mum
# 11                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002188404710­\r2348034395533
# 12                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002188409588­\r2348127107811
# 13                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002192004930­\r2348033725563
# 14                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002196087600­\r2348033725563
# 15                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002198016341­\r2348033725563
# 16                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002212734957­\r2348033725563
# 17                                             TRANSFER BETWEEN\rCUSTOMERS\r0000142012122359312285307...\rADEOSUN MONSURAT\rOLARANTI TO\rADEOSUN|VNM812041183150...\rMONSURAT OLARANTI\rREF:000014201212235931228...
# 18                                                                                                                                                                    OWN ACCOUNT TRANSFER trf\rvia Internet Banking
# 19                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548613710356...\rfrom ADEOSUN KEHINDE WAKIL\rto ADEOSUN, ABDULSEMIU G.
# 20                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002224342762­\r2349090373699
# 21                                                                                                                                                                                   MTHLY SALARY December 2020\rSal
# 22                                                                                                                                                                                         MISC. December 2020 Allow
# 23                                                                                                                                                                      MEDICAL BILL/REFUND\rMedrefund December 2020
# 24                                                                      TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000023404955322050154...\rfrom AGBOOLA, ALIRAT\rOLAKEMI to ADEOSUN KEHINDE\rWAKIL
# 25                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000002250002...
# 26                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000004830002...
# 27                                                                              TRANSFER BETWEEN\rCUSTOMERS Via GTWorld Trfs\rREF:205153162000000050002...\rfrom OLADEJI, SAHEED\rADEKUNLE to ADEOSUN\rKEHINDE WAKIL
# 28                                                                                                                                                                                              PREMATURE SETTLEMENT
# 29                                                                                                                                                                                                 LOAN DISBURSEMENT
# 30                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000008000002...
# 31                                                                      TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612050153...\rfrom ADEOSUN KEHINDE WAKIL\rto OLADEJI, SAHEED ADEKUNLE
# 32                                                                       TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614920470...\rfrom ADEOSUN KEHINDE WAKIL\rto YUSUF , NAFISAT OPEYEMI
# 33                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000000800002...
# 34                                                                                                                                                                                          MATURED LOAN INSTALLMENT
# 35                                                                                                                                                                                              INTEREST CAPITALISED
# 36                   REMITA PAYMENT R­\r444669036/LIBER:Loan\rrepayment Loan repayment\rDD:3304343 84446690366 from\rADEOSUN KEHINDE WAKIL To\rGENERAL REF:\r0000016304107184446690366\rREF:205015486100043370582...
# 37                                                                                                                                                                OWN ACCOUNT TRANSFER\rREF:205154861000000250002...
# 38                                                                                                                                               Airtime Purchase GTWORLD­\r101CT0000000002262779776­\r2349034765471
# 39                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002259503318­\r2349090373699
# 40                                                                                                                                                  Airtime Purchase USSD­\r101CT0000000002264277713­\r2348030460489
# 41                                                                                                                                                              OTHER TRANSACTION 2020\rQuarterly Deferred Incentive
# 42                                                                                                                                                    OTHER TRANSACTION GSAC\rPremium (Jan 5, 2021 ­ April 4,\r2021)
# 43                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614910462...\rfrom ADEOSUN KEHINDE WAKIL\rto ADEDEJI OMOTAYO GANIYU
# ...
# 354                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002559111735­\r2348033725563
# 355                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002561393688­\r2348033725563
# 356                                                                          TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rCollect it\rREF:481454704000000210002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 357                                                                                           Biometric ATM Withdrawal ATM\rFingerprint Cash for ADEOSUN\rKEHINDE WAKIL_\r8175_1948098\rREF:020515486100000150000...
# 358                                                                                           Biometric ATM Withdrawal ATM\rFingerprint Cash for ADEOSUN\rKEHINDE WAKIL_\r3043_1948142\rREF:020515486100000060000...
# 359                                                                              TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rThanks\rREF:481454704000000250002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 360                                                                                                                                                               OWN ACCOUNT TRANSFER\rREF:205154861000000200002...
# 361                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614810454...\rfrom ADEOSUN KEHINDE WAKIL\rto JIMOH, SHADE SHAKIRAT
# 362                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002566080309­\r2349090373699
# 363                                                                                                                                                               OWN ACCOUNT TRANSFER\rREF:205154861000000030002...
# 364                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002569273316­\r2348033725563
# 365                                                                              TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rThanks\rREF:481454704000000450002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 366                                                                                                                                                               OWN ACCOUNT TRANSFER\rREF:205154861000000050002...
# 367                                                                    TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612280679...\rfrom ADEOSUN KEHINDE WAKIL\rto OYEKUNLE KEHINDE\rADEJOKE
# 368                                                                                  TRANSFER BETWEEN\rCUSTOMERS Via GTWorld Add\rREF:481454704000000020002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 369                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614810454...\rfrom ADEOSUN KEHINDE WAKIL\rto JIMOH, SHADE SHAKIRAT
# 370                                     TRANSFER BETWEEN\rCUSTOMERS\r0000082105101639505907296...\rTo: ADEOSUN KEHINDE\rWAKIL:GTBank :\rD212667D924B435FA107412A...\rOLAJEMIYO ADEOSUN\rREF:000008210510163950590...
# 371                                                                                      GTRescue Cashout GTRescue\rcashout for 08033725563 from\rADEOSUN KEHINDE WAKIL_\r5644_2114371\rREF:020515486100000150000...
# 372                                                                                           Biometric ATM Withdrawal ATM\rFingerprint Cash for ADEOSUN\rKEHINDE WAKIL_\r8142_2114828\rREF:020515486100000250000...
# 373                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002581977897­\r2348033725563
# 374                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002581985870­\r2348033725563
# 375                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002582988307­\r2348187682149
# 376                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002583988630­\r2349090373699
# 377                                                                                      TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rREF:481454704000000100002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 378                                                                      TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614920441...\rfrom ADEOSUN KEHINDE WAKIL\rto OYEBODE OYEPEJU GANIYAT
# 379                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002586146283­\r2348033725563
# 380                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002587379676­\r2348033725563
# 381                                                            NIBSS Instant Payment Outward\r0000132105131449490001313...\rUSSD NIP Transfer from\r08033725563 TO ARIKE TAIBAT\rJIMOH\rREF:000013210513144949000...
# 382                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002588460673­\r2348033725563
# 383                                                                                           Biometric ATM Withdrawal ATM\rFingerprint Cash for ADEOSUN\rKEHINDE WAKIL_\r9048_2216845\rREF:020515486100000010000...
# 384                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002592570118­\r2348033725563
# 385                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002593930515­\r2348033725563
# 386                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002595600236­\r2348033725563
# 387                                                                   TRANSFER BETWEEN\rCUSTOMERS\r1100072105181415165554658...\rPOS\rAgent|DEP|2MPT1z7c|1394642...\rAgent AZ Ventures\rREF:110007210518141516555...
# 388                                            NIBSS Instant Payment Outward\r0000132105181440290001379...\rvia GTWORLD Adeosun Wasiu\rOlajemiyo TO LETSHEGO\rMICROFINANCE BANK LIMITED\rREF:GW205154861000000300...
# 389                                                                                   TRANSFER BETWEEN\rCUSTOMERS Via GTWorld Re\rREF:481454704000000470002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 390                                                                                   FASTTRACK CASH\rWITHDRAWAL PINPAD­\r80974523­491/1564 CASH\rWITHDRAWAL BY ADEOSUN\rKEHINDE WAKIL\r0006375695084901239313380...
# 391                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002600613300­\r2349090373699
# 392                                                                   TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000049105478352050154...\rfrom BULIAMINU, ABDULLAHI\rFEMI to ADEOSUN KEHINDE\rWAKIL
# 393                                                                         TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612480305...\rfrom ADEOSUN KEHINDE WAKIL\rto AINA, BABAJIDE DAVID
# 394                                                                                                                                                               OWN ACCOUNT TRANSFER\rREF:205154861000000460002...
# 395                                                                                   TRANSFER BETWEEN\rCUSTOMERS Via GTWorld Ok\rREF:481454704000000300002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 396                                                                                   FASTTRACK CASH\rWITHDRAWAL PINPAD­\r80991622­491/1564 CASH\rWITHDRAWAL BY ADEOSUN\rKEHINDE WAKIL\r0006375703345975884483380...
# 397                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002604135151­\r2348033725563
# 398                                                                              TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rThanks\rREF:481454704000000500002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 399                                                                                                                                                                                                   FASTTRACK CASH
# 400                                                                                                                       81094178­491/1564 CASH\rWITHDRAWAL BY ADEOSUN\rKEHINDE WAKIL\r0006375764115666410053380...
# 401                                                                                                                                                                          MEDICAL BILL/REFUND\rMedrefund May 2021
# 402                                                                                                                                                                                             MISC. May 2021 Allow
# 403                                                                                                                                                                                        MTHLY SALARY May 2021 Sal
# 404                                                                         TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000024302265352050154...\rfrom FALOLA ISAAC OLUFEMI to\rADEOSUN KEHINDE WAKIL
# 405                                                                                                                               CASH WITHDRAWAL FROM OUR\rATM ­008394­ ­360416­GTBank\r3, Lagere Road Ile­Ife OSNG
# 406                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614810454...\rfrom ADEOSUN KEHINDE WAKIL\rto JIMOH, SHADE SHAKIRAT
# 407                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002630330396­\r2348033725563
# 408                                                                                      TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rREF:205154861000000990002...\rfrom ADEOSUN KEHINDE WAKIL\rto ODELE,ABIODUN RAYMOND
# 409                                                                     TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548612050153...\rfrom ADEOSUN KEHINDE WAKIL\rto OLADEJI, SAHEED ADEKUNLE
# 410                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002631673142­\r2348033725563
# 411                                                                     TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614910495...\rfrom ADEOSUN KEHINDE WAKIL\rto ABIYEYE, OLUWATOMISIN O.
# 412                                                                                                                                                                                         MATURED LOAN INSTALLMENT
# 413                                                                                                                                                                                         MATURED LOAN INSTALLMENT
# 414                                                                                                                                                                                         MATURED LOAN INSTALLMENT
# 415                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002633441152­\r2348113897792
# 416                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002635178608­\r2348033725563
# 417                                                                                                                                            STANDING ORDER Standing\rOrder via Internet Banking For\rmy sweet mum
# 418                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002635972771­\r2349090373699
# 419                                                                                   TRANSFER BETWEEN\rCUSTOMERS Via GTWorld\rREF:205154861000000010252...\rfrom ADEOSUN KEHINDE WAKIL\rto OLADEJI, SAHEED ADEKUNLE
# 420                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002637741277­\r2348033725563
# 421                                                                        TRANSFER BETWEEN\rCUSTOMERS Via USSD GTBank\rTransfer\r0000000020501548614910542...\rfrom ADEOSUN KEHINDE WAKIL\rto ADEOSUN, OMOBOLAJI O.
# 422                                                                                    TRANSFER BETWEEN\rCUSTOMERS Via GTWorld K\rREF:481454704000000430002...\rfrom JIMOH, SHADE SHAKIRAT\rto ADEOSUN KEHINDE WAKIL
# 423                                                                                   FASTTRACK CASH\rWITHDRAWAL PINPAD­\r81238406­491/1564 CASH\rWITHDRAWAL BY ADEOSUN\rKEHINDE WAKIL\r0006375833362441499213380...
# 424                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002640604089­\r2348033725563
# 425                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002641830288­\r2349034765471
# 426                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002645228359­\r2348187682149
# 427                                                                                                                                                 Airtime Purchase USSD­\r101CT0000000002650673299­\r2348033725563

# %%
def log_info(step, account_type, bank_id, statement_gt_bank, error,**kwargs):
    
    extension = os.path.splitext(f'{statement_gt_bank}')[1][:]
    rel_logname = f'{statement_gt_bank}'.replace(extension,".log").split("/")[-1]
    logname = os.path.join(os.getcwd(), rel_logname)
    
    FORMAT = '%(asctime)-15s %(bank_account_type)s %(bank_file_name)-15s %(error_message)s %(message)s'
    #FORMAT = '%(asctime)-15s %(message)s'
    logging.basicConfig(filename=logname,
                        filemode='a',
                        format=FORMAT,
                        force=True,
                        level=logging.INFO)

    d = {
        'bank_account_type': account_type,
        'step':step,
        'bank_id': bank_id, 
        'bank_file_name': statement_gt_bank,
        'error_message': str(error)
        }

    
    logger = logging.getLogger('bank_statement')
    if error != None:
        logger.info('ETL_STEP_%s', step, extra=d)
    else:
        logger.error('ETL_STEP_%s', step, extra=d)

# %%
class BankAccountTypeError(Exception):
    
    def __init__(self, bank_account_type, message="There are too many uploaded documents"):
        self.bank_account_type_list = bank_account_type
        self.message = message
        super().__init__(self.message)
        
    def __str__(self):
        return "You must upload one statement per individual (SAVINGS/CURRENT) bank statement per individual"

# %%
class BankStatementPathError(Exception):
    
    def __init__(self, message="The Bank statement path does not exist"):
        self.message = message
        super().__init__(self.message)
        
    def __str__(self):
        return "Check that there is no typo in the bank statement filepath"

# %%
class BankStatementFormatError(Exception):
    
    def __init__(self, message="The Bank statement format is not accepted"):
        self.message = message
        super().__init__(self.message)
        
    def __str__(self):
        return "The valid format is pdf - only"

# %%
class BankStatementColumnsError(Exception):
    
    def __init__(self, template_version, bank_id, mapping):

        
        message = f"DataFrames format should have at max: {mapping[bank_id][template_version]}"
        self.message = message
        super().__init__(self.message)
        
    def __str__(self):
        return "There is a problem of columns during extraction"

# %%
class GT_BankStatement_no_header():
    
    def __init__(self, b_statement_gt_bank, bank_id='GT_Bank', template_version='NO_HEADER'):
        '''
        initializes the Gt_bank statement class
        '''
        # a bankstatement has 2 input attributes (for now)
        # bank_id & statement pdf path
        
        self.bank_id = bank_id
        self.filename = b_statement_gt_bank
        self.allowed_extensions =["pdf"]
        self.template_version = template_version
        
                
        self.mapping = {
            "GT_Bank": {
                "NO_HEADER":8,
                "HEADER":7
                }
        }
        
        self.log_check_bank_statement_extension()
        self.log_check_bank_statement_path()
        
        self.customer_bank_statement = bank_statement_to_dataframe(b_statement_gt_bank, mult=True, pages_all='all')
        self.df = self.customer_bank_statement.copy()
        
              
    def describe_accounts_types(self):
        '''
        returns the account type (savings or current)
        '''
        
        self.accounts_info = [df for df in self.df if len(df.columns) == 2]
        account_type_list= []
        for account in self.accounts_info:
            account.index = account["Print. Date"]
            acc_tr = account.transpose()
            account_type_list.append(acc_tr["Account Type"][-1])
        return account_type_list
            
        
        
    def log_check_bank_statement_extension(self):
        extension = os.path.splitext(self.filename)[1][1:]
        if extension not in self.allowed_extensions:
            account_type = 'NA'
            log_info('PRELOAD',account_type, self.bank_id, self.filename,'BankStatementFormatError')
            raise BankStatementFormatError
            
            
    def log_check_bank_statement_path(self):
        file_exists = os.path.exists(self.filename)
        if not file_exists:
            account_type = 'NA'
            log_info('PRELOAD',account_type, self.bank_id, self.filename,'BankStatementPathError')
            raise BankStatementPathError
        
        
    def log_check_account_type(self):
        '''
        checks the bank_type and logs the operation
        '''
        
        account_type = self.describe_accounts_types()
        if len(account_type) != 1:
            log_info('LOAD',account_type, self.bank_id, self.filename,'BankAccountTypeError')
            raise BankAccountTypeError(account_type)
        else:
            self.account_type = account_type[0]
            log_info('LOAD',self.account_type, self.bank_id, self.filename,None)
            
            
    def log_check_table(self):
        '''
        Store the list of columns names of all extracted dataframes
        '''
        # store the columns names for debug
        self.df_cols = [b_statement_dataframe.columns for b_statement_dataframe in self.df]
        
        max_ncols = self.mapping[self.bank_id][self.template_version]
        print(max_ncols)
        print(max([len(el) for el in self.df_cols]))
        
        
        
        if max([len(el) for el in self.df_cols]) < max_ncols:
            raise BankStatementColumnsError(self.template_version, self.bank_id, self.mapping)
            log_info('PDF-TABLES',self.account_type, self.bank_id, self.filename,'BankStatementColumnsError')   
        
        elif max([len(el) for el in self.df_cols]) > max_ncols:
            log_info('PDF-TABLES',self.account_type, self.bank_id, self.filename,'BankStatementColumnsWarning')
            self.passed_df_cols_idx = [ind for ind, ex in enumerate(self.df_cols) if len(ex) == 8]
            failed_idx = list(set(list(range(len(self.df_cols))))- set(self.passed_df_cols_idx))
            failed_idx.sort()
            self.not_passed_df_cols_idx = failed_idx
            
        return self.df_cols
    
    
    
    
    
    def black_list_narrow_tables(self, verbose = False):
        '''
        removes the tables that do not contain transaction data
        '''
        
        # each pdf can extract tables
        # (some tables will be without headers)
        # We want to recreate the header (which matches table 1)
        
        
        self.finalized_dfs = []
        self.blacklisted_tables_idxs = []
        
        # all dataframes with statement operations is reformatted
        self.reformatted_dfs = [self.df[k].T.reset_index().T for k in range(1,len(self.df),1)]
        
        
        for idx,r_df in enumerate(self.reformatted_dfs): 
            try:
                # the first dataframe with the right header is the dataframe id = 1
                r_df.columns = self.df[1].columns
                r_df.index = range(r_df.shape[0])
                r_df = r_df.replace(regex=[r'^Unnamed:..$'], value=np.nan)
                
                # store  the cleaned data frame in a placeholder list
                self.finalized_dfs.append(r_df)
                
            except Exception as e:
                if verbose : print(e)
                log_info('DATAFRAME-CLEANING',self.account_type, self.bank_id, self.filename,e) 
                # if it fails, it is because it is a table of another type
                # they will be blacklisted and kept for potential processing
                self.blacklisted_tables_idxs.append(idx)

    
    def combine_dataframes(self):
        '''
        combines dataframes that contain financial data
        '''
        # combine all whitelisted dataframes (=transactions)
        try:
            self.master_df = pd.concat(self.finalized_dfs[:]).reset_index(drop=True)
            log_info('DATAFRAME-COMBINATION',self.account_type, self.bank_id, self.filename, None)
            
            assert (self.master_df.columns == self.df[1].columns), "the columns names do not match the top header"
            assert (self.shape[0] != 0), "the dataframe is empty - no rows"
            
        except Exception as e:
            log_info('DATAFRAME-COMBINATION', self.account_type, self.bank_id, self.filename, e) 

        
    def clean_dataframe(self):
        '''
        simple data cleaning to remove non informative cells
        '''
        # extra cleaning due to columns concatenation
        self.master_df = self.master_df[self.master_df['Remarks']!= 'Remarks']
        self.master_df = self.master_df[self.master_df['Remarks']!= 'Balance as at Last Transaction.']
        self.master_df = self.master_df[self.master_df["Trans. Date"] != 'Trans. Date']
        self.master_df = self.master_df.reset_index(drop=True)
        log_info('CLEAN-DATFRAME', self.account_type, self.bank_id, self.filename, None)
        
        
    def clean_transactions(self):
        '''
        keep only the transactions with dates and add one fictious date for easier processing
        
        '''
        try:
            self.clean_dataframe()
            self.transaction_not_null = self.master_df[~self.master_df["Trans. Date"].isna()].copy()
            max_idx = self.self.transaction_not_null.index.max()
            self.index_list_of_transaction = list(self.transaction_not_null.index)
            self.transaction_not_null.loc[max_idx + 1,'Trans. Date'] = '99-Apr-9999'
            
            log_info('CLEAN-TRANSACTIONS', self.account_type, self.bank_id, self.filename, None) 

            assert (self.transaction_not_null.shape[0] == max_idx + 1),"the additional row  (99-Apr-9999) was not added"
            assert (self.transaction_not_null.loc[max_idx + 1,'Trans. Date'] == '99-Apr-9999'),"the additional row (99-Apr-9999) was not properly added"

        except Exception as e:
            log_info('CLEAN-TRANSACTIONS', self.account_type, self.bank_id, self.filename, e) 
            
    def postprocess(self, verbose = False):
        '''
        reconstruct the financial operations which overflow to the next line in 1 single text
        '''
        
        # all the indexes of the transaction with dates
        self.index_with_dates = self.transaction_not_null.index
        
        self.descr = {}
        for step_date in self.index_with_dates:
            self.descr[str(step_date)] = []
  

        for idx, step in enumerate(self.index_with_dates):
            if idx < len(self.index_with_dates)-1:
                for ind in range(self.index_with_dates[idx], self.index_with_dates[idx+1], 1):
                    if ind < self.index_with_dates[idx+1]: 
                        if str(self.master_df.loc[ind, 'Remarks']) != 'nan':
                            self.descr[str(step)] += [str(self.master_df.loc[ind, 'Remarks'])]
            else:
                for ind in range(self.index_with_dates[idx], self.master_df.shape[0], 1):
                    if str(self.master_df.loc[ind, 'Remarks']) != 'nan':
                        self.descr[str(step)] += [str(self.master_df.loc[ind, 'Remarks'])]
                        
        for key in self.descr.keys():
            self.descr[key] = (''.join(self.descr[key])).replace('\r',' ')
        if verbose:
            return self.descr
    
    def recombined_dataframe(self, verbose= False):
        '''
        reconstruct the final dataset with all original transaction information plus the annotations
        '''
        # Dataframe of the transactions
        annotations = pd.DataFrame.from_dict(self.descr,  orient='index', columns=['Remarks_processed'])
        self.dataset_recombined = pd.concat([self.transaction_not_null.reset_index(drop=True), annotations.reset_index(drop=True)], axis=1)
        self.dataset_recombined['ACCOUNT_TYPE'] = self.account_type
        self.dataset_recombined['BANK_ID'] = self.bank_id
        self.dataset_recombined['FILE_NAME'] = self.filename
        
        if verbose:
            return self.dataset_recombined
        
        self.dataset_recombined = self.dataset_recombined[['Trans. Date','Reference','Value. Date','Debits','Credits','Balance','Remarks_processed','ACCOUNT_TYPE','BANK_ID', 'FILE_NAME']]

# %%
### Demo on GT bank - template with no header

# %%
customer1 =  GT_BankStatement_no_header("./Dataset_banks/statements/MR IBRAHIM ASHAFA STATEMENT.pdf")

# %%
customer1.describe_accounts_types()
# Out:
# ['SAVINGS ACCOUNT']

# %%
customer1.log_check_account_type()

# %%
customer1.account_type
# Out:
# 'SAVINGS ACCOUNT'

# %%
customer1.log_check_bank_statement_extension()

# %%
customer1.black_list_narrow_tables()

# %%
customer1.log_check_table()
# Out:
# 8
# 8
# [Index(['Print. Date', '10-Jun-2021'], dtype='object'),
#  Index(['Trans. Date', 'Value. Date', 'Reference', 'Debits', 'Credits',
#         'Balance', 'Originating Branch', 'Remarks'],
#        dtype='object'),
#  Index(['07-Dec-2020', '07-Dec-2020.1', ''0GWTR', '50,000.00', 'Unnamed: 0',
#         '310,944.19', 'E- CHANNELS',
#         'TRANSFER BETWEEN CUSTOMERS Via GTWorld\rEneke   REF:681976569000000500002012070913\rfrom ASHAFA IBRAHIM ABDULLAHI  to  SALAMI,\rABUBAKAR'],
#        dtype='object'),
#  Index(['07-Dec-2020', '07-Dec-2020.1', ''0NIPG', '15,000.00', 'Unnamed: 0',
#         '105,863.57', 'E- CHANNELS',
#         'NIBSS Instant Payment Outward\r000013201207093604000279969267 via\rGTWORLD  TO UBA/YAKUBU ASHAFA\rABDULLAHI\r/26.875/REF:GW6819765690000001500020120709\rf'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'NIP TRANSFER COMMISSION FOR\r000013201207094005000279976405 via\rGTWORLD  TO ECO/HASSAN ABDULLAHI\rReF:GW681976569000000040002012070939'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '000013201207095014000279994062 via'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'IBRAHIM ABDULLAHI\rREF: 0005628626104167342000000'],
#        dtype='object'),
#  Index(['08-Dec-2020', '08-Dec-2020.1', ''0NIPG', '15,000.00', 'Unnamed: 0',
#         '36,813.09', 'E- CHANNELS',
#         'NIBSS Instant Payment Outward\r000013201208094656000281590024 via\rGTWORLD  TO ECO/HUSSAINI NAFISAT AKUKI\r/26.875/REF:GW6819765690000001500020120809\rf'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'KDNG'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'REF:681976569000000010002012101202  from'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'ENEYAMIRE JEMILATU\rReF:GW681976569000000300002012110919'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'ABDULLAHI\rReF:GW681976569000000130002012110923'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000020002012111627'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'ASHAFA IBRAHIM ABDULLAHI  to  ABDULLATIF,\rRUKAYYA'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'TRANSFER FOR\r000013201215113430000292092013 via\rGTWORLD  TO UBA/YUSUF HASSAN\rReF:GW681976569000000040002012151132'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000060002012160938'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'GTWORLD  TO ZBN/AISHA NAMAMA ZUBAIRU\r/26.875/REF:GW6819765690000002000020121715\rf'],
#        dtype='object'),
#  Index(['20-Dec-2020', '20-Dec-2020.1', ''0GWTR', '7,000.00', 'Unnamed: 0',
#         '-7,422.54', 'E- CHANNELS',
#         'TRANSFER BETWEEN CUSTOMERS Via GTWorld\rREF:681976569000000070002012201553  from\rASHAFA IBRAHIM ABDULLAHI  to  ABDULLATIF,\rRUKAYYA'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '000013201222122228000303286132 via'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'MOHAMMED\r/26.875/REF:GW6819765690000001000020122219\rf'],
#        dtype='object'),
#  Index(['23-Dec-2020', '23-Dec-2020.1', ''99993389179999', '2,100.00',
#         'Unnamed: 0', '-24,516.66', 'E- CHANNELS',
#         'POS/WEB PURCHASE TRANSACTION  -338917- -\r708511-PAYCOM NIGERIA LIMIT   LA           LANG'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ISMAIL RABO'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '20DEC2020'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'JEMILATU'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'REF:100004201227141611100314406715'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'GTWORLD  TO UBA/YAKUBU ASHAFA'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '000013210101131534000318536356 via'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'IBRA|614819958||abdullahi ibrahim\rREF:000010210102095847111038084692'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '/26.875/REF:GW6819765690000002000021010212\rf'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '/10.75/REF:GW6819765690000000500021010514  f'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'ABDULLAHI\rReF:GW681976569000000060002101060638'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210108165229000327186939 VAT ON NIP\rTRANSFER FOR\r000013210108165229000327186939 via\rGTWORLD  TO UBA/YAKUBU ASHAFA\rABDULLAHI\rReF:GW681976569000000050002101081651'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'GTWORLD  TO UBA/ZAINAB  UMAR'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'FUNSHO\rREF:000016210112164114000002233860'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '101CT0000000002289137209-2348038673032'],
#        dtype='object'),
#  Index(['01-Feb-2021', '01-Feb-2021.1', ''0USAT', '1,000.00', 'Unnamed: 0',
#         '8,146.27', 'E- CHANNELS',
#         'Airtime Purchase GTWORLD_QL-\r101CT0000000002334364532-2348038673032'],
#        dtype='object'),
#  Index(['02-Feb-2021', '02-Feb-2021.1', ''0NIPG', '25.00', 'Unnamed: 0',
#         '1,160.92', 'E- CHANNELS',
#         'COMMISSION 000013210202153948000360956151\rNIP TRANSFER COMMISSION FOR\r000013210202153948000360956151 via\rGTWORLD  TO ACCESS/SALIHU JOHN\rMUSTAPHA\rReF:GW681976569000000060002102021538'],
#        dtype='object'),
#  Index(['03-Feb-2021', '03-Feb-2021.1', ''99994361519999', '90,100.00',
#         'Unnamed: 0', '160,048.30', 'E- CHANNELS',
#         'POS/WEB PURCHASE TRANSACTION  -436151- -\r385669-BEST BUY APPLIANCES    LA           LANG'],
#        dtype='object'),
#  Index(['03-Feb-2021', '03-Feb-2021.1', ''0NIPT', 'Unnamed: 0', '50,000.00',
#         '61,320.68', 'E- CHANNELS',
#         'TRANSFER BETWEEN CUSTOMERS\r000015210203203422001470533624||ASHAFA\rIBRAHIM ABDULLAHI||ENEYAMIRE JEMILATU\rDEMIDE\rREF:000015210203203422001470533624'],
#        dtype='object'),
#  Index(['04-Feb-2021', '04-Feb-2021.1', ''0NIPG', '1.87', 'Unnamed: 0',
#         '20,788.94', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210204074527000363429064 VAT ON NIP\rTRANSFER FOR\r000013210204074527000363429064 via\rGTWORLD Bills TO UBA/ALIYU HAUWA\rReF:GW681976569000000300002102040743'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ABDULLAHI'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210208131926000369778449 VAT ON NIP\rTRANSFER FOR\r000013210208131926000369778449 via\rGTWORLD  TO FBN/LIBERTA LEASING LIMITED\rReF:GW681976569000000400002102081317'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'ASHAFA IBRAHIM ABDULLAHI  to  MUNDU\rHAUWA, MOHAMMED'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'ASHAFA IBRAHIM ABDULLAHI  to  ABDULLATIF,\rRUKAYYA'],
#        dtype='object'),
#  Index(['10-Feb-2021', '10-Feb-2021.1', ''99996923109999', '1,600.00',
#         'Unnamed: 0', '54,915.01', 'E- CHANNELS',
#         'POS/WEB PURCHASE TRANSACTION  -692310- -\r122553-PAYCOM NIGERIA LIMIT   LA           LANG'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'NIP TRANSFER COMMISSION FOR'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'CHARGE - 14/02/2021'],
#        dtype='object'),
#  Index(['16-Feb-2021', '16-Feb-2021.1', ''99996307219999', '3,000.00',
#         'Unnamed: 0', '1,065.89', 'E- CHANNELS',
#         'CASH WITHDRAWAL FROM OTHER ATM  -\r630721- -272650-KEYSTONE BANK          WUSE 1\rNG'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210219141042000006479351 VAT ON NIP'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '000015210221194205001510872617|Wawis'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210222154407000010115113 VAT ON NIP'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210222160431000010147525 via\rGTWORLD  TO IBRAHIM ASHAFA\rReF:GW681976569000002100002102221603'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000050002102221611'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '/26.875/REF:GW6819765690000000800021022216\rf'],
#        dtype='object'),
#  Index(['22-Feb-2021', '22-Feb-2021.1', ''0NIPG', '1.87', 'Unnamed: 0',
#         '50,286.41', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210222163832000010199317 VAT ON NIP\rTRANSFER FOR\r000013210222163832000010199317 via\rGTWORLD  TO AISHA NAMAMA ZUBAIRU\rReF:GW681976569000000100002102221636'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'NIP TRANSFER COMMISSION FOR\r000013210223092850000010883989 via\rGTWORLD  TO ZAM SHAMMAH DANIEL\rReF:GW681976569000000015002102230927'],
#        dtype='object'),
#  Index(['01-Mar-2021', '01-Mar-2021.1', ''0NIPG', '25.00', 'Unnamed: 0',
#         '6,716.77', 'E- CHANNELS',
#         'COMMISSION 000013210301103047000019583944\rNIP TRANSFER COMMISSION FOR\r000013210301103047000019583944 via\rGTWORLD  TO LIBERTA LEASING LIMITED\rReF:GW681976569000000100002103011029'],
#        dtype='object'),
#  Index(['02-Mar-2021', '02-Mar-2021.1', ''0NIPG', '1.87', 'Unnamed: 0',
#         '20,516.73', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210302124205000021642530 VAT ON NIP\rTRANSFER FOR\r000013210302124205000021642530 via\rGTWORLD  TO JAAFAR I AKUMA\rReF:GW681976569000000400002103021240'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '6375029029873783741963692'],
#        dtype='object'),
#  Index(['03-Mar-2021', '03-Mar-2021.1', ''0GWTR', '5,000.00', 'Unnamed: 0',
#         '21,013.34', 'E- CHANNELS',
#         'TRANSFER BETWEEN CUSTOMERS Via GTWorld\rREF:681976569000000050002103031133  from\rASHAFA IBRAHIM ABDULLAHI  to  ALIYU\rMUHAMMED AHMED'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'f'],
#        dtype='object'),
#  Index(['08-Mar-2021', '08-Mar-2021.1', ''0USAT', '200.00', 'Unnamed: 0',
#         '74.60', 'E- CHANNELS',
#         'Airtime Purchase GTWORLD_QL-\r101CT0000000002425037784-2348038673032'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '/26.875/REF:GW6819765690000000700021030912\rf'],
#        dtype='object'),
#  Index(['09-Mar-2021', '09-Mar-2021.1', ''0NIPG', '.75', 'Unnamed: 0',
#         '926,983.24', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210309121612000032587098 VAT ON NIP\rTRANSFER FOR\r000013210309121612000032587098 via\rGTWORLD  TO ABUBAKAR ABDULRAKIB\rReF:GW681976569000000050002103091214'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000700002103091225'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'NIP TRANSFER COMMISSION FOR\r000013210309130120000032666504 via\rGTWORLD  TO ADAM HAFSAT MOHAMMED\rReF:GW681976569000000060002103091259'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'GTWORLD  TO MUHAMMED  ABUBAKAR\rReF:GW681976569000000080002103091324'],
#        dtype='object'),
#  Index(['09-Mar-2021', '09-Mar-2021.1', ''11480000', '2,800.00', 'Unnamed: 0',
#         '57,930.01', 'E- CHANNELS',
#         'POS/WEB PURCHASE TRANSACTION  -001148- -\r935023-SAHAD STORES LTD (POS RFC\rLANG'],
#        dtype='object'),
#  Index(['10-Mar-2021', '10-Mar-2021.1', ''0NIPG', '1.87', 'Unnamed: 0',
#         '22,040.64', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210310134440000034276081 VAT ON NIP\rTRANSFER FOR\r000013210310134440000034276081 via\rGTWORLD  TO HUSSAINI MUSA\rReF:GW681976569000000500002103101343'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:001319344930645000002103111515'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'MOHAMMED   BAKO\rREF:000015210312143726001562712959'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'GTWORLD  TO IBRAHIM ABBA UMAR\r/26.875/REF:GW6819765690000003000021031214\rf'],
#        dtype='object'),
#  Index(['12-Mar-2021', '12-Mar-2021.1', ''0NIPG', '25.00', 'Unnamed: 0',
#         '236,600.65', 'E- CHANNELS',
#         'COMMISSION 000013210312150132000037372135\rNIP TRANSFER COMMISSION FOR\r000013210312150132000037372135 via\rGTWORLD  TO ASHAFA USMAN ABDULLAHI\rReF:GW681976569000000200002103121500'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000800002103121609'],
#        dtype='object'),
#  Index(['12-Mar-2021', '12-Mar-2021.1', ''0NIPG', '20,000.00', 'Unnamed: 0',
#         '93,480.54', 'E- CHANNELS',
#         'NIBSS Instant Payment Outward\r000013210312161526000037498214 via\rGTWORLD  TO IBRAHIM ABBA UMAR\r/26.875/REF:GW6819765690000002000021031216\rf'],
#        dtype='object'),
#  Index(['12-Mar-2021', '12-Mar-2021.1', ''0NIPG', '10.00', 'Unnamed: 0',
#         '58,216.80', 'E- CHANNELS',
#         'COMMISSION 000013210312184859000037761314\rNIP TRANSFER COMMISSION FOR\r000013210312184859000037761314 via\rGTWORLD  TO ISMAILA ATTEH AUDU\rReF:GW681976569000000050002103121847'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ISMAIL RABO'],
#        dtype='object'),
#  Index(['15-Mar-2021', '15-Mar-2021.1', ''0NIPG', '.75', 'Unnamed: 0',
#         '37,398.80', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210315084344000040524768 VAT ON NIP\rTRANSFER FOR\r000013210315084344000040524768 via\rGTWORLD  TO HASSAN MANSUR RAMALAN\rReF:GW681976569000000030002103150842'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '/53.75/REF:GW6819765690000029000021031516  f'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210315164819000041332528 via\rGTWORLD  TO ALIYU HAUWA\rReF:GW681976569000000200002103151646'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210315182653000041506944 via\rGTWORLD  TO DALHATU ABDULLAHI ASHAFA\rReF:GW681976569000000080002103151825'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210315211326000041738823 via\rGTWORLD  TO DALHATU ABDULLAHI ASHAFA\rReF:GW681976569000000010002103152111'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'GTWORLD  TO JAAFAR I AKUMA'],
#        dtype='object'),
#  Index(['18-Mar-2021', '18-Mar-2021.1', ''0GWTR', '5,000.00', 'Unnamed: 0',
#         '40,140.83', 'E- CHANNELS',
#         'TRANSFER BETWEEN CUSTOMERS Via GTWorld\rREF:681976569000000050002103181221  from\rASHAFA IBRAHIM ABDULLAHI  to  AMALA\rDELIGHT CITY RESTAURANT'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000050002103201744'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'REF:000015210321151410001590860189'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '/26.875/REF:GW6819765690000001200021032311\rf'],
#        dtype='object'),
#  Index(['23-Mar-2021', '23-Mar-2021.1', ''0NIPG', '.75', 'Unnamed: 0',
#         '85,048.34', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210323113123000051989604 VAT ON NIP\rTRANSFER FOR\r000013210323113123000051989604 via\rGTWORLD  TO USMAN YAKUBU BABA\rReF:GW681976569000000040002103231130'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'GTWORLD  TO AHMED GAMBO MOHAMMED\rReF:GW681976569000000015002103232203'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210325201335000055886467 via\rGTWORLD  TO IDA DANLAMI SULE\rReF:GW681976569000000050002103252012'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000050002103271911'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000015002103282216'],
#        dtype='object'),
#  Index(['01-Apr-2021', '01-Apr-2021.1', ''0NIPT', 'Unnamed: 0', '110,004.95',
#         '83,513.37', 'E- CHANNELS',
#         'TRANSFER BETWEEN CUSTOMERS\r000004210401110443200095077282|TUD\rIBG/UTO/NetC Mar Sal Ashsfa|200095077282||NET\rCONSTRUCT NIGERIA LIMITED\rREF:000004210401110443200095077282'],
#        dtype='object'),
#  Index(['02-Apr-2021', '02-Apr-2021.1', ''0NIPG', '.75', 'Unnamed: 0',
#         '35,609.75', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210402154517000068452216 VAT ON NIP\rTRANSFER FOR\r000013210402154517000068452216 via\rGTWORLD  TO ADO ABDUL BWARI\rReF:GW681976569000000020002104021543'],
#        dtype='object'),
#  Index(['04-Apr-2021', '04-Apr-2021.1', ''0USAT', '1,000.00', 'Unnamed: 0',
#         '21,088.25', 'E- CHANNELS',
#         'Airtime Purchase GTWORLD_QL-\r101CT0000000002490626388-2347063168196'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'REF: 0005628626111064050000000'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210407173501000076161809 via\rGTWORLD Hauwa TO DEMIDE ENEYAMIRE\rJEMILATU\r/26.875/REF:GW6819765690000002000021040717\rf'],
#        dtype='object'),
#  Index(['08-Apr-2021', '07-Apr-2021', ''0', '100.00', 'Unnamed: 0', '50,146.88',
#         'LAFIA', 'STAMP DUTY CHARGE 07042021 STAMP DUTY\rCHARGE - 07/04/2021'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'KDNG'],
#        dtype='object'),
#  Index(['10-Apr-2021', '10-Apr-2021.1', ''0NIPG', '10.00', 'Unnamed: 0',
#         '80,238.51', 'E- CHANNELS',
#         'COMMISSION 000013210410220609000081261167\rNIP TRANSFER COMMISSION FOR\r000013210410220609000081261167 via\rGTWORLD  TO UTHMAN BALA AHMED\rReF:GW681976569000000020002104102204'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '/26.875/REF:GW6819765690000000700021041211\rf'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'NIP TRANSFER COMMISSION FOR'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'ASHAFA IBRAHIM ABDULLAHI BO IBRAHIM\rAS|STAJJNG21041506235073||IBRAHIM ASHAFA\rREF:000026210415101759000003861618'],
#        dtype='object'),
#  Index(['15-Apr-2021', '15-Apr-2021.1', ''0USAT', '1,000.00', 'Unnamed: 0',
#         '31,157.66', 'E- CHANNELS',
#         'Airtime Purchase GTWORLD-\r101CT0000000002517180333-2348038673032'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210416111749000089328488 via\rGTWORLD  TO UMAR AMINA MOHAMMED\rReF:GW681976569000000020002104161115'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000020002104171900'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'TRANSFER FOR'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '/10.75/REF:GW6819765690000000400021042419  f'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'NIP TRANSFER COMMISSION FOR\r000013210426120239000103595981 via\rGTWORLD  TO JIBRIN BASIRAH USMAN\rReF:GW681976569000000100002104261201'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210427153421000105607837 via\rGTWORLD  TO MADAKI ALI\rReF:GW681976569000000020002104271532'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '000013210503135547000114957611 via'],
#        dtype='object'),
#  Index(['04-May-2021', '04-May-2021.1', ''0GAPS', 'Unnamed: 0', '47,500.00',
#         '381,029.73', 'E- CHANNELS',
#         'TRANSFER BETWEEN CUSTOMERS via GAPS\rcom on Kenneth J 2M sales 112623556 0 from\rNETCONSTRUCT NIGERIA LIMITED to ASHAFA\rIBRAHIM ABDULLAHI\rREF: 0005628626112623556000000'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'GTWORLD  TO ALIYU HAUWA'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210504192155000117212720 via\rGTWORLD  TO OJEIKPO MICHAEL ELAIGWU\r/53.75/REF:GW6819765690000013000021050419  f'],
#        dtype='object'),
#  Index(['04-May-2021', '04-May-2021.1', ''0NIPG', '1.87', 'Unnamed: 0',
#         '140,761.00', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210504194135000117240083 VAT ON NIP\rTRANSFER FOR\r000013210504194135000117240083 via\rGTWORLD  TO YAKUBU ASHAFA ABDULLAHI\rReF:GW681976569000000300002105041940'],
#        dtype='object'),
#  Index(['05-May-2021', '04-May-2021', ''0', '150.00', 'Unnamed: 0',
#         '135,089.50', 'LAFIA',
#         'STAMP DUTY CHARGE 04052021 STAMP DUTY\rCHARGE - 04/05/2021'],
#        dtype='object'),
#  Index(['07-May-2021', '06-May-2021', ''0', '50.00', 'Unnamed: 0', '140,218.00',
#         'LAFIA', 'STAMP DUTY CHARGE 06052021 STAMP DUTY\rCHARGE - 06/05/2021'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '101CT0000000002571822649-2348109828886'],
#        dtype='object'),
#  Index(['09-May-2021', '09-May-2021.1', ''0GWTR', '10,000.00', 'Unnamed: 0',
#         '115,208.88', 'E- CHANNELS',
#         'TRANSFER BETWEEN CUSTOMERS Via GTWorld\rREF:681976569000000100002105091230  from\rASHAFA IBRAHIM ABDULLAHI  to  SALAMI,\rABUBAKAR'],
#        dtype='object'),
#  Index(['11-May-2021', '11-May-2021.1', ''99990145079999', '1,850.00',
#         'Unnamed: 0', '98,348.13', 'E- CHANNELS',
#         'POS/WEB PURCHASE TRANSACTION  -014507- -\r855255-OJUELEGBA RESTAURANT & FC\rLANG'],
#        dtype='object'),
#  Index(['12-May-2021', '12-May-2021.1', ''0NIPG', '1,200.00', 'Unnamed: 0',
#         '109,110.51', 'E- CHANNELS',
#         'NIBSS Instant Payment Outward\r000013210512074538000129121977 via\rGTWORLD  TO HUSSAINI YUSUF\r/10.75/REF:GW6819765690000000120021051207  f'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', '05121533'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:000013210512211741000130492329'],
#        dtype='object'),
#  Index(['14-May-2021', '14-May-2021.1', ''0NIPG', '10.00', 'Unnamed: 0',
#         '60,087.64', 'E- CHANNELS',
#         'COMMISSION 000013210514071456000131957505\rNIP TRANSFER COMMISSION FOR\r000013210514071456000131957505 via\rGTWORLD  TO YUSUF HASSAN\rReF:GW681976569000000050002105140715'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'GTWORLD  TO YUSUF HASSAN\rReF:GW681976569000000050002105150632'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'TRANSFER FOR\r000013210517134246000136362998 via\rGTWORLD  TO DANSABO ABDULAZEEZ\rReF:GW681976569000000020002105171341'],
#        dtype='object'),
#  Index(['18-May-2021', '18-May-2021.1', ''99990016819999', '4,100.00',
#         'Unnamed: 0', '4,997.02', 'E- CHANNELS',
#         'POS/WEB PURCHASE TRANSACTION  -001681- -\r794422-PAYCOM NIGERIA LIMITED LA\rLANG'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000050002105192058'],
#        dtype='object'),
#  Index(['20-May-2021', '20-May-2021.1', ''0USAT', '1,000.00', 'Unnamed: 0',
#         '9,164.77', 'E- CHANNELS',
#         'Airtime Purchase GTWORLD_QL-\r101CT0000000002604374479-2348038673032'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'TRANSFER FOR'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000050002105211653'],
#        dtype='object'),
#  Index(['23-May-2021', '23-May-2021.1', ''0NIPG', '2,000.00', 'Unnamed: 0',
#         '28,038.28', 'E- CHANNELS',
#         'NIBSS Instant Payment Outward\r000013210523164333000145351940 via\rGTWORLD  TO JOSEPH DRAMABI YOHANNA\r/10.75/REF:GW6819765690000000200021052316  f'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'GTWORLD  TO BEPOS CLINIC AND MATERNITY'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'REF:000015210525133127001745906861'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'GTBank Transfer'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         'NASIR|100033210531165724000007092379||PALM\rPAY LIMITED\rREF:100033210531165724000007092379'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210531192542000158288788 via\rGTWORLD  TO AISHA NAMAMA ZUBAIRU\rReF:GW681976569000000100002105311926'],
#        dtype='object'),
#  Index(['02-Jun-2021', '02-Jun-2021.1', ''0USAT', '800.00', 'Unnamed: 0',
#         '1,237.88', 'E- CHANNELS',
#         'Airtime Purchase GTWORLD_QL-\r101CT0000000002636819537-2348109828886'],
#        dtype='object'),
#  Index(['02-Jun-2021', '02-Jun-2021.1', ''0NIPG', '1.87', 'Unnamed: 0',
#         '17,200.26', 'E- CHANNELS',
#         'VALUE ADDED TAX\r000013210602174926000161742014 VAT ON NIP\rTRANSFER FOR\r000013210602174926000161742014 via\rGTWORLD  TO AISHA NAMAMA ZUBAIRU\rReF:GW681976569000000100002106021750'],
#        dtype='object'),
#  Index(['02-Jun-2021', '02-Jun-2021.1', ''0NIPG', '10.00', 'Unnamed: 0',
#         '14,190.26', 'E- CHANNELS',
#         'COMMISSION 000013210602190815000161906176\rNIP TRANSFER COMMISSION FOR\r000013210602190815000161906176 via\rGTWORLD  TO OGBUKA IFEOMA ROSE\rReF:GW681976569000000030002106021908'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210604123924000164716236 VAT ON NIP'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210604132531000164803419 via\rGTWORLD  TO AISHA NAMAMA ZUBAIRU\rReF:GW681976569000000100002106041326'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000013210604184012000165434057 VAT ON NIP\rTRANSFER FOR\r000013210604184012000165434057 via\rGTWORLD  TO YAHAYA ABUBAKAR SADIQ\rReF:GW681976569000000030002106041840'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6', 'ReF:GW681976569000000015002106070934'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#         'Unnamed: 5', 'Unnamed: 6',
#         '000003210607155309000891578787|web:\rexchange|S24218089||HOUSE OF IZZI LIMITED\rREF:000003210607155309000891578787'],
#        dtype='object'),
#  Index(['07-Jun-2021', '07-Jun-2021.1', ''99990169049999', '3,500.00',
#         'Unnamed: 0', '12,788.35', 'E- CHANNELS',
#         'POS/WEB PURCHASE TRANSACTION  -016904- -\r660767-RAPHVASELL ENTERPRIS   FC\rFCNG'],
#        dtype='object'),
#  Index(['ReF:GW681976569000000040002106091419'], dtype='object')]

# %%
customer1.combine_dataframes()

# %%
customer1.master_df.head()
# Out:
#    Trans. Date  Value. Date  Reference  Debits     Credits     Balance  \
# 0  Trans. Date  Value. Date  Reference  Debits     Credits     Balance
# 1  07-Dec-2020  07-Dec-2020     '0GAPS     NaN  308,750.00  278,851.80
# 2          NaN          NaN        NaN     NaN         NaN         NaN
# 3          NaN          NaN        NaN     NaN         NaN         NaN
# 4          NaN          NaN        NaN     NaN         NaN         NaN
#
#    Originating Branch                                       Remarks
# 0  Originating Branch                                       Remarks
# 1         E- CHANNELS           TRANSFER BETWEEN CUSTOMERS via GAPS
# 2                 NaN  com on Babawuro A 13M sales 104164162 0 from
# 3                 NaN        NETCONSTRUCT NIGERIA LIMITED to ASHAFA
# 4                 NaN                             IBRAHIM ABDULLAHI

# %%
customer1.clean_dataframe()

# %%
customer1.clean_transactions()

# %%
customer1.postprocess()

# %%
customer1.recombined_dataframe()

# %%
customer1.dataset_recombined.head()
# Out:
#    Trans. Date Reference    Value. Date      Debits     Credits     Balance  \
# 0  07-Dec-2020    '0GAPS    07-Dec-2020         NaN  308,750.00  278,851.80
# 1  07-Dec-2020    '0GAPS    07-Dec-2020         NaN   82,092.39  360,944.19
# 2  07-Dec-2020    '0GWTR  07-Dec-2020.1   50,000.00         NaN  310,944.19
# 3  07-Dec-2020    '0NIPG    07-Dec-2020  140,000.00         NaN  170,944.19
# 4  07-Dec-2020    '0NIPG    07-Dec-2020       50.00         NaN  170,894.19
#
#                                                                                                                                                                                Remarks_processed  \
# 0                           TRANSFER BETWEEN CUSTOMERS via GAPScom on Babawuro A 13M sales 104164162 0 fromNETCONSTRUCT NIGERIA LIMITED to ASHAFAIBRAHIM ABDULLAHIREF: 0005628626104164162000000
# 1                        TRANSFER BETWEEN CUSTOMERS via GAPScom on Ekene Nnabuhie 3M sales 104164068 0 fromNETCONSTRUCT NIGERIA LIMITED to ASHAFAIBRAHIM ABDULLAHIREF: 0005628626104164068000000
# 2                                                          TRANSFER BETWEEN CUSTOMERS Via GTWorld Eneke   REF:681976569000000500002012070913 from ASHAFA IBRAHIM ABDULLAHI  to  SALAMI, ABUBAKAR
# 3                                  NIBSS Instant Payment Outward 000013201207091758000279938909 via GTWORLD Babawuro Ali TO FBN/MANCHA GILBERT SIMI /53.75/REF:GW6819765690000014000020120709  f
# 4  COMMISSION 000013201207091758000279938909 NIP TRANSFER COMMISSION FOR 000013201207091758000279938909 via GTWORLD Babawuro Ali TO FBN/MANCHA GILBERT SIMI ReF:GW681976569000001400002012070916
#
#       ACCOUNT_TYPE  BANK_ID  \
# 0  SAVINGS ACCOUNT  GT_Bank
# 1  SAVINGS ACCOUNT  GT_Bank
# 2  SAVINGS ACCOUNT  GT_Bank
# 3  SAVINGS ACCOUNT  GT_Bank
# 4  SAVINGS ACCOUNT  GT_Bank
#
#                                                     FILE_NAME
# 0  ./Dataset_banks/statements/MR IBRAHIM ASHAFA STATEMENT.pdf
# 1  ./Dataset_banks/statements/MR IBRAHIM ASHAFA STATEMENT.pdf
# 2  ./Dataset_banks/statements/MR IBRAHIM ASHAFA STATEMENT.pdf
# 3  ./Dataset_banks/statements/MR IBRAHIM ASHAFA STATEMENT.pdf
# 4  ./Dataset_banks/statements/MR IBRAHIM ASHAFA STATEMENT.pdf

# %% [markdown]
# ## 2. Features engineering (-> classifier)

# %%
class Dataset_Bank():
    def __init__(self, Data, a_list_of_keywords):
        # save data inside the object
        self._data = Data
        self.filename = Data['FILE_NAME'].unique()[0]
        self.account_type = Data['ACCOUNT_TYPE'].unique()[0]
        self.bank_id = Data['BANK_ID'].unique()[0]
        self.features_engineering(a_list_of_keywords)
        self.filter_text()
        self.dest()  
        self.clean_data()
        self.save2csv(out="./first_data.csv")
        self.subset_dataframe()
        #print(self.df.columns())
        self.impute_class()
        
    def features_engineering(self, a_list_of_keywords):

        for key_word in tqdm(a_list_of_keywords):
            self.check_keyword(key_word)
    
    def check_keyword(self, keyword):
        # check whether the criteria is valid
        self._data["IS_A_"+ keyword] =  self._data.loc[:,"Remarks_processed"].str.contains(keyword, case=False).astype('int')
    
    def filter_text(self):
        # filter description
        self._data["filtered_description"] = self._data.loc[:,"Remarks_processed"].str.findall('[^\d\W]+').str.join(sep =' ')
    
    def dest(self):
        # filtered benificiary
        self._data["filtered_dest"] = self._data["filtered_description"].str.upper()
        self._data["filtered_dest"] = self._data["filtered_dest"].str.split("TO").str[-1]
        
    def clean_data(self):
        # fix data problems
        # the "date format" problem inside timestamp cell
        # problem found : 02-Apr-2021.1
        self.csv_to_annotate = self._data
        for c in self.csv_to_annotate.columns[:2]:
            self.csv_to_annotate[c] = self.csv_to_annotate[c].apply(lambda x : str(x).split(".")[0])
            
        # problem found : \r inside the dataframe
        self.csv_to_annotate[c] = self.csv_to_annotate[c].astype('str').str.replace("\r"," ")
        
    def save2csv(self, out):
        self.df = self.csv_to_annotate.iloc[:-1,:]
        self.df.to_csv(out, index= None, sep = ";",encoding='utf-8-sig')
        print(self.df.columns)
        
        
    def subset_dataframe(self):
        '''
        creates subset dataframes with key information (loan, salary, cheque,commission,tax)
        '''
        self.salary = self.df[self.df["Remarks_processed"].str.contains("SALARY", case=False).values]
        self.salary_advance = self.df[self.df["Remarks_processed"].str.contains("SALARY ADVANCE", case=False).values]
        self.transfer = self.df[self.df["Remarks_processed"].str.contains("TRANSFER", case=False).values]
        self.loan = self.df[self.df["Remarks_processed"].str.contains("LOAN", case=False).values]
        self.tax = self.df[self.df["Remarks_processed"].str.contains("TAX", case=False).values]
        self.commission = self.df[self.df["Remarks_processed"].str.contains("COMM", case=False).values]
        self.cheque = self.df[self.df["Remarks_processed"].str.contains("CHEQUE",case=False).values]
        self.cash_withdrawal = self.df[self.df["Remarks_processed"].str.contains("WITHDRAWAL|CASH",case=False).values]
        self.others = self.df[self.df["Remarks_processed"].str.contains("OTHER",case=False).values]
        
    def impute_class(self):
        '''
        classify transactions based on remarks
        '''
        
        self.subset_dataframe()
        transfer_index = self.transfer.index
        comm_index = self.commission.index
        tax_index = self.tax.index
        salary_index = self.salary.index
        loan_index = self.loan.index
        
        impute_list = [
                    [transfer_index, "TRANSFER"],
                    [comm_index, "COMM"],
                    [tax_index,"TAX"],
                    [salary_index,"SALARY"],
                    [loan_index,"LOAN"]]

        self.df_class = self.df.copy()
        for element in impute_list:
            self.df_class.loc[element[0],"Class"] = element[1]

        return self.df_class

# %%
import copy

# %%
class Metrics2():
    def __init__(self,imputed_Dataset):
        self.Ds = copy.deepcopy(imputed_Dataset)
        self.data = imputed_Dataset.df_class
        self.create_loan_summary()
        self.DTI = {
        "LOW_EARNER": 0.33,
        "LOW_MED_EARNER":0.35,
        "MED_EARNER":0.40,
        "HIGH_MED_EARNER":0.45,
        "HIGH_EARNER": 0.5,
        "TOP_EARNER": 0.55
        }
    def create_salary_advance_summary(self):
        return self.Ds.salary_advance.shape[0] > 0
 
    def create_others_summary(self): 
        '''
        creates the dataframe for the loan info
        '''
        # convert entries to date format
        #self.data.loc[:]["Trans. Date"] = pd.to_datetime(self.Ds.loan["Trans. Date"], errors='coerce')
        
        # create a summary limiting ourselves to some columns
        other_summary = self.Ds.others.loc[:,["Trans. Date", "Credits", "Debits"]].copy()
        
        # use the colum ( just transformed to date format as index)
        other_summary.set_index('Trans. Date', inplace=True)
        
        
        # make sure thzat the index is @ the right format (date)
        other_summary.index = pd.to_datetime(other_summary.index)
        
        
        # remove the missing value and replace them by 0
        for cat in ["Credits", "Debits"]:
            other_summary[cat].fillna("0", inplace=True)

        
        # remove the thousands separator
        for cat in ["Credits", "Debits"]:
            other_summary[cat]= other_summary[cat].str.replace(",","").astype('float')
            
            
        # "effective" number of loans
        self.df_other_summary = other_summary.groupby(pd.Grouper(level='Trans. Date',freq='M')).sum()
        
        credits = self.df_other_summary.copy()
        debits = self.df_other_summary.copy()

        credits[credits['Credits']>0]=1
        debits[debits['Debits']>0]=-1
        
        credits['Credits'].fillna(0,inplace=True)
        debits['Debits'].fillna(0,inplace=True)

        df_credits = credits['Credits'].astype(str).str.replace(",","").astype('float')
        df_debits = debits['Debits'].astype(str).str.replace(",","").astype('float')
        
        
        
        self.total_n_other_summary = pd.DataFrame(pd.concat([df_debits,df_credits], axis = 1).sum(axis=1))
        self.total_n_other_summary.columns = ['#n loans']
        self.total_n_other_summary['#n loans'] = self.total_n_other_summary['#n loans'].apply(lambda x: np.abs(x))
        
        self.df_other_summary["effective"] = -1*self.df_other_summary["Debits"].astype('float')+self.df_other_summary["Credits"].astype('float')
        
        self.other_dict = {
            "other_summary" : self.df_other_summary, 
            "n_other_summary": self.total_n_other_summary
        }
        return self.other_dict
    
    
    def create_loan_summary(self):
        '''
        creates the dataframe for the loan info
        '''
        # convert entries to date format
        #self.data.loc[:]["Trans. Date"] = pd.to_datetime(self.Ds.loan["Trans. Date"], errors='coerce')
        
        # create a summary limiting ourselves to some columns
        loan_summary = self.Ds.loan.loc[:,["Trans. Date", "Credits", "Debits"]].copy()
        
        # use the colum ( just transformed to date format as index)
        loan_summary.set_index('Trans. Date', inplace=True)
        
        
        # make sure thzat the index is @ the right format (date)
        loan_summary.index = pd.to_datetime(loan_summary.index)
        
        
        # remove the missing value and replace them by 0
        for cat in ["Credits", "Debits"]:
            loan_summary[cat].fillna("0", inplace=True)

        
        # remove the thousands separator
        for cat in ["Credits", "Debits"]:
            loan_summary[cat]= loan_summary[cat].str.replace(",","").astype('float')
            
            
        # "effective" number of loans
        self.df_loan_summary = loan_summary.groupby(pd.Grouper(level='Trans. Date',freq='M')).sum()
        
        credits = self.df_loan_summary.copy()
        debits = self.df_loan_summary.copy()

        credits[credits['Credits']>0]=1
        debits[debits['Debits']>0]=-1
        
        credits['Credits'].fillna(0,inplace=True)
        debits['Debits'].fillna(0,inplace=True)

        df_credits = credits['Credits'].astype(str).str.replace(",","").astype('float')
        df_debits = debits['Debits'].astype(str).str.replace(",","").astype('float')
        
        
        
        self.total_n_loans_summary = pd.DataFrame(pd.concat([df_debits,df_credits], axis = 1).sum(axis=1))
        self.total_n_loans_summary.columns = ['#n loans']
        self.total_n_loans_summary['#n loans'] = self.total_n_loans_summary['#n loans'].apply(lambda x: np.abs(x))
        
        self.df_loan_summary["effective"] = -1*self.df_loan_summary["Debits"].astype('float')+self.df_loan_summary["Credits"].astype('float')
        
        self.loan_dict = {
            "loan_summary" : self.df_loan_summary, 
            "n_loans_summary": self.total_n_loans_summary
        }
        return self.loan_dict
    
    
    
    def create_cash_summary(self):

        self.Ds.cash_withdrawal.loc[:]["Trans. Date"] = pd.to_datetime(self.Ds.cash_withdrawal["Trans. Date"], errors='coerce')
        self.Ds.cash_withdrawal.set_index('Trans. Date', inplace=True)
        self.Ds.cash_withdrawal.index = pd.to_datetime(self.Ds.cash_withdrawal.index)
        
        number_of_payments = len(set(list(self.Ds.cash_withdrawal.index)))
        cash_info = np.array([[el.month,el.day] for el in set(list(self.Ds.cash_withdrawal.index))])



        cash_numeric = self.Ds.cash_withdrawal.loc[:,["Debits","Credits"]]
        
        for cat in ["Debits","Credits"] :
            cash_numeric[cat].fillna(0, inplace=True)
        
        for cat in ["Debits","Credits"] :
            cash_numeric[cat] = cash_numeric[cat].astype(str).str.replace(",","")
        
        cash_numeric["effective"] = cash_numeric["Credits"].astype('float') - cash_numeric["Debits"].astype('float')
        
        
        #aggregation - monthly income
        df_cash_summary = cash_numeric[["effective"]].groupby(pd.Grouper(level='Trans. Date',freq='M')).sum()
        

        self.cash_dict = {
            "all_transactions": cash_numeric,
            "number_of_payments": number_of_payments,
            "cash_summary": df_cash_summary,
         
        }
    
        return self.cash_dict
    

    
    def create_salary_summary(self):

        self.Ds.salary.loc[:]["Trans. Date"] = pd.to_datetime(self.Ds.salary["Trans. Date"], errors='coerce')
        self.Ds.salary.set_index('Trans. Date', inplace=True)
        self.Ds.salary.index = pd.to_datetime(self.Ds.salary.index)
        
        number_of_payments = len(set(list(self.Ds.salary.index)))
        paid_info = np.array([[el.month,el.day] for el in set(list(self.Ds.salary.index))])
        
        
        self.salary_dict = {
        "all_transactions": None,
        "number_of_payments": None,
        "paid_month": None,
        "paid_days": None,
        "paid_day_mean": None,
        "paid_day_variance": None,
        "salary_summary": pd.DataFrame(),
        "paid_to_employees": None
        }
    
        
        
        try:
            paid_month, paid_day = paid_info[:,0],paid_info[:,1]

            paid_day_mean, paid_day_variance = np.mean(paid_day), np.std(paid_day) 


            salary_numeric = self.Ds.salary.loc[:,["Debits","Credits"]]

            for cat in ["Debits","Credits"] :
                salary_numeric[cat].fillna(0, inplace=True)

            for cat in ["Debits","Credits"] :
                salary_numeric[cat] = salary_numeric[cat].astype(str).str.replace(",","")

            salary_numeric["effective"] = salary_numeric["Credits"].astype('float') - salary_numeric["Debits"].astype('float')


            #aggregation - monthly income
            df_salary_summary = salary_numeric[["effective"]].groupby(pd.Grouper(level='Trans. Date',freq='M')).sum()

            # check if the salary info describes income or paid salary
            salary_paid_to_employees = df_salary_summary["effective"].sum() <0

            self.salary_dict = {
                "all_transactions": salary_numeric,
                "number_of_payments": number_of_payments,
                "paid_month": paid_month,
                "paid_days": paid_day,
                "paid_day_mean": paid_day_mean,
                "paid_day_variance": paid_day_variance,
                "salary_summary": df_salary_summary,
                "paid_to_employees": salary_paid_to_employees
            }
        except IndexError as e:
            log_info('ANALYTICS',self.Ds.account_type, self.Ds.bank_id, self.Ds.filename, e)
            
        return self.salary_dict
        
        
        
    def create_transfer_between_summary(self):

        self.Ds.transfer.loc[:]["Trans. Date"] = pd.to_datetime(self.Ds.transfer["Trans. Date"], errors='coerce')
        self.Ds.transfer.set_index('Trans. Date', inplace=True)
        self.Ds.transfer.index = pd.to_datetime(self.Ds.transfer.index)
        
        number_of_transfer = len(set(list(self.Ds.transfer.index)))
        paid_info = np.array([[el.month,el.day] for el in set(list(self.Ds.transfer.index))])
        paid_month, paid_day = paid_info[:,0],paid_info[:,1]

        paid_day_mean, paid_day_variance = np.mean(paid_day), np.std(paid_day) 


        transfer_numeric = self.Ds.transfer.loc[:,["Debits","Credits"]]
        
        for cat in ["Debits","Credits"] :
            transfer_numeric[cat].fillna(0, inplace=True)
        
        for cat in ["Debits","Credits"] :
            transfer_numeric[cat] = transfer_numeric[cat].astype(str).str.replace(",","")
        
        transfer_numeric["effective"] = transfer_numeric["Credits"].astype('float') - transfer_numeric["Debits"].astype('float')
        
        
        #aggregation - monthly income
        df_transfer_summary = transfer_numeric[["effective"]].groupby(pd.Grouper(level='Trans. Date',freq='M')).sum()
        
        # check if the salary info describes income or paid salary
        total_transfer = df_transfer_summary["effective"].sum()
        
        self.transfer_between_summary_dict = {
            "all_transactions": transfer_numeric,
            "number_of_payments": number_of_transfer,
            "transfer_summary": df_transfer_summary,
            "total_transfer": total_transfer   
        }
        return self.transfer_between_summary_dict
    
    
    def create_salary_bracket(self, salary_dollars):
        
        if salary_dollars > 50000 and salary_dollars < 200000:
            bracket = "LOW_EARNER"
        elif salary_dollars > 210000 and salary_dollars < 500000:
            bracket = "LOW_MED_EARNER"
        elif salary_dollars > 500000 and salary_dollars < 1000000:  
            bracket = "MED_EARNER"
        elif salary_dollars > 1000000 and salary_dollars < 3000000: 
            bracket = "HIGH_MED_EARNER"
        elif salary_dollars > 3000000 and salary_dollars < 5000000:
            bracket = "HIGH_EARNER"
        elif salary_dollars > 5000000:
            bracket = "TOP_EARNER"
        return bracket
    
        
        
    
    
    def loan_to_salary_ratio(self):
        df_loan = self.loan_dict['loan_summary']
        
        df_transfer_summary = self.transfer_between_summary_dict['transfer_summary']
        df_salary_summary = self.salary_dict['salary_summary']
        print(df_salary_summary)
        
        if (df_salary_summary.empty) or (df_salary_summary["effective"].sum() <0):
            df_salary = df_transfer_summary    
            log_info('ANALYTICS_LOAN_TO_SALARY_RATIO',self.Ds.account_type, self.Ds.bank_id, self.Ds.filename, 'NO_SALARY')
                
        else:
            df_salary = df_salary_summary
        
        salary_bracket = self.create_salary_bracket(df_salary["effective"].mean())
        
        loan_to_salary = pd.merge(df_loan['effective'],df_salary['effective'], left_index=True,right_index=True )
        loan_to_salary.columns = ['effective_loan', 'salary']
        loan_to_salary['ratio'] = loan_to_salary['effective_loan']/loan_to_salary['salary']
        return loan_to_salary, salary_bracket
    
    
    def no_access_to_direct_debit_criteria(self):
        return self.Ds.bank_id.lower() in ["standard charter", "first bank", "stanbic"]
    
    
    def abnormal_transactions(self):
        self.Ds.transfer.loc[:,'F_Credits'] = self.Ds.transfer['Credits'].fillna(0).astype('str').str.replace(",","").astype('float').copy()
        
        self.Ds.salary.loc[:,'F_Credits'] = self.Ds.salary['Credits'].fillna(0).astype('str').str.replace(",","").astype('float').copy()

        self.Ds.transfer.loc[:,'F_Debits'] = self.Ds.transfer['Debits'].fillna(0).astype('str').str.replace(",","").astype('float').copy()
        
        df_salary_summary = self.salary_dict['salary_summary']
        
        if (df_salary_summary.empty) or (df_salary_summary["effective"].sum() <0):
            history_transaction_pos = self.Ds.transfer.loc[self.Ds.transfer['F_Credits']>0].copy()
        else:
            history_transaction_pos = self.Ds.salary.loc[self.Ds.transfer['F_Credits']>0].copy()
            
        history_transaction_neg = self.Ds.transfer.loc[self.Ds.transfer['F_Debits']>0].copy()
        
        print(history_transaction_neg.columns)
        
        transfer_pos = history_transaction_pos.loc[:,["F_Credits"]].groupby("Trans. Date").agg(sum)
        transfer_neg = history_transaction_neg.loc[:,["F_Debits"]].groupby("Trans. Date").agg(sum)

        self.transfer_anomaly = pd.merge(transfer_pos,transfer_neg,left_index=True,right_index=True, how='outer').fillna(0)
        #self.transfer_anomaly["daily_delta"] = (self.transfer_anomaly["F_Credits"] - self.transfer_anomaly["F_Debits"])/(transfer_anomaly["F_Credits"]+ 1e-6)
        #self.transfer_anomaly["abnormality"] = self.transfer_anomaly["daily_delta"].apply(lambda x: x <0.2 and x>0)
        
        
        self.transfer_anomaly["daily_delta"] = 1-(transfer_anomaly["F_Credits"] - transfer_anomaly["F_Debits"])/(transfer_anomaly["F_Credits"])
        self.transfer_anomaly["abnormality"] = transfer_anomaly["daily_delta"].apply(lambda x: x >0.8 and x!= np.inf).astype('int')
        
        self.transfer_anomaly.index = pd.to_datetime(transfer_anomaly.index)
        self.monthly_anomaly = transfer_anomaly[['abnormality']].groupby(pd.Grouper(level='Trans. Date',freq='M')).sum()
        self.daily_anomaly = transfer_anomaly[['abnormality']].groupby(pd.Grouper(level='Trans. Date',freq='D')).sum()
        return self.transfer_anomaly, self.daily_anomaly, self.monthly_anomaly

# %%
list_of_keywords = ["TRANSFER", "TRANSFER COMMISSION","TRANSFER BETWEEN CUSTOMERS","CONTRIBUTION",
                   "TAX","SALARY", "VAT", "WEB PURCHASE", "POS/WEB",
                   "AIRTIME", "PURCHASE", "INSTANT PAYMENT",
                   "CASH","WITHDRAWAL", "ATM", "SMS ALERT CHARGE",
                   "FAILED", "FUNDS", "FAILED","FUNDS","LOAN","INTEREST",
                    "GTWORLD", "LOANDISBURSEMENT"]


GT_Dataset = Dataset_Bank(customer1.dataset_recombined,list_of_keywords)
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 301.48it/s]
# Index(['Trans. Date', 'Reference', 'Value. Date', 'Debits', 'Credits',
#        'Balance', 'Remarks_processed', 'ACCOUNT_TYPE', 'BANK_ID', 'FILE_NAME',
#        'IS_A_TRANSFER', 'IS_A_TRANSFER COMMISSION',
#        'IS_A_TRANSFER BETWEEN CUSTOMERS', 'IS_A_CONTRIBUTION', 'IS_A_TAX',
#        'IS_A_SALARY', 'IS_A_VAT', 'IS_A_WEB PURCHASE', 'IS_A_POS/WEB',
#        'IS_A_AIRTIME', 'IS_A_PURCHASE', 'IS_A_INSTANT PAYMENT', 'IS_A_CASH',
#        'IS_A_WITHDRAWAL', 'IS_A_ATM', 'IS_A_SMS ALERT CHARGE', 'IS_A_FAILED',
#        'IS_A_FUNDS', 'IS_A_LOAN', 'IS_A_INTEREST', 'IS_A_GTWORLD',
#        'IS_A_LOANDISBURSEMENT', 'filtered_description', 'filtered_dest'],
#       dtype='object')

# %%
del(m)

# %%
m = Metrics2(GT_Dataset)
loans_dict = m.create_loan_summary()

cash_dict =  m.create_cash_summary()
salary_dict = m.create_salary_summary()
transfer_dict = m.create_transfer_between_summary()
other_dict = m.create_others_summary()
took_advance = m.create_salary_advance_summary()
abnormality_transactions = m.abnormal_transactions()
no_axess_dir_deb = m.no_access_to_direct_debit_criteria()
# Out:
# Index(['Reference', 'Value. Date', 'Debits', 'Credits', 'Balance',
#        'Remarks_processed', 'ACCOUNT_TYPE', 'BANK_ID', 'FILE_NAME',
#        'IS_A_TRANSFER', 'IS_A_TRANSFER COMMISSION',
#        'IS_A_TRANSFER BETWEEN CUSTOMERS', 'IS_A_CONTRIBUTION', 'IS_A_TAX',
#        'IS_A_SALARY', 'IS_A_VAT', 'IS_A_WEB PURCHASE', 'IS_A_POS/WEB',
#        'IS_A_AIRTIME', 'IS_A_PURCHASE', 'IS_A_INSTANT PAYMENT', 'IS_A_CASH',
#        'IS_A_WITHDRAWAL', 'IS_A_ATM', 'IS_A_SMS ALERT CHARGE', 'IS_A_FAILED',
#        'IS_A_FUNDS', 'IS_A_LOAN', 'IS_A_INTEREST', 'IS_A_GTWORLD',
#        'IS_A_LOANDISBURSEMENT', 'filtered_description', 'filtered_dest',
#        'F_Credits', 'F_Debits'],
#       dtype='object')

# %%
abnormality_transactions[0]
# Out:
#               F_Credits   F_Debits  daily_delta  abnormality
# Trans. Date
# 2021-04-01    618842.39  215531.10     0.348281            0
# 2021-02-01         0.00   11053.74          inf            0
# 2021-01-01         0.00      10.75          inf            0
# 2021-03-01         0.00    3021.50          inf            0
# 2021-04-02    120000.00   23118.23     0.192652            0
# 2021-02-02         0.00    2010.75          inf            0
# 2021-01-02         0.00    5021.50          inf            0
# 2021-06-02         0.00      21.50          inf            0
# 2021-03-02     34000.00   14026.87     0.412555            0
# 2021-04-03    110004.95   28053.74     0.255023            0
# 2021-02-03         0.00   22100.00          inf            0
# 2021-01-03     40000.00   23548.37     0.588709            0
# 2021-06-03    223250.00   98026.87     0.439090            0
# 2021-03-03         0.00    5000.00          inf            0
# 2021-05-03         0.00   11053.74          inf            0
# 2021-04-04     20000.00      10.75     0.000537            0
# 2021-02-04         0.00   12900.00          inf            0
# 2021-06-04         0.00    1026.87          inf            0
# 2021-03-04     10000.00      37.62     0.003762            0
# 2021-05-04     80000.00      75.24     0.000941            0
# 2021-02-05         0.00      10.75          inf            0
# 2021-01-05         0.00      21.50          inf            0
# 2021-03-05         0.00      37.62          inf            0
# 2021-01-06         0.00      10.75          inf            0
# 2021-05-06         0.00      21.50          inf            0
# 2021-04-07     23000.00       0.00     0.000000            0
# 2020-12-07     30000.00      37.62     0.001254            0
# 2021-06-07      2000.00       0.00     0.000000            0
# 2021-05-07     70970.94    2537.62     0.035756            0
# 2021-04-08      7125.00      37.62     0.005280            0
# 2020-12-08    300000.00     107.49     0.000358            0
# 2021-02-08         0.00      37.62          inf            0
# 2021-01-08         0.00    2010.75          inf            0
# 2021-06-08    473863.80   30161.23     0.063650            0
# 2021-05-08         0.00      26.87          inf            0
# 2021-04-09     20000.00   20021.50     1.001075            1
# 2020-12-09         0.00      10.75          inf            0
# 2021-01-09      5000.00       0.00     0.000000            0
# 2021-06-09     50000.00   30021.50     0.600430            0
# 2021-03-09      5000.00    2000.00     0.400000            0
# 2021-05-09    579500.00  177495.60     0.306291            0
# 2021-04-10         0.00      10.75          inf            0
# 2020-12-10     43263.08      26.87     0.000621            0
# 2021-01-10    107144.98   16964.49     0.158332            0
# 2021-03-10         0.00    5026.87          inf            0
# 2021-05-10    110000.00   35026.87     0.318426            0
# 2021-04-11         0.00    4000.00          inf            0
# 2020-12-11    958000.00   30413.84     0.031747            0
# 2021-02-11     62937.50   30526.87     0.485035            0
# 2021-03-11    700000.00   11253.75     0.016077            0
# 2021-05-11    817300.00  110570.84     0.135288            0
# 2021-04-12     20000.00   15121.50     0.756075            0
# 2020-12-12    450000.00   10704.23     0.023787            0
# 2021-01-12         0.00    7100.00          inf            0
# 2021-03-12     10000.00      64.49     0.006449            0
# 2021-05-12         0.00    5000.00          inf            0
# 2021-04-13      5000.00       0.00     0.000000            0
# 2020-12-13         0.00      10.75          inf            0
# 2021-03-13      8000.00      21.50     0.002687            0
# 2021-05-13         0.00      10.75          inf            0
# 2021-04-14    115000.00      85.99     0.000748            0
# 2021-02-14         0.00      37.62          inf            0
# 2021-05-14         0.00   10000.00          inf            0
# 2021-04-15         0.00      10.75          inf            0
# 2020-12-15         0.00      21.50          inf            0
# 2021-01-15     43263.08      26.87     0.000621            0
# 2021-03-15    110004.95       0.00     0.000000            0
# 2021-05-15      5000.00      37.62     0.007524            0
# 2021-04-16         0.00      10.75          inf            0
# 2020-12-16         0.00      10.75          inf            0
# 2021-02-16    269250.00      91.37     0.000339            0
# 2021-03-16         0.00      37.62          inf            0
# 2021-04-17    100000.00       0.00     0.000000            0
# 2020-12-17         0.00   14321.50          inf            0
# 2021-03-17         0.00   70200.00          inf            0
# 2021-05-17     30000.00    2153.74     0.071791            0
# 2021-02-18         0.00    4600.00          inf            0
# 2021-03-18     20000.00    3137.62     0.156881            0
# 2021-05-18    100000.00   53053.74     0.530537            0
# 2021-04-19     54438.80   20010.75     0.367582            0
# 2021-02-19         0.00    9221.50          inf            0
# 2021-03-19         0.00   10100.00          inf            0
# 2021-05-19     14250.00      10.75     0.000754            0
# 2020-12-20     20000.00   15137.62     0.756881            0
# 2021-03-20    120000.00   90053.74     0.750448            0
# 2021-05-20         0.00    3760.75          inf            0
# 2021-02-21    110004.95   40037.62     0.363962            0
# 2021-03-21    661000.00   30290.23     0.045825            0
# 2021-05-21     15000.00      21.50     0.001433            0
# 2020-12-22     22800.00      32.25     0.001414            0
# 2021-02-22         0.00      26.87          inf            0
# 2021-03-22         0.00   10000.00          inf            0
# 2021-05-22      5000.00    5000.00     1.000000            1
# 2021-04-23     25000.00    2048.37     0.081935            0
# 2021-02-23         0.00   24064.50          inf            0
# 2021-03-23         0.00      26.87          inf            0
# 2021-05-23         0.00      32.25          inf            0
# 2021-04-24         0.00   10010.75          inf            0
# 2020-12-24         0.00   10010.75          inf            0
# 2021-05-24         0.00    3537.62          inf            0
# 2020-12-25     10000.00      10.75     0.001075            0
# 2021-03-25     35000.00    3048.37     0.087096            0
# 2021-05-25     50000.00      48.37     0.000967            0
# 2021-04-26      4000.00       0.00     0.000000            0
# 2020-12-26     10000.00      21.50     0.002150            0
# 2021-03-26         0.00    5126.87          inf            0
# 2021-05-26     10000.00      21.50     0.002150            0
# 2021-04-27         0.00    2010.75          inf            0
# 2020-12-27     10000.00       0.00     0.000000            0
# 2021-03-27      7000.00      10.75     0.001536            0
# 2021-05-27     20000.00    5053.74     0.252687            0
# 2021-03-28    120400.00   70075.24     0.582020            0
# 2021-05-28         0.00    5500.00          inf            0
# 2021-03-29    120004.94     102.11     0.000851            0
# 2020-12-30   2023525.00    3128.99     0.001546            0
# 2020-12-31         0.00      10.75          inf            0
# 2021-05-31         0.00      10.00          inf            0

# %%
# to do check against a certain regexp
# unit tests

# %% [markdown]
# ### 3. Analytics

# %%
# salary

# %%
def salary_stability(df_salary):
    return df_salary['Credits'].std()

# %% [markdown]
# ## 3. Rules

# %%
# high risk:
- Low Income
- Multiple Loans
- Total Monthly Loan repayment is higher than Net salary
- Instant transfer of salary to any other account

# %%
# move the money on the other account the day or the next day" not many transactions in the account
# probaly something to hide
# 12465 type of expense - hidden things for a loan
# direct debit /loan

# %%
# Ayo

# %% [markdown]
# - Unstable Net Income ( what is the criteria for instable : variation of how many % ?) - > 10 % & above
# - leave allowances/bonus (quaterly) -tricky

# %% [markdown]
# - Unstable Salary Date ( what is the criteria for instable : variation of how many days ?) More than 1 week

# %% [markdown]
# - Constant delay repayment (where to find this info?) - can not do (finsoft)

# %% [markdown]
# - No access to direct debit on salary Account (where to find this info?)
# - no direct debit (standard charter, first bank, stanbic)

# %% [markdown]
# - already taken I.O.U from Organization (not clear)
# - company name (mentionned for salary)

# %% [markdown]
# - High Number of returned cheques
# - 1 max for any period

# %% [markdown]
# - Works in a blue chip company - can not do myself (finsoft)
# - (structured company)

# %%
# Assan

# %% [markdown]
# - Salary Account is not a checking account  (to debug)

# %%
pd.read_csv('./dataset_statement_bank_type.csv')
# Out:
#        bank       folder                                  filename  \
# 0   gt_bank  1_statement  214773647637581511468199616204-part1.pdf
# 1   gt_bank  1_statement  214773647637581511468199616204-part2.pdf
# 2   gt_bank  1_statement  214773647637581511468199616204-part3.pdf
# 3   gt_bank  1_statement  214773647637581511468199616204-part4.pdf
# 4   gt_bank  1_statement      250231923637586605609611256130-part1
# 5   gt_bank  1_statement      250231923637586605609611256130-part2
# 6   gt_bank  1_statement       Mr  festus oshokhue statement-part1
# 7   gt_bank  1_statement       Mr  festus oshokhue statement-part2
# 8   gt_bank  1_statement         MR SAMSON UGWANYI STATEMENT-part1
# 9   gt_bank  1_statement         MR SAMSON UGWANYI STATEMENT-part2
# 10  gt_bank  1_statement       MR TAPIYA JOHN BANK STATEMENT-part1
# 11  gt_bank  1_statement       MR TAPIYA JOHN BANK STATEMENT-part2
# 12  gt_bank  1_statement       MR TAPIYA JOHN BANK STATEMENT-part3
# 13  gt_bank  1_statement               Mr Tochukwu statement-part1
# 14  gt_bank  1_statement               Mr Tochukwu statement-part2
# 15  gt_bank  1_statement               Mr Tochukwu statement-part3
# 16  gt_bank  1_statement               Mr Tochukwu statement-part4
# 17  gt_bank   statements                 0163041071-(205154861110)
# 18  gt_bank   statements            214773647637581511468199616204
# 19  gt_bank   statements            250231923637586605609611256130
# 20  gt_bank   statements             68197656963758929248882067034
# 21  gt_bank   statements               Abiodun_lanre_gtb_statement
# 22  gt_bank   statements                 ADENIRAN SUNDAY STATEMENT
# 23  gt_bank   statements             Mr  festus oshokhue statement
# 24  gt_bank   statements               MR IBRAHIM ASHAFA STATEMENT
# 25  gt_bank   statements                MR MOSES ADEYEMI STATEMENT
# 26  gt_bank   statements               MR SAMSON UGWANYI STATEMENT
# 27  gt_bank   statements             MR TAPIYA JOHN BANK STATEMENT
# 28  gt_bank   statements                     Mr Tochukwu statement
#
#                   bank_account template_type
# 0                      CURRENT     NO_HEADER
# 1                      SAVINGS     NO_HEADER
# 2                      CURRENT     NO_HEADER
# 3   MASTERCARD/VISA DEBIT CARD     NO_HEADER
# 4                      CURRENT     NO_HEADER
# 5                      SAVINGS     NO_HEADER
# 6                      CURRENT     NO_HEADER
# 7                      SAVINGS     NO_HEADER
# 8                      CURRENT     NO_HEADER
# 9                      SAVINGS     NO_HEADER
# 10                     CURRENT     NO_HEADER
# 11                     SAVINGS     NO_HEADER
# 12                     CURRENT     NO_HEADER
# 13                     CURRENT     NO_HEADER
# 14                     SAVINGS     NO_HEADER
# 15                     CURRENT     NO_HEADER
# 16  MASTERCARD/VISA DEBIT CARD     NO_HEADER
# 17                     CURRENT        HEADER
# 18                       MULTI     NO_HEADER
# 19                       MULTI     NO_HEADER
# 20                     SAVINGS     NO_HEADER
# 21                     CURRENT        HEADER
# 22                     SAVINGS     NO_HEADER
# 23                       MULTI     NO_HEADER
# 24                     SAVINGS     NO_HEADER
# 25                     SAVINGS     NO_HEADER
# 26                       MULTI     NO_HEADER
# 27                       MULTI     NO_HEADER
# 28                       MULTI     NO_HEADER

# %% [markdown]
# ## 4. Classifier Model

# %% [markdown]
# ## 5 score extraction

# %% [markdown]
# ### a. Credit score (final score)

# %%
l_credit_scores = glob2.glob('./credit_score/*')

# %%
credit_report_godwin = l_credit_scores[0]

# %%
TOP = 253
LEFT = 23
WIDTH = 280
HEIGHT = 28
PDF_WIDTH = 612
PDF_HEIGHT = 792



df = tabula.read_pdf(credit_report_godwin, 
                     multiple_tables=True,
                     area=[100*TOP/PDF_HEIGHT,
                           100*LEFT/PDF_WIDTH,
                           100*(TOP+ HEIGHT)/PDF_HEIGHT,
                           100*(LEFT+WIDTH)/PDF_WIDTH],
                     relative_area=True,
                    pages='1')

# %%
df[0]

# %% [markdown]
# ### b. Score summary breakdown

# %%
# repayment history
# total amount owed
# types of credits in use


TOP = 196
LEFT = 244
WIDTH = 112
HEIGHT = 54
PDF_WIDTH = 612
PDF_HEIGHT = 792



df = tabula.read_pdf(credit_report_godwin, 
                     multiple_tables=True,
                     area=[100*TOP/PDF_HEIGHT,
                           100*LEFT/PDF_WIDTH,
                           100*(TOP+ HEIGHT)/PDF_HEIGHT,
                           100*(LEFT+WIDTH)/PDF_WIDTH],
                     relative_area=True,
                    pages='1')

score_summary_breakdown_1 = df[0].T.reset_index(drop=True).T

# %%
# length of credit history
# number of credits



TOP = 180
LEFT = 356
WIDTH = 116
HEIGHT = 53
PDF_WIDTH = 612
PDF_HEIGHT = 792



df = tabula.read_pdf(credit_report_godwin, 
                     multiple_tables=True,
                     area=[100*TOP/PDF_HEIGHT,
                           100*LEFT/PDF_WIDTH,
                           100*(TOP+ HEIGHT)/PDF_HEIGHT,
                           100*(LEFT+WIDTH)/PDF_WIDTH],
                     relative_area=True,
                    pages='1')

score_summary_breakdown_2 = df[0].T.reset_index(drop=True).T

# %%
score_summary_breakdown = pd.concat([score_summary_breakdown_1,score_summary_breakdown_2], axis=0).T

# %%
new_header = [el.strip() for el in score_summary_breakdown.iloc[0]]
score_summary = score_summary_breakdown[1:]
score_summary.columns = new_header

# %%
score_summary

# %%
score_total_amount_owned = score_summary['Total Amount Owed:'].str.split("/").str[0].astype('float')
score_total_type_of_credits_in_use = score_summary['Types of Credit(s) in Use:'].str.split("/").str[0].astype('float')
score_total_length_of_credit_history = score_summary['Length of Credit History:'].str.split("/").str[0].astype('float')
score_total_number_of_credits = score_summary['Number of Credits:'].str.split("/").str[0].astype('float')

# %%
score_total_amount_owned_max = score_summary['Total Amount Owed:'].str.split("/").str[1].astype('float')
score_total_type_of_credits_in_use_max = score_summary['Types of Credit(s) in Use:'].str.split("/").str[1].astype('float')
score_total_length_of_credit_history_max = score_summary['Length of Credit History:'].str.split("/").str[1].astype('float')
score_total_number_of_credits_max = score_summary['Number of Credits:'].str.split("/").str[1].astype('float')

# %%
pd.DataFrame([score_total_amount_owned/score_total_amount_owned_max,
score_total_type_of_credits_in_use/score_total_type_of_credits_in_use_max,
score_total_length_of_credit_history/score_total_length_of_credit_history_max,
score_total_number_of_credits/score_total_number_of_credits_max]).T

# %% [markdown]
# ___________

# %%
# each pdf can extract tables
# (those tables will be without headers)

# %%
# this first table has the correct header
df[1].columns

# %%
# this second table DOES NOT have the correct header
df[2].columns

# %%
# We want to recreate the header (which matches table 1)

# %%
reformatted_dfs = [df[k].T.reset_index().T for k in range(1,len(df),1)]
finalized_dfs = []
for idx,r_df in enumerate(reformatted_dfs): 
    try:
        r_df.columns = df[1].columns
        r_df.index = range(r_df.shape[0])
        r_df = r_df.replace(regex=[r'^Unnamed:..$'], value=np.nan)
        finalized_dfs.append(r_df)
    except:
        # if it fails, it is because it is a table of another type
        print(idx)

# %%
# Visualize the first table of the finalized dataframes
finalized_dfs[0]

# %%
# reset index in order to prevent problmems of indexation
master_df = pd.concat(finalized_dfs[:]).reset_index(drop=True)

# %%
# extra cleaning

master_df = master_df[master_df['Remarks']!= 'Remarks']
master_df = master_df[master_df['Remarks']!= 'Balance as at Last Transaction.']
master_df = master_df[master_df["Trans. Date"] != 'Trans. Date']

# %%
master_df = master_df.reset_index(drop=True)

# %%
transaction_not_null = master_df[~master_df["Trans. Date"].isna()]
index_list_of_transaction = list(transaction_not_null.index)

# %%
# all the transaction whithout a null starting date
transaction_not_null

# %%
# check that the column names is OK
transaction_not_null.columns

# %%
# create a dictionary with row indexes to keep
descr = {}

# %%
#transaction_not_null.loc[transaction_not_null.shape[0]]= [np.nan for i in range(8)]
# Create an arbitrary date (year 4021)
transaction_not_null.loc[master_df.index.max() +1,'Trans. Date'] = '01-Apr-4021'
#transaction_not_null = transaction_not_null[transaction_not_null["Trans. Date"] != 'Trans. Date']

# %%
# visualize the dataframe and its modification
transaction_not_null

# %%
# all the indexes of the transaction with dates
index_with_dates = transaction_not_null.index

# %%
descr ={}
for step in index_with_dates:
    descr[str(step)] = []
descr

# %%
step = 0    

for idx, step in enumerate(index_with_dates):
    if idx < len(index_with_dates)-1:
        for ind in range(index_with_dates[idx], index_with_dates[idx+1], 1):
            if ind < index_with_dates[idx+1]: 
                if str(master_df.loc[ind, 'Remarks']) != 'nan':
                    descr[str(step)] += [str(master_df.loc[ind, 'Remarks'])]
    else:
        for ind in range(index_with_dates[idx], master_df.shape[0], 1):
            if str(master_df.loc[ind, 'Remarks']) != 'nan':
                descr[str(step)] += [str(master_df.loc[ind, 'Remarks'])]

# %%
for key in descr.keys():
    descr[key] = (''.join(descr[key])).replace('\r',' ')

# %%
descr

# %%
# Dataframe of the transactions
pd.DataFrame.from_dict(descr,  orient='index', columns=['remarks_one_line'])

# %%
import json

# %%
my_j =  "{\"Transactions\": [{\"transactionType\": \"SALES\",\"transactionAmount\": 10.05}]}"

# %%
json.loads(my_j)

# %%
my_j['msg'].keys()

# %%
# trial on 1 dataframe

# %%
first_transaction = df[1]

first_transaction_not_null = first_transaction[~first_transaction["Trans. Date"].isna()]
index_list_of_transaction = list(first_transaction_not_null.index)
first_transaction_not_null.columns

# %%
first_transaction

# %%
descr = {}
first_transaction.shape

# %%
first_transaction.loc[first_transaction.shape[0]]= [np.nan for i in range(8)]
first_transaction.loc[first_transaction.shape[0],'Trans. Date'] = '01-Apr-4021'

# %%
first_transaction

# %%
index_with_dates = list(first_transaction[~first_transaction['Trans. Date'].isnull()].index)

# %%
descr ={}
for step in index_with_dates:
    descr[step] = []
descr

# %%
index_with_dates

# %%
step = 0    

for idx, step in enumerate(index_with_dates):
    print(idx)
    if idx < len(index_with_dates)-1:
        for ind in range(index_with_dates[idx], index_with_dates[idx+1], 1):
            if ind < index_with_dates[idx+1]: 
                if str(first_transaction.loc[ind, 'Remarks']) != 'nan':
                    descr[step] += [str(first_transaction.loc[ind, 'Remarks'])]
    else:
        for ind in range(index_with_dates[idx], first_transaction.shape[0], 1):
            if str(first_transaction.loc[ind, 'Remarks']) != 'nan':
                descr[step] += [str(first_transaction.loc[ind, 'Remarks'])]

# %%
for key in descr.keys():
    descr[key] = (''.join(descr[key]))

# %%
descr

# %% [markdown]
# # 2. Data conversion

# %%
import time
import typing

# %%
def time_my_func(func):
    
    def inner_func(a_string):
        start = time.time()
        a =  func(a_string)
        end = time.time()
        print(f"it took : {(end-start)*1e6} microseconds")
        return a
    return inner_func

# %%
@time_my_func
def process(my_string:str) -> int:
    return(len(my_string))

# %%
process("this sheez is crazy")

# %%
def parameterize(c):
    def smart_div(func):
        def inner_f(a,b):
            return(func(c,a))
        return inner_f
    return smart_div

# %%
@parameterize(500)
def div(a,b):
    return a/b

# %%
div(3,4)

# %%
div(30,4)

# %% [markdown]
# # 3. Conversion evaluation
